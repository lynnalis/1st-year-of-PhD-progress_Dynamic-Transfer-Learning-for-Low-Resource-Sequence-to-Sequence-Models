# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/hplt-bin/Bin_hplt/train.en-ar.ar.bin
# /kaggle/input/hplt-bin/Bin_hplt/train.en-ar.en.bin
# /kaggle/input/hplt-bin/Bin_hplt/dict.ar.txt
# /kaggle/input/hplt-bin/Bin_hplt/test.en-ar.ar.bin
# /kaggle/input/hplt-bin/Bin_hplt/valid.en-ar.en.idx
# /kaggle/input/hplt-bin/Bin_hplt/test.en-ar.ar.idx
# /kaggle/input/hplt-bin/Bin_hplt/train.en-ar.ar.idx
# /kaggle/input/hplt-bin/Bin_hplt/preprocess.log
# /kaggle/input/hplt-bin/Bin_hplt/train.en-ar.en.idx
# /kaggle/input/hplt-bin/Bin_hplt/valid.en-ar.en.bin
# /kaggle/input/hplt-bin/Bin_hplt/dict.en.txt
# /kaggle/input/hplt-bin/Bin_hplt/valid.en-ar.ar.idx
# /kaggle/input/hplt-bin/Bin_hplt/valid.en-ar.ar.bin
# /kaggle/input/hplt-bin/Bin_hplt/test.en-ar.en.bin
# /kaggle/input/hplt-bin/Bin_hplt/test.en-ar.en.idx
# /kaggle/input/pseudo-madar/psmada-bin/preprocess.log
# /kaggle/input/pseudo-madar/psmada-bin/dict.en.txt
# /kaggle/input/pseudo-madar/psmada-bin/train.en-None.en.bin
# /kaggle/input/pseudo-madar/psmada-bin/train.en-None.en.idx
# /kaggle/input/parent_best/pytorch/default/1/checkpoint_best.pt
# /kaggle/input/parent_best/pytorch/default/1/parent_training_log.txt
# /kaggle/input/bin-madar/Bin_madar/valid.drj-ar.drj.bin
# /kaggle/input/bin-madar/Bin_madar/train.drj-ar.drj.idx
# /kaggle/input/bin-madar/Bin_madar/test.drj-ar.ar.bin
# /kaggle/input/bin-madar/Bin_madar/dict.ar.txt
# /kaggle/input/bin-madar/Bin_madar/train.drj-ar.drj.bin
# /kaggle/input/bin-madar/Bin_madar/train.drj-ar.ar.bin
# /kaggle/input/bin-madar/Bin_madar/valid.drj-ar.ar.bin
# /kaggle/input/bin-madar/Bin_madar/preprocess.log
# /kaggle/input/bin-madar/Bin_madar/test.drj-ar.drj.idx
# /kaggle/input/bin-madar/Bin_madar/test.drj-ar.drj.bin
# /kaggle/input/bin-madar/Bin_madar/test.drj-ar.ar.idx
# /kaggle/input/bin-madar/Bin_madar/train.drj-ar.ar.idx
# /kaggle/input/bin-madar/Bin_madar/valid.drj-ar.drj.idx
# /kaggle/input/bin-madar/Bin_madar/valid.drj-ar.ar.idx
# /kaggle/input/bin-madar/Bin_madar/dict.drj.txt
# /kaggle/input/bin-padic/Bin_padic/valid.drj-ar.drj.bin
# /kaggle/input/bin-padic/Bin_padic/train.drj-ar.drj.idx
# /kaggle/input/bin-padic/Bin_padic/test.drj-ar.ar.bin
# /kaggle/input/bin-padic/Bin_padic/dict.ar.txt
# /kaggle/input/bin-padic/Bin_padic/train.drj-ar.drj.bin
# /kaggle/input/bin-padic/Bin_padic/train.drj-ar.ar.bin
# /kaggle/input/bin-padic/Bin_padic/valid.drj-ar.ar.bin
# /kaggle/input/bin-padic/Bin_padic/preprocess.log
# /kaggle/input/bin-padic/Bin_padic/test.drj-ar.drj.idx
# /kaggle/input/bin-padic/Bin_padic/test.drj-ar.drj.bin
# /kaggle/input/bin-padic/Bin_padic/test.drj-ar.ar.idx
# /kaggle/input/bin-padic/Bin_padic/train.drj-ar.ar.idx
# /kaggle/input/bin-padic/Bin_padic/valid.drj-ar.drj.idx
# /kaggle/input/bin-padic/Bin_padic/valid.drj-ar.ar.idx
# /kaggle/input/bin-padic/Bin_padic/dict.drj.txt
# /kaggle/input/pseudo-data-bin/pseudo-bin/preprocess.log
# /kaggle/input/pseudo-data-bin/pseudo-bin/dict.en.txt
# /kaggle/input/pseudo-data-bin/pseudo-bin/train.en-None.en.bin
# /kaggle/input/pseudo-data-bin/pseudo-bin/train.en-None.en.idx

# %%
# !apt-get update
# !sudo apt install -y build-essential zlib1g-dev libncurses5-dev libgdbm-dev libnss3-dev libssl-dev libreadline-dev libffi-dev libsqlite3-dev wget libbz2-dev
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,762 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,139 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,126 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [75.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,461 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,840 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,572 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,148 kB]
# Get:21 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [32.9 kB]
# Get:22 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [51.0 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,932 kB]
# Get:24 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [48.5 kB]
# Get:25 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,267 kB]
# Fetched 34.0 MB in 3s (12.9 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libbz2-dev is already the newest version (1.0.8-5build1).
# libbz2-dev set to manually installed.
# libffi-dev is already the newest version (3.4.2-4).
# libffi-dev set to manually installed.
# libreadline-dev is already the newest version (8.1.2-1).
# libreadline-dev set to manually installed.
# libncurses5-dev is already the newest version (6.3-2ubuntu0.1).
# libsqlite3-dev is already the newest version (3.37.2-2ubuntu0.4).
# libsqlite3-dev set to manually installed.
# libssl-dev is already the newest version (3.0.2-0ubuntu1.19).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   libnspr4-dev
# The following NEW packages will be installed:
#   libgdbm-dev libnspr4-dev libnss3-dev
# 0 upgraded, 3 newly installed, 0 to remove and 75 not upgraded.
# Need to get 581 kB of archives.
# After this operation, 2,950 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgdbm-dev amd64 1.23-1 [117 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnspr4-dev amd64 2:4.35-0ubuntu0.22.04.1 [219 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnss3-dev amd64 2:3.98-0ubuntu0.22.04.2 [246 kB]
# Fetched 581 kB in 0s (2,038 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
#
# 78Selecting previously unselected package libgdbm-dev:amd64.
# (Reading database ... 128663 files and directories currently installed.)
# Preparing to unpack .../libgdbm-dev_1.23-1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  8%] [####......................................................] 8Unpacking libgdbm-dev:amd64 (1.23-1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libnspr4-dev.
# Preparing to unpack .../libnspr4-dev_2%3a4.35-0ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libnspr4-dev (2:4.35-0ubuntu0.22.04.1) ...
# 7Progress: [ 31%] [#################.........................................] 8Selecting previously unselected package libnss3-dev:amd64.
# Preparing to unpack .../libnss3-dev_2%3a3.98-0ubuntu0.22.04.2_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libnss3-dev:amd64 (2:3.98-0ubuntu0.22.04.2) ...
# 7Progress: [ 46%] [##########################................................] 8Setting up libnspr4-dev (2:4.35-0ubuntu0.22.04.1) ...
# 7Progress: [ 54%] [###############################...........................] 87Progress: [ 62%] [###################################.......................] 8Setting up libnss3-dev:amd64 (2:3.98-0ubuntu0.22.04.2) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 77%] [############################################..............] 8Setting up libgdbm-dev:amd64 (1.23-1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 92%] [#####################################################.....] 8Processing triggers for man-db (2.10.2-1) ...
#
# 78

# %%
# !wget https://www.python.org/ftp/python/3.10.12/Python-3.10.12.tgz
# Out:
# --2025-07-21 10:20:46--  https://www.python.org/ftp/python/3.10.12/Python-3.10.12.tgz
# Resolving www.python.org (www.python.org)... 151.101.64.223, 151.101.192.223, 151.101.128.223, ...
# Connecting to www.python.org (www.python.org)|151.101.64.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26103005 (25M) [application/octet-stream]
# Saving to: ‘Python-3.10.12.tgz’
#
# Python-3.10.12.tgz  100%[===================>]  24.89M  --.-KB/s    in 0.1s
#
# 2025-07-21 10:20:46 (188 MB/s) - ‘Python-3.10.12.tgz’ saved [26103005/26103005]

# %%
# !tar -zvxf /kaggle/working/Python-3.10.12.tgz
# Out:
# Python-3.10.12/
# Python-3.10.12/Mac/
# Python-3.10.12/Mac/README.rst
# Python-3.10.12/Mac/Icons/
# Python-3.10.12/Mac/Icons/PythonLauncher.icns
# Python-3.10.12/Mac/Icons/IDLE.icns
# Python-3.10.12/Mac/Icons/PythonCompiled.icns
# Python-3.10.12/Mac/Icons/ReadMe.txt
# Python-3.10.12/Mac/Icons/PythonSource.icns
# Python-3.10.12/Mac/Icons/Disk Image.icns
# Python-3.10.12/Mac/Icons/Python Folder.icns
# Python-3.10.12/Mac/Tools/
# Python-3.10.12/Mac/Tools/pythonw.c
# Python-3.10.12/Mac/Tools/plistlib_generate_testdata.py
# Python-3.10.12/Mac/Makefile.in
# Python-3.10.12/Mac/Resources/
# Python-3.10.12/Mac/Resources/framework/
# Python-3.10.12/Mac/Resources/framework/Info.plist.in
# Python-3.10.12/Mac/Resources/app/
# Python-3.10.12/Mac/Resources/app/PkgInfo
# Python-3.10.12/Mac/Resources/app/Resources/
# Python-3.10.12/Mac/Resources/app/Resources/PythonApplet.icns
# Python-3.10.12/Mac/Resources/app/Resources/PythonInterpreter.icns
# Python-3.10.12/Mac/Resources/app/Info.plist.in
# Python-3.10.12/Mac/Resources/iconsrc/
# Python-3.10.12/Mac/Resources/iconsrc/PythonSource.psd
# Python-3.10.12/Mac/Resources/iconsrc/PythonCompiled.psd
# Python-3.10.12/Mac/Resources/iconsrc/PythonApplet.psd
# Python-3.10.12/Mac/Resources/iconsrc/IDE.psd
# Python-3.10.12/Mac/Resources/iconsrc/PythonIcon.psd
# Python-3.10.12/Mac/Resources/iconsrc/PackageManager.psd
# Python-3.10.12/Mac/Resources/iconsrc/PythonWSource.psd
# Python-3.10.12/Mac/Extras.install.py
# Python-3.10.12/Mac/BuildScript/
# Python-3.10.12/Mac/BuildScript/README.rst
# Python-3.10.12/Mac/BuildScript/build-installer.py
# Python-3.10.12/Mac/BuildScript/tk868_on_10_8_10_9.patch
# Python-3.10.12/Mac/BuildScript/seticon.m
# Python-3.10.12/Mac/BuildScript/scripts/
# Python-3.10.12/Mac/BuildScript/scripts/postflight.documentation
# Python-3.10.12/Mac/BuildScript/scripts/postflight.framework
# Python-3.10.12/Mac/BuildScript/scripts/postflight.ensurepip
# Python-3.10.12/Mac/BuildScript/scripts/postflight.patch-profile
# Python-3.10.12/Mac/BuildScript/resources/
# Python-3.10.12/Mac/BuildScript/resources/ReadMe.rtf
# Python-3.10.12/Mac/BuildScript/resources/Conclusion.rtf
# Python-3.10.12/Mac/BuildScript/resources/License.rtf
# Python-3.10.12/Mac/BuildScript/resources/install_certificates.command
# Python-3.10.12/Mac/BuildScript/resources/Welcome.rtf
# Python-3.10.12/Mac/BuildScript/resources/background.jpg
# Python-3.10.12/Mac/IDLE/
# Python-3.10.12/Mac/IDLE/IDLE.app/
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/Info.plist
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/PkgInfo
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/MacOS/
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/MacOS/IDLE
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/Resources/
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/Resources/idlemain.py
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/Resources/IDLE.icns
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/Resources/PythonCompiled.icns
# Python-3.10.12/Mac/IDLE/IDLE.app/Contents/Resources/PythonSource.icns
# Python-3.10.12/Mac/PythonLauncher/
# Python-3.10.12/Mac/PythonLauncher/MyAppDelegate.h
# Python-3.10.12/Mac/PythonLauncher/MyDocument.h
# Python-3.10.12/Mac/PythonLauncher/FileSettings.m
# Python-3.10.12/Mac/PythonLauncher/PreferencesWindowController.m
# Python-3.10.12/Mac/PythonLauncher/factorySettings.plist
# Python-3.10.12/Mac/PythonLauncher/FileSettings.h
# Python-3.10.12/Mac/PythonLauncher/Makefile.in
# Python-3.10.12/Mac/PythonLauncher/MyDocument.m
# Python-3.10.12/Mac/PythonLauncher/MyAppDelegate.m
# Python-3.10.12/Mac/PythonLauncher/Info.plist.in
# Python-3.10.12/Mac/PythonLauncher/main.m
# Python-3.10.12/Mac/PythonLauncher/doscript.h
# Python-3.10.12/Mac/PythonLauncher/doscript.m
# Python-3.10.12/Mac/PythonLauncher/English.lproj/
# Python-3.10.12/Mac/PythonLauncher/English.lproj/PreferenceWindow.nib/
# Python-3.10.12/Mac/PythonLauncher/English.lproj/PreferenceWindow.nib/info.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/PreferenceWindow.nib/objects.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/PreferenceWindow.nib/classes.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MyDocument.nib/
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MyDocument.nib/info.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MyDocument.nib/objects.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MyDocument.nib/classes.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/Credits.rtf
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MainMenu.nib/
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MainMenu.nib/info.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MainMenu.nib/objects.nib
# Python-3.10.12/Mac/PythonLauncher/English.lproj/MainMenu.nib/classes.nib
# Python-3.10.12/Mac/PythonLauncher/PreferencesWindowController.h
# Python-3.10.12/README.rst
# Python-3.10.12/Python/
# Python-3.10.12/Python/clinic/
# Python-3.10.12/Python/clinic/marshal.c.h
# Python-3.10.12/Python/clinic/traceback.c.h
# Python-3.10.12/Python/clinic/import.c.h
# Python-3.10.12/Python/clinic/bltinmodule.c.h
# Python-3.10.12/Python/clinic/sysmodule.c.h
# Python-3.10.12/Python/clinic/context.c.h
# Python-3.10.12/Python/clinic/_warnings.c.h
# Python-3.10.12/Python/symtable.c
# Python-3.10.12/Python/pystrtod.c
# Python-3.10.12/Python/formatter_unicode.c
# Python-3.10.12/Python/dynamic_annotations.c
# Python-3.10.12/Python/ceval.c
# Python-3.10.12/Python/dynload_stub.c
# Python-3.10.12/Python/pylifecycle.c
# Python-3.10.12/Python/dup2.c
# Python-3.10.12/Python/modsupport.c
# Python-3.10.12/Python/importdl.h
# Python-3.10.12/Python/frozen_hello.h
# Python-3.10.12/Python/ast_unparse.c
# Python-3.10.12/Python/README
# Python-3.10.12/Python/pystrcmp.c
# Python-3.10.12/Python/dtoa.c
# Python-3.10.12/Python/dynload_hpux.c
# Python-3.10.12/Python/structmember.c
# Python-3.10.12/Python/pyfpe.c
# Python-3.10.12/Python/_warnings.c
# Python-3.10.12/Python/asdl.c
# Python-3.10.12/Python/pystrhex.c
# Python-3.10.12/Python/pythonrun.c
# Python-3.10.12/Python/frozen.c
# Python-3.10.12/Python/preconfig.c
# Python-3.10.12/Python/context.c
# Python-3.10.12/Python/compile.c
# Python-3.10.12/Python/thread.c
# Python-3.10.12/Python/suggestions.c
# Python-3.10.12/Python/fileutils.c
# Python-3.10.12/Python/wordcode_helpers.h
# Python-3.10.12/Python/getversion.c
# Python-3.10.12/Python/frozenmain.c
# Python-3.10.12/Python/ast.c
# Python-3.10.12/Python/thread_nt.h
# Python-3.10.12/Python/sysmodule.c
# Python-3.10.12/Python/codecs.c
# Python-3.10.12/Python/bootstrap_hash.c
# Python-3.10.12/Python/mystrtoul.c
# Python-3.10.12/Python/pyarena.c
# Python-3.10.12/Python/getcompiler.c
# Python-3.10.12/Python/errors.c
# Python-3.10.12/Python/getopt.c
# Python-3.10.12/Python/hamt.c
# Python-3.10.12/Python/pystate.c
# Python-3.10.12/Python/pyctype.c
# Python-3.10.12/Python/importlib_external.h
# Python-3.10.12/Python/opcode_targets.h
# Python-3.10.12/Python/pyhash.c
# Python-3.10.12/Python/future.c
# Python-3.10.12/Python/import.c
# Python-3.10.12/Python/initconfig.c
# Python-3.10.12/Python/dynload_shlib.c
# Python-3.10.12/Python/Python-ast.c
# Python-3.10.12/Python/dynload_win.c
# Python-3.10.12/Python/ceval_gil.h
# Python-3.10.12/Python/marshal.c
# Python-3.10.12/Python/mysnprintf.c
# Python-3.10.12/Python/pathconfig.c
# Python-3.10.12/Python/importlib.h
# Python-3.10.12/Python/condvar.h
# Python-3.10.12/Python/bltinmodule.c
# Python-3.10.12/Python/pytime.c
# Python-3.10.12/Python/thread_pthread.h
# Python-3.10.12/Python/getargs.c
# Python-3.10.12/Python/ast_opt.c
# Python-3.10.12/Python/getcopyright.c
# Python-3.10.12/Python/pymath.c
# Python-3.10.12/Python/getplatform.c
# Python-3.10.12/Python/makeopcodetargets.py
# Python-3.10.12/Python/stdlib_module_names.h
# Python-3.10.12/Python/traceback.c
# Python-3.10.12/Python/importdl.c
# Python-3.10.12/Python/hashtable.c
# Python-3.10.12/Python/importlib_zipimport.h
# Python-3.10.12/Grammar/
# Python-3.10.12/Grammar/Tokens
# Python-3.10.12/Grammar/python.gram
# Python-3.10.12/Tools/
# Python-3.10.12/Tools/clinic/
# Python-3.10.12/Tools/clinic/cpp.py
# Python-3.10.12/Tools/clinic/clinic.py
# Python-3.10.12/Tools/README
# Python-3.10.12/Tools/peg_generator/
# Python-3.10.12/Tools/peg_generator/pegen/
# Python-3.10.12/Tools/peg_generator/pegen/c_generator.py
# Python-3.10.12/Tools/peg_generator/pegen/sccutils.py
# Python-3.10.12/Tools/peg_generator/pegen/grammar_parser.py
# Python-3.10.12/Tools/peg_generator/pegen/keywordgen.py
# Python-3.10.12/Tools/peg_generator/pegen/tokenizer.py
# Python-3.10.12/Tools/peg_generator/pegen/metagrammar.gram
# Python-3.10.12/Tools/peg_generator/pegen/__main__.py
# Python-3.10.12/Tools/peg_generator/pegen/build.py
# Python-3.10.12/Tools/peg_generator/pegen/grammar.py
# Python-3.10.12/Tools/peg_generator/pegen/ast_dump.py
# Python-3.10.12/Tools/peg_generator/pegen/parser.py
# Python-3.10.12/Tools/peg_generator/pegen/grammar_visualizer.py
# Python-3.10.12/Tools/peg_generator/pegen/testutil.py
# Python-3.10.12/Tools/peg_generator/pegen/python_generator.py
# Python-3.10.12/Tools/peg_generator/pegen/__init__.py
# Python-3.10.12/Tools/peg_generator/pegen/first_sets.py
# Python-3.10.12/Tools/peg_generator/pegen/validator.py
# Python-3.10.12/Tools/peg_generator/pegen/parser_generator.py
# Python-3.10.12/Tools/peg_generator/pyproject.toml
# Python-3.10.12/Tools/peg_generator/requirements.pip
# Python-3.10.12/Tools/peg_generator/mypy.ini
# Python-3.10.12/Tools/peg_generator/.clang-format
# Python-3.10.12/Tools/peg_generator/scripts/
# Python-3.10.12/Tools/peg_generator/scripts/ast_timings.py
# Python-3.10.12/Tools/peg_generator/scripts/benchmark.py
# Python-3.10.12/Tools/peg_generator/scripts/download_pypi_packages.py
# Python-3.10.12/Tools/peg_generator/scripts/test_pypi_packages.py
# Python-3.10.12/Tools/peg_generator/scripts/joinstats.py
# Python-3.10.12/Tools/peg_generator/scripts/test_parse_directory.py
# Python-3.10.12/Tools/peg_generator/scripts/__init__.py
# Python-3.10.12/Tools/peg_generator/scripts/grammar_grapher.py
# Python-3.10.12/Tools/peg_generator/scripts/find_max_nesting.py
# Python-3.10.12/Tools/peg_generator/peg_extension/
# Python-3.10.12/Tools/peg_generator/peg_extension/__init__.py
# Python-3.10.12/Tools/peg_generator/peg_extension/peg_extension.c
# Python-3.10.12/Tools/peg_generator/Makefile
# Python-3.10.12/Tools/peg_generator/data/
# Python-3.10.12/Tools/peg_generator/data/top-pypi-packages-365-days.json
# Python-3.10.12/Tools/peg_generator/data/cprog.py
# Python-3.10.12/Tools/peg_generator/data/xxl.zip
# Python-3.10.12/Tools/peg_generator/.gitignore
# Python-3.10.12/Tools/nuget/
# Python-3.10.12/Tools/nuget/build.bat
# Python-3.10.12/Tools/nuget/python.nuspec
# Python-3.10.12/Tools/nuget/pythondaily.symbols.nuspec
# Python-3.10.12/Tools/nuget/make_pkg.proj
# Python-3.10.12/Tools/nuget/pythonarm32.nuspec
# Python-3.10.12/Tools/nuget/pythondaily.nuspec
# Python-3.10.12/Tools/nuget/pythonx86.nuspec
# Python-3.10.12/Tools/tz/
# Python-3.10.12/Tools/tz/zdump.py
# Python-3.10.12/Tools/test2to3/
# Python-3.10.12/Tools/test2to3/README
# Python-3.10.12/Tools/test2to3/maintest.py
# Python-3.10.12/Tools/test2to3/test2to3/
# Python-3.10.12/Tools/test2to3/test2to3/hello.py
# Python-3.10.12/Tools/test2to3/test2to3/__init__.py
# Python-3.10.12/Tools/test2to3/setup.py
# Python-3.10.12/Tools/test2to3/test/
# Python-3.10.12/Tools/test2to3/test/test_foo.py
# Python-3.10.12/Tools/test2to3/test/runtests.py
# Python-3.10.12/Tools/ccbench/
# Python-3.10.12/Tools/ccbench/ccbench.py
# Python-3.10.12/Tools/pynche/
# Python-3.10.12/Tools/pynche/StripViewer.py
# Python-3.10.12/Tools/pynche/ListViewer.py
# Python-3.10.12/Tools/pynche/pyColorChooser.py
# Python-3.10.12/Tools/pynche/websafe.txt
# Python-3.10.12/Tools/pynche/PyncheWidget.py
# Python-3.10.12/Tools/pynche/README
# Python-3.10.12/Tools/pynche/Main.py
# Python-3.10.12/Tools/pynche/namedcolors.txt
# Python-3.10.12/Tools/pynche/ColorDB.py
# Python-3.10.12/Tools/pynche/pynche
# Python-3.10.12/Tools/pynche/webcolors.txt
# Python-3.10.12/Tools/pynche/X/
# Python-3.10.12/Tools/pynche/X/xlicense.txt
# Python-3.10.12/Tools/pynche/X/rgb.txt
# Python-3.10.12/Tools/pynche/TypeinViewer.py
# Python-3.10.12/Tools/pynche/Switchboard.py
# Python-3.10.12/Tools/pynche/__init__.py
# Python-3.10.12/Tools/pynche/TextViewer.py
# Python-3.10.12/Tools/pynche/html40colors.txt
# Python-3.10.12/Tools/pynche/pynche.pyw
# Python-3.10.12/Tools/pynche/ChipViewer.py
# Python-3.10.12/Tools/pynche/DetailsViewer.py
# Python-3.10.12/Tools/freeze/
# Python-3.10.12/Tools/freeze/makeconfig.py
# Python-3.10.12/Tools/freeze/README
# Python-3.10.12/Tools/freeze/bkfile.py
# Python-3.10.12/Tools/freeze/makefreeze.py
# Python-3.10.12/Tools/freeze/checkextensions_win32.py
# Python-3.10.12/Tools/freeze/checkextensions.py
# Python-3.10.12/Tools/freeze/flag.py
# Python-3.10.12/Tools/freeze/winmakemakefile.py
# Python-3.10.12/Tools/freeze/test/
# Python-3.10.12/Tools/freeze/test/ok.py
# Python-3.10.12/Tools/freeze/test/Makefile
# Python-3.10.12/Tools/freeze/hello.py
# Python-3.10.12/Tools/freeze/win32.html
# Python-3.10.12/Tools/freeze/parsesetup.py
# Python-3.10.12/Tools/freeze/extensions_win32.ini
# Python-3.10.12/Tools/freeze/makemakefile.py
# Python-3.10.12/Tools/freeze/regen_frozen.py
# Python-3.10.12/Tools/freeze/freeze.py
# Python-3.10.12/Tools/importbench/
# Python-3.10.12/Tools/importbench/README
# Python-3.10.12/Tools/importbench/importbench.py
# Python-3.10.12/Tools/msi/
# Python-3.10.12/Tools/msi/lib/
# Python-3.10.12/Tools/msi/lib/lib.wxs
# Python-3.10.12/Tools/msi/lib/lib_pdb.wxs
# Python-3.10.12/Tools/msi/lib/lib_pdb.wixproj
# Python-3.10.12/Tools/msi/lib/lib.wixproj
# Python-3.10.12/Tools/msi/lib/lib_d.wixproj
# Python-3.10.12/Tools/msi/lib/lib_files.wxs
# Python-3.10.12/Tools/msi/lib/lib_d.wxs
# Python-3.10.12/Tools/msi/lib/lib_en-US.wxl
# Python-3.10.12/Tools/msi/build.bat
# Python-3.10.12/Tools/msi/msi.targets
# Python-3.10.12/Tools/msi/common_en-US.wxl_template
# Python-3.10.12/Tools/msi/dev/
# Python-3.10.12/Tools/msi/dev/dev.wixproj
# Python-3.10.12/Tools/msi/dev/dev_files.wxs
# Python-3.10.12/Tools/msi/dev/dev_en-US.wxl
# Python-3.10.12/Tools/msi/dev/dev.wxs
# Python-3.10.12/Tools/msi/dev/dev_d.wxs
# Python-3.10.12/Tools/msi/dev/dev_d.wixproj
# Python-3.10.12/Tools/msi/ucrt/
# Python-3.10.12/Tools/msi/ucrt/ucrt.wixproj
# Python-3.10.12/Tools/msi/ucrt/ucrt_en-US.wxl
# Python-3.10.12/Tools/msi/ucrt/ucrt.wxs
# Python-3.10.12/Tools/msi/uploadrelease.ps1
# Python-3.10.12/Tools/msi/path/
# Python-3.10.12/Tools/msi/path/path.wixproj
# Python-3.10.12/Tools/msi/path/path.wxs
# Python-3.10.12/Tools/msi/path/path_en-US.wxl
# Python-3.10.12/Tools/msi/README.txt
# Python-3.10.12/Tools/msi/sign_build.ps1
# Python-3.10.12/Tools/msi/msi.props
# Python-3.10.12/Tools/msi/make_zip.proj
# Python-3.10.12/Tools/msi/uploadrelease.proj
# Python-3.10.12/Tools/msi/bundle/
# Python-3.10.12/Tools/msi/bundle/releaselocal.wixproj
# Python-3.10.12/Tools/msi/bundle/snapshot.wixproj
# Python-3.10.12/Tools/msi/bundle/bundle.targets
# Python-3.10.12/Tools/msi/bundle/packagegroups/
# Python-3.10.12/Tools/msi/bundle/packagegroups/lib.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/postinstall.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/doc.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/core.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/tcltk.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/test.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/launcher.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/pip.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/packageinstall.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/exe.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/dev.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/crt.wxs
# Python-3.10.12/Tools/msi/bundle/packagegroups/tools.wxs
# Python-3.10.12/Tools/msi/bundle/Default.wxl
# Python-3.10.12/Tools/msi/bundle/Default.thm
# Python-3.10.12/Tools/msi/bundle/full.wixproj
# Python-3.10.12/Tools/msi/bundle/SideBar.png
# Python-3.10.12/Tools/msi/bundle/bundle.wxs
# Python-3.10.12/Tools/msi/bundle/bundle.wxl
# Python-3.10.12/Tools/msi/bundle/bootstrap/
# Python-3.10.12/Tools/msi/bundle/bootstrap/pythonba.def
# Python-3.10.12/Tools/msi/bundle/bootstrap/LICENSE.txt
# Python-3.10.12/Tools/msi/bundle/bootstrap/pch.h
# Python-3.10.12/Tools/msi/bundle/bootstrap/pythonba.vcxproj
# Python-3.10.12/Tools/msi/bundle/bootstrap/pch.cpp
# Python-3.10.12/Tools/msi/bundle/bootstrap/pythonba.cpp
# Python-3.10.12/Tools/msi/bundle/bootstrap/resource.h
# Python-3.10.12/Tools/msi/bundle/bootstrap/pythonba.sln
# Python-3.10.12/Tools/msi/bundle/bootstrap/PythonBootstrapperApplication.cpp
# Python-3.10.12/Tools/msi/bundle/releaseweb.wixproj
# Python-3.10.12/Tools/msi/test/
# Python-3.10.12/Tools/msi/test/test_d.wixproj
# Python-3.10.12/Tools/msi/test/test_d.wxs
# Python-3.10.12/Tools/msi/test/test.wxs
# Python-3.10.12/Tools/msi/test/test_pdb.wixproj
# Python-3.10.12/Tools/msi/test/test_en-US.wxl
# Python-3.10.12/Tools/msi/test/test_pdb.wxs
# Python-3.10.12/Tools/msi/test/test.wixproj
# Python-3.10.12/Tools/msi/test/test_files.wxs
# Python-3.10.12/Tools/msi/tcltk/
# Python-3.10.12/Tools/msi/tcltk/tcltk_reg.wxs
# Python-3.10.12/Tools/msi/tcltk/tcltk.wxs
# Python-3.10.12/Tools/msi/tcltk/tcltk_files.wxs
# Python-3.10.12/Tools/msi/tcltk/tcltk_d.wxs
# Python-3.10.12/Tools/msi/tcltk/tcltk.wixproj
# Python-3.10.12/Tools/msi/tcltk/tcltk_d.wixproj
# Python-3.10.12/Tools/msi/tcltk/tcltk_en-US.wxl_template
# Python-3.10.12/Tools/msi/tcltk/tcltk_pdb.wixproj
# Python-3.10.12/Tools/msi/tcltk/tcltk_pdb.wxs
# Python-3.10.12/Tools/msi/sdktools.psm1
# Python-3.10.12/Tools/msi/pip/
# Python-3.10.12/Tools/msi/pip/pip.wixproj
# Python-3.10.12/Tools/msi/pip/pip.wxs
# Python-3.10.12/Tools/msi/pip/pip_en-US.wxl
# Python-3.10.12/Tools/msi/launcher/
# Python-3.10.12/Tools/msi/launcher/launcher.wxs
# Python-3.10.12/Tools/msi/launcher/launcher_files.wxs
# Python-3.10.12/Tools/msi/launcher/launcher_en-US.wxl
# Python-3.10.12/Tools/msi/launcher/launcher.wixproj
# Python-3.10.12/Tools/msi/launcher/launcher_reg.wxs
# Python-3.10.12/Tools/msi/make_cat.ps1
# Python-3.10.12/Tools/msi/doc/
# Python-3.10.12/Tools/msi/doc/doc.wxs
# Python-3.10.12/Tools/msi/doc/doc_files.wxs
# Python-3.10.12/Tools/msi/doc/doc_no_files.wxs
# Python-3.10.12/Tools/msi/doc/doc_en-US.wxl_template
# Python-3.10.12/Tools/msi/doc/doc.wixproj
# Python-3.10.12/Tools/msi/generate_md5.py
# Python-3.10.12/Tools/msi/common.wxs
# Python-3.10.12/Tools/msi/uploadrelease.bat
# Python-3.10.12/Tools/msi/core/
# Python-3.10.12/Tools/msi/core/core.wxs
# Python-3.10.12/Tools/msi/core/core_files.wxs
# Python-3.10.12/Tools/msi/core/core_pdb.wxs
# Python-3.10.12/Tools/msi/core/core_pdb.wixproj
# Python-3.10.12/Tools/msi/core/core_en-US.wxl
# Python-3.10.12/Tools/msi/core/core_d.wixproj
# Python-3.10.12/Tools/msi/core/core_d.wxs
# Python-3.10.12/Tools/msi/core/core.wixproj
# Python-3.10.12/Tools/msi/csv_to_wxs.py
# Python-3.10.12/Tools/msi/exe/
# Python-3.10.12/Tools/msi/exe/exe_d.wxs
# Python-3.10.12/Tools/msi/exe/exe_files.wxs
# Python-3.10.12/Tools/msi/exe/exe_reg.wxs
# Python-3.10.12/Tools/msi/exe/exe_en-US.wxl_template
# Python-3.10.12/Tools/msi/exe/exe_pdb.wixproj
# Python-3.10.12/Tools/msi/exe/exe.wxs
# Python-3.10.12/Tools/msi/exe/exe.wixproj
# Python-3.10.12/Tools/msi/exe/exe_pdb.wxs
# Python-3.10.12/Tools/msi/exe/exe_d.wixproj
# Python-3.10.12/Tools/msi/buildrelease.bat
# Python-3.10.12/Tools/msi/wix.props
# Python-3.10.12/Tools/msi/make_appx.ps1
# Python-3.10.12/Tools/msi/testrelease.bat
# Python-3.10.12/Tools/msi/get_externals.bat
# Python-3.10.12/Tools/msi/purge.py
# Python-3.10.12/Tools/msi/tools/
# Python-3.10.12/Tools/msi/tools/tools.wixproj
# Python-3.10.12/Tools/msi/tools/tools_en-US.wxl
# Python-3.10.12/Tools/msi/tools/tools.wxs
# Python-3.10.12/Tools/msi/tools/tools_files.wxs
# Python-3.10.12/Tools/scripts/
# Python-3.10.12/Tools/scripts/pickle2db.py
# Python-3.10.12/Tools/scripts/nm2def.py
# Python-3.10.12/Tools/scripts/import_diagnostics.py
# Python-3.10.12/Tools/scripts/dutree.py
# Python-3.10.12/Tools/scripts/highlight.py
# Python-3.10.12/Tools/scripts/README
# Python-3.10.12/Tools/scripts/untabify.py
# Python-3.10.12/Tools/scripts/gprof2html.py
# Python-3.10.12/Tools/scripts/verify_ensurepip_wheels.py
# Python-3.10.12/Tools/scripts/suff.py
# Python-3.10.12/Tools/scripts/db2pickle.py
# Python-3.10.12/Tools/scripts/fixnotice.py
# Python-3.10.12/Tools/scripts/pep384_macrocheck.py
# Python-3.10.12/Tools/scripts/parseentities.py
# Python-3.10.12/Tools/scripts/fixps.py
# Python-3.10.12/Tools/scripts/fixdiv.py
# Python-3.10.12/Tools/scripts/checkpip.py
# Python-3.10.12/Tools/scripts/finddiv.py
# Python-3.10.12/Tools/scripts/ifdef.py
# Python-3.10.12/Tools/scripts/lfcr.py
# Python-3.10.12/Tools/scripts/texi2html.py
# Python-3.10.12/Tools/scripts/pdeps.py
# Python-3.10.12/Tools/scripts/findlinksto.py
# Python-3.10.12/Tools/scripts/md5sum.py
# Python-3.10.12/Tools/scripts/pysource.py
# Python-3.10.12/Tools/scripts/find_recursionlimit.py
# Python-3.10.12/Tools/scripts/lll.py
# Python-3.10.12/Tools/scripts/get-remote-certificate.py
# Python-3.10.12/Tools/scripts/generate_token.py
# Python-3.10.12/Tools/scripts/fixcid.py
# Python-3.10.12/Tools/scripts/pydoc3
# Python-3.10.12/Tools/scripts/reindent-rst.py
# Python-3.10.12/Tools/scripts/eptags.py
# Python-3.10.12/Tools/scripts/ndiff.py
# Python-3.10.12/Tools/scripts/ptags.py
# Python-3.10.12/Tools/scripts/generate_stdlib_module_names.py
# Python-3.10.12/Tools/scripts/findnocoding.py
# Python-3.10.12/Tools/scripts/abitype.py
# Python-3.10.12/Tools/scripts/generate_opcode_h.py
# Python-3.10.12/Tools/scripts/combinerefs.py
# Python-3.10.12/Tools/scripts/pathfix.py
# Python-3.10.12/Tools/scripts/diff.py
# Python-3.10.12/Tools/scripts/mailerdaemon.py
# Python-3.10.12/Tools/scripts/patchcheck.py
# Python-3.10.12/Tools/scripts/idle3
# Python-3.10.12/Tools/scripts/crlf.py
# Python-3.10.12/Tools/scripts/cleanfuture.py
# Python-3.10.12/Tools/scripts/byext.py
# Python-3.10.12/Tools/scripts/copytime.py
# Python-3.10.12/Tools/scripts/2to3
# Python-3.10.12/Tools/scripts/parse_html5_entities.py
# Python-3.10.12/Tools/scripts/update_file.py
# Python-3.10.12/Tools/scripts/make_ctype.py
# Python-3.10.12/Tools/scripts/stable_abi.py
# Python-3.10.12/Tools/scripts/byteyears.py
# Python-3.10.12/Tools/scripts/google.py
# Python-3.10.12/Tools/scripts/reindent.py
# Python-3.10.12/Tools/scripts/win_add2path.py
# Python-3.10.12/Tools/scripts/smelly.py
# Python-3.10.12/Tools/scripts/rgrep.py
# Python-3.10.12/Tools/scripts/run_tests.py
# Python-3.10.12/Tools/scripts/serve.py
# Python-3.10.12/Tools/scripts/find-uname.py
# Python-3.10.12/Tools/scripts/analyze_dxp.py
# Python-3.10.12/Tools/scripts/linktree.py
# Python-3.10.12/Tools/scripts/var_access_benchmark.py
# Python-3.10.12/Tools/scripts/mkreal.py
# Python-3.10.12/Tools/scripts/objgraph.py
# Python-3.10.12/Tools/scripts/pindent.py
# Python-3.10.12/Tools/scripts/dutree.doc
# Python-3.10.12/Tools/scripts/which.py
# Python-3.10.12/Tools/scripts/fixheader.py
# Python-3.10.12/Tools/i18n/
# Python-3.10.12/Tools/i18n/msgfmt.py
# Python-3.10.12/Tools/i18n/pygettext.py
# Python-3.10.12/Tools/i18n/makelocalealias.py
# Python-3.10.12/Tools/iobench/
# Python-3.10.12/Tools/iobench/iobench.py
# Python-3.10.12/Tools/c-analyzer/
# Python-3.10.12/Tools/c-analyzer/cpython/
# Python-3.10.12/Tools/c-analyzer/cpython/_capi.py
# Python-3.10.12/Tools/c-analyzer/cpython/_analyzer.py
# Python-3.10.12/Tools/c-analyzer/cpython/known.tsv
# Python-3.10.12/Tools/c-analyzer/cpython/_files.py
# Python-3.10.12/Tools/c-analyzer/cpython/__main__.py
# Python-3.10.12/Tools/c-analyzer/cpython/ignored.tsv
# Python-3.10.12/Tools/c-analyzer/cpython/__init__.py
# Python-3.10.12/Tools/c-analyzer/cpython/_parser.py
# Python-3.10.12/Tools/c-analyzer/c_parser/
# Python-3.10.12/Tools/c-analyzer/c_parser/match.py
# Python-3.10.12/Tools/c-analyzer/c_parser/_state_machine.py
# Python-3.10.12/Tools/c-analyzer/c_parser/info.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_regexes.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_global.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_common.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_info.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_func_body.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/__init__.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_compound_decl_body.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_alt.py
# Python-3.10.12/Tools/c-analyzer/c_parser/parser/_delim.py
# Python-3.10.12/Tools/c-analyzer/c_parser/source.py
# Python-3.10.12/Tools/c-analyzer/c_parser/__main__.py
# Python-3.10.12/Tools/c-analyzer/c_parser/__init__.py
# Python-3.10.12/Tools/c-analyzer/c_parser/datafiles.py
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/common.py
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/__main__.py
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/errors.py
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/__init__.py
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/gcc.py
# Python-3.10.12/Tools/c-analyzer/c_parser/preprocessor/pure.py
# Python-3.10.12/Tools/c-analyzer/README
# Python-3.10.12/Tools/c-analyzer/TODO
# Python-3.10.12/Tools/c-analyzer/c_analyzer/
# Python-3.10.12/Tools/c-analyzer/c_analyzer/match.py
# Python-3.10.12/Tools/c-analyzer/c_analyzer/info.py
# Python-3.10.12/Tools/c-analyzer/c_analyzer/__main__.py
# Python-3.10.12/Tools/c-analyzer/c_analyzer/analyze.py
# Python-3.10.12/Tools/c-analyzer/c_analyzer/__init__.py
# Python-3.10.12/Tools/c-analyzer/c_analyzer/datafiles.py
# Python-3.10.12/Tools/c-analyzer/check-c-globals.py
# Python-3.10.12/Tools/c-analyzer/must-resolve.sh
# Python-3.10.12/Tools/c-analyzer/c_common/
# Python-3.10.12/Tools/c-analyzer/c_common/iterutil.py
# Python-3.10.12/Tools/c-analyzer/c_common/scriptutil.py
# Python-3.10.12/Tools/c-analyzer/c_common/info.py
# Python-3.10.12/Tools/c-analyzer/c_common/misc.py
# Python-3.10.12/Tools/c-analyzer/c_common/clsutil.py
# Python-3.10.12/Tools/c-analyzer/c_common/tables.py
# Python-3.10.12/Tools/c-analyzer/c_common/__init__.py
# Python-3.10.12/Tools/c-analyzer/c_common/fsutil.py
# Python-3.10.12/Tools/c-analyzer/c_common/logging.py
# Python-3.10.12/Tools/c-analyzer/c_common/show.py
# Python-3.10.12/Tools/c-analyzer/c_common/strutil.py
# Python-3.10.12/Tools/c-analyzer/c-analyzer.py
# Python-3.10.12/Tools/demo/
# Python-3.10.12/Tools/demo/queens.py
# Python-3.10.12/Tools/demo/rpythond.py
# Python-3.10.12/Tools/demo/eiffel.py
# Python-3.10.12/Tools/demo/README
# Python-3.10.12/Tools/demo/redemo.py
# Python-3.10.12/Tools/demo/spreadsheet.py
# Python-3.10.12/Tools/demo/vector.py
# Python-3.10.12/Tools/demo/sortvisu.py
# Python-3.10.12/Tools/demo/life.py
# Python-3.10.12/Tools/demo/rpython.py
# Python-3.10.12/Tools/demo/mcast.py
# Python-3.10.12/Tools/demo/beer.py
# Python-3.10.12/Tools/demo/hanoi.py
# Python-3.10.12/Tools/demo/markov.py
# Python-3.10.12/Tools/ssl/
# Python-3.10.12/Tools/ssl/make_ssl_data.py
# Python-3.10.12/Tools/ssl/multissltests.py
# Python-3.10.12/Tools/unicode/
# Python-3.10.12/Tools/unicode/genwincodec.py
# Python-3.10.12/Tools/unicode/python-mappings/
# Python-3.10.12/Tools/unicode/python-mappings/CP1140.TXT
# Python-3.10.12/Tools/unicode/python-mappings/GB2312.TXT
# Python-3.10.12/Tools/unicode/python-mappings/diff/
# Python-3.10.12/Tools/unicode/python-mappings/diff/jisx0213-2000-std.txt.diff
# Python-3.10.12/Tools/unicode/python-mappings/diff/jisx0213-2004-std.txt.diff
# Python-3.10.12/Tools/unicode/python-mappings/CP273.TXT
# Python-3.10.12/Tools/unicode/python-mappings/KOI8-U.TXT
# Python-3.10.12/Tools/unicode/python-mappings/jisx0213-2004-std.txt
# Python-3.10.12/Tools/unicode/python-mappings/TIS-620.TXT
# Python-3.10.12/Tools/unicode/python-mappings/gb-18030-2000.xml
# Python-3.10.12/Tools/unicode/genmap_schinese.py
# Python-3.10.12/Tools/unicode/gencjkcodecs.py
# Python-3.10.12/Tools/unicode/mkstringprep.py
# Python-3.10.12/Tools/unicode/genwincodecs.bat
# Python-3.10.12/Tools/unicode/gencodec.py
# Python-3.10.12/Tools/unicode/genmap_japanese.py
# Python-3.10.12/Tools/unicode/genmap_support.py
# Python-3.10.12/Tools/unicode/comparecodecs.py
# Python-3.10.12/Tools/unicode/Makefile
# Python-3.10.12/Tools/unicode/genmap_korean.py
# Python-3.10.12/Tools/unicode/listcodecs.py
# Python-3.10.12/Tools/unicode/makeunicodedata.py
# Python-3.10.12/Tools/unittestgui/
# Python-3.10.12/Tools/unittestgui/README.txt
# Python-3.10.12/Tools/unittestgui/unittestgui.py
# Python-3.10.12/Tools/buildbot/
# Python-3.10.12/Tools/buildbot/build.bat
# Python-3.10.12/Tools/buildbot/test.bat
# Python-3.10.12/Tools/buildbot/buildmsi.bat
# Python-3.10.12/Tools/buildbot/remoteDeploy.bat
# Python-3.10.12/Tools/buildbot/clean.bat
# Python-3.10.12/Tools/buildbot/remotePythonInfo.bat
# Python-3.10.12/Tools/stringbench/
# Python-3.10.12/Tools/stringbench/README
# Python-3.10.12/Tools/stringbench/stringbench.py
# Python-3.10.12/Tools/gdb/
# Python-3.10.12/Tools/gdb/libpython.py
# Python-3.10.12/Include/
# Python-3.10.12/Include/pystate.h
# Python-3.10.12/Include/datetime.h
# Python-3.10.12/Include/namespaceobject.h
# Python-3.10.12/Include/cpython/
# Python-3.10.12/Include/cpython/pystate.h
# Python-3.10.12/Include/cpython/pyerrors.h
# Python-3.10.12/Include/cpython/pytime.h
# Python-3.10.12/Include/cpython/traceback.h
# Python-3.10.12/Include/cpython/listobject.h
# Python-3.10.12/Include/cpython/fileobject.h
# Python-3.10.12/Include/cpython/compile.h
# Python-3.10.12/Include/cpython/ceval.h
# Python-3.10.12/Include/cpython/pyctype.h
# Python-3.10.12/Include/cpython/interpreteridobject.h
# Python-3.10.12/Include/cpython/object.h
# Python-3.10.12/Include/cpython/dictobject.h
# Python-3.10.12/Include/cpython/bytearrayobject.h
# Python-3.10.12/Include/cpython/pythonrun.h
# Python-3.10.12/Include/cpython/fileutils.h
# Python-3.10.12/Include/cpython/sysmodule.h
# Python-3.10.12/Include/cpython/pyfpe.h
# Python-3.10.12/Include/cpython/import.h
# Python-3.10.12/Include/cpython/odictobject.h
# Python-3.10.12/Include/cpython/frameobject.h
# Python-3.10.12/Include/cpython/initconfig.h
# Python-3.10.12/Include/cpython/unicodeobject.h
# Python-3.10.12/Include/cpython/pymem.h
# Python-3.10.12/Include/cpython/abstract.h
# Python-3.10.12/Include/cpython/objimpl.h
# Python-3.10.12/Include/cpython/methodobject.h
# Python-3.10.12/Include/cpython/tupleobject.h
# Python-3.10.12/Include/cpython/bytesobject.h
# Python-3.10.12/Include/cpython/pydebug.h
# Python-3.10.12/Include/cpython/code.h
# Python-3.10.12/Include/cpython/picklebufobject.h
# Python-3.10.12/Include/cpython/pylifecycle.h
# Python-3.10.12/Include/pystrhex.h
# Python-3.10.12/Include/pyerrors.h
# Python-3.10.12/Include/traceback.h
# Python-3.10.12/Include/listobject.h
# Python-3.10.12/Include/fileobject.h
# Python-3.10.12/Include/longintrepr.h
# Python-3.10.12/Include/README.rst
# Python-3.10.12/Include/osmodule.h
# Python-3.10.12/Include/marshal.h
# Python-3.10.12/Include/pyexpat.h
# Python-3.10.12/Include/compile.h
# Python-3.10.12/Include/sliceobject.h
# Python-3.10.12/Include/pyhash.h
# Python-3.10.12/Include/ceval.h
# Python-3.10.12/Include/codecs.h
# Python-3.10.12/Include/funcobject.h
# Python-3.10.12/Include/pythread.h
# Python-3.10.12/Include/structmember.h
# Python-3.10.12/Include/descrobject.h
# Python-3.10.12/Include/interpreteridobject.h
# Python-3.10.12/Include/object.h
# Python-3.10.12/Include/dictobject.h
# Python-3.10.12/Include/bytearrayobject.h
# Python-3.10.12/Include/pymacconfig.h
# Python-3.10.12/Include/weakrefobject.h
# Python-3.10.12/Include/pythonrun.h
# Python-3.10.12/Include/longobject.h
# Python-3.10.12/Include/pycapsule.h
# Python-3.10.12/Include/context.h
# Python-3.10.12/Include/pydtrace.d
# Python-3.10.12/Include/intrcheck.h
# Python-3.10.12/Include/enumobject.h
# Python-3.10.12/Include/pymacro.h
# Python-3.10.12/Include/fileutils.h
# Python-3.10.12/Include/typeslots.h
# Python-3.10.12/Include/pydtrace.h
# Python-3.10.12/Include/errcode.h
# Python-3.10.12/Include/structseq.h
# Python-3.10.12/Include/sysmodule.h
# Python-3.10.12/Include/osdefs.h
# Python-3.10.12/Include/pyport.h
# Python-3.10.12/Include/genobject.h
# Python-3.10.12/Include/import.h
# Python-3.10.12/Include/pystrcmp.h
# Python-3.10.12/Include/cellobject.h
# Python-3.10.12/Include/frameobject.h
# Python-3.10.12/Include/warnings.h
# Python-3.10.12/Include/patchlevel.h
# Python-3.10.12/Include/unicodeobject.h
# Python-3.10.12/Include/pymath.h
# Python-3.10.12/Include/rangeobject.h
# Python-3.10.12/Include/floatobject.h
# Python-3.10.12/Include/moduleobject.h
# Python-3.10.12/Include/py_curses.h
# Python-3.10.12/Include/pyframe.h
# Python-3.10.12/Include/pymem.h
# Python-3.10.12/Include/abstract.h
# Python-3.10.12/Include/boolobject.h
# Python-3.10.12/Include/setobject.h
# Python-3.10.12/Include/complexobject.h
# Python-3.10.12/Include/iterobject.h
# Python-3.10.12/Include/objimpl.h
# Python-3.10.12/Include/eval.h
# Python-3.10.12/Include/exports.h
# Python-3.10.12/Include/methodobject.h
# Python-3.10.12/Include/dynamic_annotations.h
# Python-3.10.12/Include/tupleobject.h
# Python-3.10.12/Include/tracemalloc.h
# Python-3.10.12/Include/bytesobject.h
# Python-3.10.12/Include/opcode.h
# Python-3.10.12/Include/internal/
# Python-3.10.12/Include/internal/pycore_context.h
# Python-3.10.12/Include/internal/pycore_sysmodule.h
# Python-3.10.12/Include/internal/pycore_pymem.h
# Python-3.10.12/Include/internal/pycore_bytes_methods.h
# Python-3.10.12/Include/internal/pycore_hashtable.h
# Python-3.10.12/Include/internal/pycore_pyarena.h
# Python-3.10.12/Include/internal/pycore_pathconfig.h
# Python-3.10.12/Include/internal/pycore_call.h
# Python-3.10.12/Include/internal/pycore_atomic.h
# Python-3.10.12/Include/internal/pycore_pyerrors.h
# Python-3.10.12/Include/internal/pycore_condvar.h
# Python-3.10.12/Include/internal/pycore_import.h
# Python-3.10.12/Include/internal/pycore_abstract.h
# Python-3.10.12/Include/internal/pycore_traceback.h
# Python-3.10.12/Include/internal/pycore_compile.h
# Python-3.10.12/Include/internal/pycore_ceval.h
# Python-3.10.12/Include/internal/pycore_symtable.h
# Python-3.10.12/Include/internal/pycore_long.h
# Python-3.10.12/Include/internal/pycore_tuple.h
# Python-3.10.12/Include/internal/pycore_asdl.h
# Python-3.10.12/Include/internal/pycore_code.h
# Python-3.10.12/Include/internal/pycore_accu.h
# Python-3.10.12/Include/internal/pycore_list.h
# Python-3.10.12/Include/internal/pycore_format.h
# Python-3.10.12/Include/internal/pycore_structseq.h
# Python-3.10.12/Include/internal/pycore_parser.h
# Python-3.10.12/Include/internal/pycore_gc.h
# Python-3.10.12/Include/internal/pycore_blocks_output_buffer.h
# Python-3.10.12/Include/internal/pycore_object.h
# Python-3.10.12/Include/internal/pycore_hamt.h
# Python-3.10.12/Include/internal/pycore_pyhash.h
# Python-3.10.12/Include/internal/pycore_getopt.h
# Python-3.10.12/Include/internal/pycore_pylifecycle.h
# Python-3.10.12/Include/internal/pycore_pystate.h
# Python-3.10.12/Include/internal/pycore_ucnhash.h
# Python-3.10.12/Include/internal/pycore_ast_state.h
# Python-3.10.12/Include/internal/pycore_unionobject.h
# Python-3.10.12/Include/internal/pycore_ast.h
# Python-3.10.12/Include/internal/pycore_dtoa.h
# Python-3.10.12/Include/internal/pycore_runtime.h
# Python-3.10.12/Include/internal/pycore_bitutils.h
# Python-3.10.12/Include/internal/pycore_initconfig.h
# Python-3.10.12/Include/internal/pycore_fileutils.h
# Python-3.10.12/Include/internal/pycore_interp.h
# Python-3.10.12/Include/internal/pycore_gil.h
# Python-3.10.12/Include/internal/pycore_atomic_funcs.h
# Python-3.10.12/Include/internal/pycore_moduleobject.h
# Python-3.10.12/Include/internal/pycore_warnings.h
# Python-3.10.12/Include/code.h
# Python-3.10.12/Include/Python.h
# Python-3.10.12/Include/memoryobject.h
# Python-3.10.12/Include/genericaliasobject.h
# Python-3.10.12/Include/classobject.h
# Python-3.10.12/Include/token.h
# Python-3.10.12/Include/pystrtod.h
# Python-3.10.12/Include/bltinmodule.h
# Python-3.10.12/Include/modsupport.h
# Python-3.10.12/Include/pylifecycle.h
# Python-3.10.12/Modules/
# Python-3.10.12/Modules/readline.c
# Python-3.10.12/Modules/selectmodule.c
# Python-3.10.12/Modules/clinic/
# Python-3.10.12/Modules/clinic/_testclinic.c.h
# Python-3.10.12/Modules/clinic/_contextvarsmodule.c.h
# Python-3.10.12/Modules/clinic/_weakref.c.h
# Python-3.10.12/Modules/clinic/itertoolsmodule.c.h
# Python-3.10.12/Modules/clinic/_opcode.c.h
# Python-3.10.12/Modules/clinic/readline.c.h
# Python-3.10.12/Modules/clinic/gcmodule.c.h
# Python-3.10.12/Modules/clinic/_tracemalloc.c.h
# Python-3.10.12/Modules/clinic/sha1module.c.h
# Python-3.10.12/Modules/clinic/md5module.c.h
# Python-3.10.12/Modules/clinic/_queuemodule.c.h
# Python-3.10.12/Modules/clinic/pyexpat.c.h
# Python-3.10.12/Modules/clinic/_asynciomodule.c.h
# Python-3.10.12/Modules/clinic/_lzmamodule.c.h
# Python-3.10.12/Modules/clinic/_operator.c.h
# Python-3.10.12/Modules/clinic/mathmodule.c.h
# Python-3.10.12/Modules/clinic/unicodedata.c.h
# Python-3.10.12/Modules/clinic/_gdbmmodule.c.h
# Python-3.10.12/Modules/clinic/resource.c.h
# Python-3.10.12/Modules/clinic/_lsprof.c.h
# Python-3.10.12/Modules/clinic/_collectionsmodule.c.h
# Python-3.10.12/Modules/clinic/_bisectmodule.c.h
# Python-3.10.12/Modules/clinic/overlapped.c.h
# Python-3.10.12/Modules/clinic/termios.c.h
# Python-3.10.12/Modules/clinic/_bz2module.c.h
# Python-3.10.12/Modules/clinic/_winapi.c.h
# Python-3.10.12/Modules/clinic/audioop.c.h
# Python-3.10.12/Modules/clinic/_testmultiphase.c.h
# Python-3.10.12/Modules/clinic/spwdmodule.c.h
# Python-3.10.12/Modules/clinic/_cursesmodule.c.h
# Python-3.10.12/Modules/clinic/_struct.c.h
# Python-3.10.12/Modules/clinic/_elementtree.c.h
# Python-3.10.12/Modules/clinic/signalmodule.c.h
# Python-3.10.12/Modules/clinic/_randommodule.c.h
# Python-3.10.12/Modules/clinic/_dbmmodule.c.h
# Python-3.10.12/Modules/clinic/binascii.c.h
# Python-3.10.12/Modules/clinic/_heapqmodule.c.h
# Python-3.10.12/Modules/clinic/_codecsmodule.c.h
# Python-3.10.12/Modules/clinic/_hashopenssl.c.h
# Python-3.10.12/Modules/clinic/_curses_panel.c.h
# Python-3.10.12/Modules/clinic/_cryptmodule.c.h
# Python-3.10.12/Modules/clinic/symtablemodule.c.h
# Python-3.10.12/Modules/clinic/_tkinter.c.h
# Python-3.10.12/Modules/clinic/arraymodule.c.h
# Python-3.10.12/Modules/clinic/_ssl.c.h
# Python-3.10.12/Modules/clinic/grpmodule.c.h
# Python-3.10.12/Modules/clinic/_sre.c.h
# Python-3.10.12/Modules/clinic/sha256module.c.h
# Python-3.10.12/Modules/clinic/posixmodule.c.h
# Python-3.10.12/Modules/clinic/sha512module.c.h
# Python-3.10.12/Modules/clinic/_datetimemodule.c.h
# Python-3.10.12/Modules/clinic/fcntlmodule.c.h
# Python-3.10.12/Modules/clinic/_pickle.c.h
# Python-3.10.12/Modules/clinic/_localemodule.c.h
# Python-3.10.12/Modules/clinic/selectmodule.c.h
# Python-3.10.12/Modules/clinic/cmathmodule.c.h
# Python-3.10.12/Modules/clinic/_statisticsmodule.c.h
# Python-3.10.12/Modules/clinic/_abc.c.h
# Python-3.10.12/Modules/clinic/zlibmodule.c.h
# Python-3.10.12/Modules/clinic/pwdmodule.c.h
# Python-3.10.12/Modules/binascii.c
# Python-3.10.12/Modules/makesetup
# Python-3.10.12/Modules/errnomodule.c
# Python-3.10.12/Modules/_bz2module.c
# Python-3.10.12/Modules/_collectionsmodule.c
# Python-3.10.12/Modules/_posixsubprocess.c
# Python-3.10.12/Modules/_asynciomodule.c
# Python-3.10.12/Modules/_contextvarsmodule.c
# Python-3.10.12/Modules/_operator.c
# Python-3.10.12/Modules/pyexpat.c
# Python-3.10.12/Modules/_threadmodule.c
# Python-3.10.12/Modules/xxsubtype.c
# Python-3.10.12/Modules/socketmodule.h
# Python-3.10.12/Modules/mathmodule.c
# Python-3.10.12/Modules/sha1module.c
# Python-3.10.12/Modules/_testclinic.c
# Python-3.10.12/Modules/README
# Python-3.10.12/Modules/_testmultiphase.c
# Python-3.10.12/Modules/_json.c
# Python-3.10.12/Modules/_codecsmodule.c
# Python-3.10.12/Modules/rotatingtree.h
# Python-3.10.12/Modules/socketmodule.c
# Python-3.10.12/Modules/ossaudiodev.c
# Python-3.10.12/Modules/_bisectmodule.c
# Python-3.10.12/Modules/_lsprof.c
# Python-3.10.12/Modules/_tkinter.c
# Python-3.10.12/Modules/nismodule.c
# Python-3.10.12/Modules/_cryptmodule.c
# Python-3.10.12/Modules/itertoolsmodule.c
# Python-3.10.12/Modules/_pickle.c
# Python-3.10.12/Modules/signalmodule.c
# Python-3.10.12/Modules/_ssl_data_111.h
# Python-3.10.12/Modules/config.c.in
# Python-3.10.12/Modules/_decimal/
# Python-3.10.12/Modules/_decimal/libmpdec/
# Python-3.10.12/Modules/_decimal/libmpdec/literature/
# Python-3.10.12/Modules/_decimal/libmpdec/literature/matrix-transform.txt
# Python-3.10.12/Modules/_decimal/libmpdec/literature/six-step.txt
# Python-3.10.12/Modules/_decimal/libmpdec/literature/umodarith.lisp
# Python-3.10.12/Modules/_decimal/libmpdec/literature/fnt.py
# Python-3.10.12/Modules/_decimal/libmpdec/literature/bignum.txt
# Python-3.10.12/Modules/_decimal/libmpdec/literature/mulmod-ppro.txt
# Python-3.10.12/Modules/_decimal/libmpdec/literature/REFERENCES.txt
# Python-3.10.12/Modules/_decimal/libmpdec/literature/mulmod-64.txt
# Python-3.10.12/Modules/_decimal/libmpdec/constants.c
# Python-3.10.12/Modules/_decimal/libmpdec/sixstep.h
# Python-3.10.12/Modules/_decimal/libmpdec/crt.c
# Python-3.10.12/Modules/_decimal/libmpdec/fnt.h
# Python-3.10.12/Modules/_decimal/libmpdec/convolute.c
# Python-3.10.12/Modules/_decimal/libmpdec/io.h
# Python-3.10.12/Modules/_decimal/libmpdec/transpose.c
# Python-3.10.12/Modules/_decimal/libmpdec/bench_full.c
# Python-3.10.12/Modules/_decimal/libmpdec/context.c
# Python-3.10.12/Modules/_decimal/libmpdec/difradix2.c
# Python-3.10.12/Modules/_decimal/libmpdec/vcdiv64.asm
# Python-3.10.12/Modules/_decimal/libmpdec/README.txt
# Python-3.10.12/Modules/_decimal/libmpdec/fourstep.c
# Python-3.10.12/Modules/_decimal/libmpdec/constants.h
# Python-3.10.12/Modules/_decimal/libmpdec/typearith.h
# Python-3.10.12/Modules/_decimal/libmpdec/transpose.h
# Python-3.10.12/Modules/_decimal/libmpdec/bench.c
# Python-3.10.12/Modules/_decimal/libmpdec/fnt.c
# Python-3.10.12/Modules/_decimal/libmpdec/basearith.c
# Python-3.10.12/Modules/_decimal/libmpdec/mpalloc.h
# Python-3.10.12/Modules/_decimal/libmpdec/convolute.h
# Python-3.10.12/Modules/_decimal/libmpdec/mpsignal.c
# Python-3.10.12/Modules/_decimal/libmpdec/basearith.h
# Python-3.10.12/Modules/_decimal/libmpdec/numbertheory.h
# Python-3.10.12/Modules/_decimal/libmpdec/fourstep.h
# Python-3.10.12/Modules/_decimal/libmpdec/crt.h
# Python-3.10.12/Modules/_decimal/libmpdec/mpdecimal.c
# Python-3.10.12/Modules/_decimal/libmpdec/numbertheory.c
# Python-3.10.12/Modules/_decimal/libmpdec/umodarith.h
# Python-3.10.12/Modules/_decimal/libmpdec/io.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/
# Python-3.10.12/Modules/_decimal/libmpdec/examples/shift.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/pow.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/sqrt.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/div.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/powmod.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/multiply.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/README.txt
# Python-3.10.12/Modules/_decimal/libmpdec/examples/compare.c
# Python-3.10.12/Modules/_decimal/libmpdec/examples/divmod.c
# Python-3.10.12/Modules/_decimal/libmpdec/bits.h
# Python-3.10.12/Modules/_decimal/libmpdec/mpalloc.c
# Python-3.10.12/Modules/_decimal/libmpdec/difradix2.h
# Python-3.10.12/Modules/_decimal/libmpdec/sixstep.c
# Python-3.10.12/Modules/_decimal/libmpdec/mpdecimal.h
# Python-3.10.12/Modules/_decimal/README.txt
# Python-3.10.12/Modules/_decimal/_decimal.c
# Python-3.10.12/Modules/_decimal/tests/
# Python-3.10.12/Modules/_decimal/tests/deccheck.py
# Python-3.10.12/Modules/_decimal/tests/runall-memorydebugger.sh
# Python-3.10.12/Modules/_decimal/tests/runall.bat
# Python-3.10.12/Modules/_decimal/tests/README.txt
# Python-3.10.12/Modules/_decimal/tests/bench.py
# Python-3.10.12/Modules/_decimal/tests/bignum.py
# Python-3.10.12/Modules/_decimal/tests/randfloat.py
# Python-3.10.12/Modules/_decimal/tests/randdec.py
# Python-3.10.12/Modules/_decimal/tests/formathelper.py
# Python-3.10.12/Modules/_decimal/docstrings.h
# Python-3.10.12/Modules/md5module.c
# Python-3.10.12/Modules/sha512module.c
# Python-3.10.12/Modules/_ctypes/
# Python-3.10.12/Modules/_ctypes/darwin/
# Python-3.10.12/Modules/_ctypes/darwin/README.ctypes
# Python-3.10.12/Modules/_ctypes/darwin/README
# Python-3.10.12/Modules/_ctypes/darwin/dlfcn.h
# Python-3.10.12/Modules/_ctypes/darwin/dlfcn_simple.c
# Python-3.10.12/Modules/_ctypes/darwin/LICENSE
# Python-3.10.12/Modules/_ctypes/libffi_osx/
# Python-3.10.12/Modules/_ctypes/libffi_osx/README
# Python-3.10.12/Modules/_ctypes/libffi_osx/x86/
# Python-3.10.12/Modules/_ctypes/libffi_osx/x86/darwin64.S
# Python-3.10.12/Modules/_ctypes/libffi_osx/x86/x86-ffi_darwin.c
# Python-3.10.12/Modules/_ctypes/libffi_osx/x86/x86-ffi64.c
# Python-3.10.12/Modules/_ctypes/libffi_osx/x86/x86-darwin.S
# Python-3.10.12/Modules/_ctypes/libffi_osx/README.pyobjc
# Python-3.10.12/Modules/_ctypes/libffi_osx/ffi.c
# Python-3.10.12/Modules/_ctypes/libffi_osx/powerpc/
# Python-3.10.12/Modules/_ctypes/libffi_osx/powerpc/ppc-darwin_closure.S
# Python-3.10.12/Modules/_ctypes/libffi_osx/powerpc/ppc-darwin.S
# Python-3.10.12/Modules/_ctypes/libffi_osx/powerpc/ppc-ffi_darwin.c
# Python-3.10.12/Modules/_ctypes/libffi_osx/powerpc/ppc-darwin.h
# Python-3.10.12/Modules/_ctypes/libffi_osx/powerpc/ppc64-darwin_closure.S
# Python-3.10.12/Modules/_ctypes/libffi_osx/LICENSE
# Python-3.10.12/Modules/_ctypes/libffi_osx/types.c
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/ffi_common.h
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/ffi.h
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/fficonfig.h
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/x86-ffitarget.h
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/ppc-ffitarget.h
# Python-3.10.12/Modules/_ctypes/libffi_osx/include/ffitarget.h
# Python-3.10.12/Modules/_ctypes/callbacks.c
# Python-3.10.12/Modules/_ctypes/ctypes_dlfcn.h
# Python-3.10.12/Modules/_ctypes/malloc_closure.c
# Python-3.10.12/Modules/_ctypes/callproc.c
# Python-3.10.12/Modules/_ctypes/_ctypes.c
# Python-3.10.12/Modules/_ctypes/stgdict.c
# Python-3.10.12/Modules/_ctypes/_ctypes_test.h
# Python-3.10.12/Modules/_ctypes/_ctypes_test.c
# Python-3.10.12/Modules/_ctypes/cfield.c
# Python-3.10.12/Modules/_ctypes/ctypes.h
# Python-3.10.12/Modules/_ssl.c
# Python-3.10.12/Modules/_csv.c
# Python-3.10.12/Modules/getbuildinfo.c
# Python-3.10.12/Modules/atexitmodule.c
# Python-3.10.12/Modules/_curses_panel.c
# Python-3.10.12/Modules/gcmodule.c
# Python-3.10.12/Modules/_xxsubinterpretersmodule.c
# Python-3.10.12/Modules/_opcode.c
# Python-3.10.12/Modules/_xxtestfuzz/
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/empty_array.json
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/pass3.json
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/empty_object.json
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/pass1.json
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/pass2.json
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_json_loads_corpus/simple_array.json
# Python-3.10.12/Modules/_xxtestfuzz/README.rst
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_sre_compile_corpus/
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_sre_compile_corpus/anchor_links
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_sre_compile_corpus/characters
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_sre_compile_corpus/phone_number
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_sre_compile_corpus/isbn
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_tests.txt
# Python-3.10.12/Modules/_xxtestfuzz/fuzzer.c
# Python-3.10.12/Modules/_xxtestfuzz/_xxtestfuzz.c
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_struct_unpack_corpus/
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_struct_unpack_corpus/varied_format_string
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_struct_unpack_corpus/long_zero
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_struct_unpack_corpus/hello_string
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_csv_reader_corpus/
# Python-3.10.12/Modules/_xxtestfuzz/fuzz_csv_reader_corpus/test.csv
# Python-3.10.12/Modules/_xxtestfuzz/dictionaries/
# Python-3.10.12/Modules/_xxtestfuzz/dictionaries/fuzz_sre_compile.dict
# Python-3.10.12/Modules/_xxtestfuzz/dictionaries/fuzz_json_loads.dict
# Python-3.10.12/Modules/_queuemodule.c
# Python-3.10.12/Modules/ld_so_aix.in
# Python-3.10.12/Modules/_sha3/
# Python-3.10.12/Modules/_sha3/clinic/
# Python-3.10.12/Modules/_sha3/clinic/sha3module.c.h
# Python-3.10.12/Modules/_sha3/sha3module.c
# Python-3.10.12/Modules/_sha3/README.txt
# Python-3.10.12/Modules/_sha3/kcp/
# Python-3.10.12/Modules/_sha3/kcp/SnP-Relaned.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-SnP.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-opt64.c
# Python-3.10.12/Modules/_sha3/kcp/KeccakHash.c
# Python-3.10.12/Modules/_sha3/kcp/PlSnP-Fallback.inc
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-unrolling.macros
# Python-3.10.12/Modules/_sha3/kcp/KeccakSponge.c
# Python-3.10.12/Modules/_sha3/kcp/align.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-opt64-config.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakSponge.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-64.macros
# Python-3.10.12/Modules/_sha3/kcp/KeccakHash.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-SnP-opt64.h
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-inplace32BI.c
# Python-3.10.12/Modules/_sha3/kcp/KeccakSponge.inc
# Python-3.10.12/Modules/_sha3/kcp/KeccakP-1600-SnP-opt32.h
# Python-3.10.12/Modules/_sha3/cleanup.py
# Python-3.10.12/Modules/getaddrinfo.c
# Python-3.10.12/Modules/_abc.c
# Python-3.10.12/Modules/_hashopenssl.c
# Python-3.10.12/Modules/sre.h
# Python-3.10.12/Modules/_elementtree.c
# Python-3.10.12/Modules/_functoolsmodule.c
# ...
# Python-3.10.12/Lib/unittest/test/testmock/testwith.py
# Python-3.10.12/Lib/unittest/test/testmock/support.py
# Python-3.10.12/Lib/unittest/test/testmock/testsealable.py
# Python-3.10.12/Lib/unittest/test/testmock/testhelpers.py
# Python-3.10.12/Lib/unittest/test/testmock/testcallable.py
# Python-3.10.12/Lib/unittest/test/testmock/__main__.py
# Python-3.10.12/Lib/unittest/test/testmock/testasync.py
# Python-3.10.12/Lib/unittest/test/testmock/testmock.py
# Python-3.10.12/Lib/unittest/test/testmock/testsentinel.py
# Python-3.10.12/Lib/unittest/test/testmock/__init__.py
# Python-3.10.12/Lib/unittest/test/testmock/testmagicmethods.py
# Python-3.10.12/Lib/unittest/test/testmock/testpatch.py
# Python-3.10.12/Lib/unittest/test/__main__.py
# Python-3.10.12/Lib/unittest/test/test_loader.py
# Python-3.10.12/Lib/unittest/test/test_result.py
# Python-3.10.12/Lib/unittest/test/test_runner.py
# Python-3.10.12/Lib/unittest/test/test_async_case.py
# Python-3.10.12/Lib/unittest/test/test_program.py
# Python-3.10.12/Lib/unittest/test/__init__.py
# Python-3.10.12/Lib/unittest/test/test_functiontestcase.py
# Python-3.10.12/Lib/unittest/test/test_discovery.py
# Python-3.10.12/Lib/unittest/test/dummy.py
# Python-3.10.12/Lib/unittest/test/test_assertions.py
# Python-3.10.12/Lib/unittest/test/test_case.py
# Python-3.10.12/Lib/unittest/__init__.py
# Python-3.10.12/Lib/unittest/mock.py
# Python-3.10.12/Lib/unittest/async_case.py
# Python-3.10.12/Lib/unittest/loader.py
# Python-3.10.12/Lib/unittest/result.py
# Python-3.10.12/Lib/site-packages/
# Python-3.10.12/Lib/site-packages/README.txt
# Python-3.10.12/Lib/abc.py
# Python-3.10.12/Lib/poplib.py
# Python-3.10.12/Lib/trace.py
# Python-3.10.12/Lib/fnmatch.py
# Python-3.10.12/Lib/mimetypes.py
# Python-3.10.12/config.guess
# Python-3.10.12/setup.py
# Python-3.10.12/PC/
# Python-3.10.12/PC/dl_nt.c
# Python-3.10.12/PC/clinic/
# Python-3.10.12/PC/clinic/winreg.c.h
# Python-3.10.12/PC/clinic/_msi.c.h
# Python-3.10.12/PC/clinic/winsound.c.h
# Python-3.10.12/PC/clinic/_testconsole.c.h
# Python-3.10.12/PC/clinic/msvcrtmodule.c.h
# Python-3.10.12/PC/pyshellext.def
# Python-3.10.12/PC/sqlite3.rc
# Python-3.10.12/PC/empty.c
# Python-3.10.12/PC/WinMain.c
# Python-3.10.12/PC/pyshellext.cpp
# Python-3.10.12/PC/frozen_dllmain.c
# Python-3.10.12/PC/store_info.txt
# Python-3.10.12/PC/_msi.c
# Python-3.10.12/PC/icons/
# Python-3.10.12/PC/icons/logo.svg
# Python-3.10.12/PC/icons/pythonwx150.png
# Python-3.10.12/PC/icons/py.png
# Python-3.10.12/PC/icons/py.icns
# Python-3.10.12/PC/icons/pyd.ico
# Python-3.10.12/PC/icons/pythonw.icns
# Python-3.10.12/PC/icons/launcher.icns
# Python-3.10.12/PC/icons/pyc.icns
# Python-3.10.12/PC/icons/py.svg
# Python-3.10.12/PC/icons/pythonw.svg
# Python-3.10.12/PC/icons/idlex44.png
# Python-3.10.12/PC/icons/python.ico
# Python-3.10.12/PC/icons/launcher.svg
# Python-3.10.12/PC/icons/pyd.icns
# Python-3.10.12/PC/icons/pythonw.ico
# Python-3.10.12/PC/icons/pythonx44.png
# Python-3.10.12/PC/icons/logox128.png
# Python-3.10.12/PC/icons/pythonx50.png
# Python-3.10.12/PC/icons/setup.icns
# Python-3.10.12/PC/icons/setup.svg
# Python-3.10.12/PC/icons/pythonwx44.png
# Python-3.10.12/PC/icons/python.svg
# Python-3.10.12/PC/icons/setup.ico
# Python-3.10.12/PC/icons/pythonx150.png
# Python-3.10.12/PC/icons/launcher.ico
# Python-3.10.12/PC/icons/pyc.ico
# Python-3.10.12/PC/icons/py.ico
# Python-3.10.12/PC/icons/idlex150.png
# Python-3.10.12/PC/icons/python.icns
# Python-3.10.12/PC/icons/pyc.svg
# Python-3.10.12/PC/icons/pyd.svg
# Python-3.10.12/PC/launcher.c
# Python-3.10.12/PC/getpathp.c
# Python-3.10.12/PC/pylauncher.rc
# Python-3.10.12/PC/msvcrtmodule.c
# Python-3.10.12/PC/classicAppCompat.cat
# Python-3.10.12/PC/python_exe.rc
# Python-3.10.12/PC/invalid_parameter_handler.c
# Python-3.10.12/PC/python_nt.rc
# Python-3.10.12/PC/classicAppCompat.can.xml
# Python-3.10.12/PC/pyshellext.rc
# Python-3.10.12/PC/pythonw_exe.rc
# Python-3.10.12/PC/python_ver_rc.h
# Python-3.10.12/PC/crtlicense.txt
# Python-3.10.12/PC/winsound.c
# Python-3.10.12/PC/python3dll.c
# Python-3.10.12/PC/errmap.h
# Python-3.10.12/PC/readme.txt
# Python-3.10.12/PC/_testconsole.c
# Python-3.10.12/PC/layout/
# Python-3.10.12/PC/layout/support/
# Python-3.10.12/PC/layout/support/python.props
# Python-3.10.12/PC/layout/support/constants.py
# Python-3.10.12/PC/layout/support/options.py
# Python-3.10.12/PC/layout/support/filesets.py
# Python-3.10.12/PC/layout/support/appxmanifest.py
# Python-3.10.12/PC/layout/support/pip.py
# Python-3.10.12/PC/layout/support/__init__.py
# Python-3.10.12/PC/layout/support/props.py
# Python-3.10.12/PC/layout/support/catalog.py
# Python-3.10.12/PC/layout/support/logging.py
# Python-3.10.12/PC/layout/support/nuspec.py
# Python-3.10.12/PC/layout/__main__.py
# Python-3.10.12/PC/layout/main.py
# Python-3.10.12/PC/layout/__init__.py
# Python-3.10.12/PC/pyconfig.h
# Python-3.10.12/PC/python.manifest
# Python-3.10.12/PC/testpy.py
# Python-3.10.12/PC/errmap.mak
# Python-3.10.12/PC/classicAppCompat.sccd
# Python-3.10.12/PC/config.c
# Python-3.10.12/PC/winreg.c
# Python-3.10.12/PC/validate_ucrtbase.py
# Python-3.10.12/PC/python_uwp.cpp
# Python-3.10.12/netlify.toml
# Python-3.10.12/config.sub
# Python-3.10.12/LICENSE
# Python-3.10.12/.editorconfig
# Python-3.10.12/Parser/
# Python-3.10.12/Parser/pegen.h
# Python-3.10.12/Parser/myreadline.c
# Python-3.10.12/Parser/pegen.c
# Python-3.10.12/Parser/tokenizer.h
# Python-3.10.12/Parser/Python.asdl
# Python-3.10.12/Parser/asdl_c.py
# Python-3.10.12/Parser/peg_api.c
# Python-3.10.12/Parser/parser.c
# Python-3.10.12/Parser/token.c
# Python-3.10.12/Parser/tokenizer.c
# Python-3.10.12/Parser/string_parser.h
# Python-3.10.12/Parser/string_parser.c
# Python-3.10.12/Parser/asdl.py
# Python-3.10.12/aclocal.m4
# Python-3.10.12/Misc/
# Python-3.10.12/Misc/python-embed.pc.in
# Python-3.10.12/Misc/valgrind-python.supp
# Python-3.10.12/Misc/README
# Python-3.10.12/Misc/python-config.in
# Python-3.10.12/Misc/python-wing3.wpr
# Python-3.10.12/Misc/requirements-test.txt
# Python-3.10.12/Misc/python-config.sh.in
# Python-3.10.12/Misc/python-wing5.wpr
# Python-3.10.12/Misc/README.valgrind
# Python-3.10.12/Misc/stable_abi.txt
# Python-3.10.12/Misc/vgrindefs
# Python-3.10.12/Misc/python.man
# Python-3.10.12/Misc/python.pc.in
# Python-3.10.12/Misc/coverity_model.c
# Python-3.10.12/Misc/python-wing4.wpr
# Python-3.10.12/Misc/README.AIX
# Python-3.10.12/Misc/gdbinit
# Python-3.10.12/Misc/README.coverity
# Python-3.10.12/Misc/svnmap.txt
# Python-3.10.12/Misc/indent.pro
# Python-3.10.12/Misc/NEWS
# Python-3.10.12/Misc/Porting
# Python-3.10.12/Misc/HISTORY
# Python-3.10.12/Misc/ACKS
# Python-3.10.12/Misc/SpecialBuilds.txt
# Python-3.10.12/Makefile.pre.in
# Python-3.10.12/configure.ac
# Python-3.10.12/pyconfig.h.in
# Python-3.10.12/PCbuild/
# Python-3.10.12/PCbuild/python.props
# Python-3.10.12/PCbuild/_ctypes_test.vcxproj
# Python-3.10.12/PCbuild/pywlauncher.vcxproj.filters
# Python-3.10.12/PCbuild/pythonw_uwp.vcxproj.filters
# Python-3.10.12/PCbuild/_freeze_importlib.vcxproj
# Python-3.10.12/PCbuild/xxlimited_35.vcxproj.filters
# Python-3.10.12/PCbuild/prepare_libffi.bat
# Python-3.10.12/PCbuild/build.bat
# Python-3.10.12/PCbuild/_testembed.vcxproj.filters
# Python-3.10.12/PCbuild/_asyncio.vcxproj
# Python-3.10.12/PCbuild/_asyncio.vcxproj.filters
# Python-3.10.12/PCbuild/_queue.vcxproj.filters
# Python-3.10.12/PCbuild/pythonw.vcxproj
# Python-3.10.12/PCbuild/_ctypes.vcxproj
# Python-3.10.12/PCbuild/_hashlib.vcxproj
# Python-3.10.12/PCbuild/_freeze_importlib.vcxproj.filters
# Python-3.10.12/PCbuild/venvlauncher.vcxproj.filters
# Python-3.10.12/PCbuild/env.ps1
# Python-3.10.12/PCbuild/fix_encoding.py
# Python-3.10.12/PCbuild/_socket.vcxproj.filters
# Python-3.10.12/PCbuild/idle.bat
# Python-3.10.12/PCbuild/python3dll.vcxproj.filters
# Python-3.10.12/PCbuild/_testimportmultiple.vcxproj.filters
# Python-3.10.12/PCbuild/_uuid.vcxproj
# Python-3.10.12/PCbuild/_ctypes.vcxproj.filters
# Python-3.10.12/PCbuild/venvwlauncher.vcxproj.filters
# Python-3.10.12/PCbuild/_bz2.vcxproj.filters
# Python-3.10.12/PCbuild/blurb.bat
# Python-3.10.12/PCbuild/_bz2.vcxproj
# Python-3.10.12/PCbuild/Directory.Build.targets
# Python-3.10.12/PCbuild/_testmultiphase.vcxproj
# Python-3.10.12/PCbuild/_overlapped.vcxproj.filters
# Python-3.10.12/PCbuild/env.bat
# Python-3.10.12/PCbuild/_testbuffer.vcxproj.filters
# Python-3.10.12/PCbuild/field3.py
# Python-3.10.12/PCbuild/_testconsole.vcxproj.filters
# Python-3.10.12/PCbuild/pyexpat.vcxproj
# Python-3.10.12/PCbuild/xxlimited.vcxproj.filters
# Python-3.10.12/PCbuild/_testinternalcapi.vcxproj
# Python-3.10.12/PCbuild/Directory.Build.props
# Python-3.10.12/PCbuild/tcl.vcxproj
# Python-3.10.12/PCbuild/_socket.vcxproj
# Python-3.10.12/PCbuild/_tkinter.vcxproj.filters
# Python-3.10.12/PCbuild/unicodedata.vcxproj.filters
# Python-3.10.12/PCbuild/pcbuild.proj
# Python-3.10.12/PCbuild/liblzma.vcxproj.filters
# Python-3.10.12/PCbuild/_testbuffer.vcxproj
# Python-3.10.12/PCbuild/python.vcxproj.filters
# Python-3.10.12/PCbuild/python.vcxproj
# Python-3.10.12/PCbuild/prepare_ssl.bat
# Python-3.10.12/PCbuild/prepare_ssl.py
# Python-3.10.12/PCbuild/_ctypes_test.vcxproj.filters
# Python-3.10.12/PCbuild/_elementtree.vcxproj
# Python-3.10.12/PCbuild/sqlite3.vcxproj
# Python-3.10.12/PCbuild/_testmultiphase.vcxproj.filters
# Python-3.10.12/PCbuild/_decimal.vcxproj
# Python-3.10.12/PCbuild/_testconsole.vcxproj
# Python-3.10.12/PCbuild/openssl.vcxproj
# Python-3.10.12/PCbuild/_overlapped.vcxproj
# Python-3.10.12/PCbuild/venvwlauncher.vcxproj
# Python-3.10.12/PCbuild/python_uwp.vcxproj.filters
# Python-3.10.12/PCbuild/urlretrieve.py
# Python-3.10.12/PCbuild/build_env.bat
# Python-3.10.12/PCbuild/venvlauncher.vcxproj
# Python-3.10.12/PCbuild/pythonw_uwp.vcxproj
# Python-3.10.12/PCbuild/_uuid.vcxproj.filters
# Python-3.10.12/PCbuild/_zoneinfo.vcxproj.filters
# Python-3.10.12/PCbuild/_queue.vcxproj
# Python-3.10.12/PCbuild/_tkinter.vcxproj
# Python-3.10.12/PCbuild/_lzma.vcxproj.filters
# Python-3.10.12/PCbuild/regen.targets
# Python-3.10.12/PCbuild/_testembed.vcxproj
# Python-3.10.12/PCbuild/pylauncher.vcxproj
# Python-3.10.12/PCbuild/_hashlib.vcxproj.filters
# Python-3.10.12/PCbuild/readme.txt
# Python-3.10.12/PCbuild/_sqlite3.vcxproj
# Python-3.10.12/PCbuild/_sqlite3.vcxproj.filters
# Python-3.10.12/PCbuild/_multiprocessing.vcxproj.filters
# Python-3.10.12/PCbuild/pythoncore.vcxproj.filters
# Python-3.10.12/PCbuild/_decimal.vcxproj.filters
# Python-3.10.12/PCbuild/_testimportmultiple.vcxproj
# Python-3.10.12/PCbuild/tix.vcxproj
# Python-3.10.12/PCbuild/python3dll.vcxproj
# Python-3.10.12/PCbuild/select.vcxproj.filters
# Python-3.10.12/PCbuild/clean.bat
# Python-3.10.12/PCbuild/pyproject.props
# Python-3.10.12/PCbuild/pcbuild.sln
# Python-3.10.12/PCbuild/rt.bat
# Python-3.10.12/PCbuild/unicodedata.vcxproj
# Python-3.10.12/PCbuild/sqlite3.vcxproj.filters
# Python-3.10.12/PCbuild/get_external.py
# Python-3.10.12/PCbuild/prepare_tcltk.bat
# Python-3.10.12/PCbuild/_msi.vcxproj
# Python-3.10.12/PCbuild/pywlauncher.vcxproj
# Python-3.10.12/PCbuild/_zoneinfo.vcxproj
# Python-3.10.12/PCbuild/find_python.bat
# Python-3.10.12/PCbuild/python_uwp.vcxproj
# Python-3.10.12/PCbuild/pythonw.vcxproj.filters
# Python-3.10.12/PCbuild/tcltk.props
# Python-3.10.12/PCbuild/_testinternalcapi.vcxproj.filters
# Python-3.10.12/PCbuild/pythoncore.vcxproj
# Python-3.10.12/PCbuild/xxlimited_35.vcxproj
# Python-3.10.12/PCbuild/_ssl.vcxproj.filters
# Python-3.10.12/PCbuild/pyexpat.vcxproj.filters
# Python-3.10.12/PCbuild/_multiprocessing.vcxproj
# Python-3.10.12/PCbuild/_testcapi.vcxproj.filters
# Python-3.10.12/PCbuild/_elementtree.vcxproj.filters
# Python-3.10.12/PCbuild/tk.vcxproj
# Python-3.10.12/PCbuild/pyshellext.vcxproj.filters
# Python-3.10.12/PCbuild/_ssl.vcxproj
# Python-3.10.12/PCbuild/winsound.vcxproj.filters
# Python-3.10.12/PCbuild/lib.pyproj
# Python-3.10.12/PCbuild/libffi.props
# Python-3.10.12/PCbuild/xxlimited.vcxproj
# Python-3.10.12/PCbuild/liblzma.vcxproj
# Python-3.10.12/PCbuild/select.vcxproj
# Python-3.10.12/PCbuild/get_externals.bat
# Python-3.10.12/PCbuild/pylauncher.vcxproj.filters
# Python-3.10.12/PCbuild/openssl.props
# Python-3.10.12/PCbuild/_lzma.vcxproj
# Python-3.10.12/PCbuild/find_msbuild.bat
# Python-3.10.12/PCbuild/_msi.vcxproj.filters
# Python-3.10.12/PCbuild/_testcapi.vcxproj
# Python-3.10.12/PCbuild/pyshellext.vcxproj
# Python-3.10.12/PCbuild/rmpyc.py
# Python-3.10.12/PCbuild/winsound.vcxproj
# Python-3.10.12/Objects/
# Python-3.10.12/Objects/clinic/
# Python-3.10.12/Objects/clinic/codeobject.c.h
# Python-3.10.12/Objects/clinic/funcobject.c.h
# Python-3.10.12/Objects/clinic/moduleobject.c.h
# Python-3.10.12/Objects/clinic/bytearrayobject.c.h
# Python-3.10.12/Objects/clinic/dictobject.c.h
# Python-3.10.12/Objects/clinic/unicodeobject.c.h
# Python-3.10.12/Objects/clinic/typeobject.c.h
# Python-3.10.12/Objects/clinic/longobject.c.h
# Python-3.10.12/Objects/clinic/odictobject.c.h
# Python-3.10.12/Objects/clinic/enumobject.c.h
# Python-3.10.12/Objects/clinic/complexobject.c.h
# Python-3.10.12/Objects/clinic/structseq.c.h
# Python-3.10.12/Objects/clinic/memoryobject.c.h
# Python-3.10.12/Objects/clinic/descrobject.c.h
# Python-3.10.12/Objects/clinic/floatobject.c.h
# Python-3.10.12/Objects/clinic/listobject.c.h
# Python-3.10.12/Objects/clinic/bytesobject.c.h
# Python-3.10.12/Objects/clinic/tupleobject.c.h
# Python-3.10.12/Objects/unionobject.c
# Python-3.10.12/Objects/lnotab_notes.txt
# Python-3.10.12/Objects/unicodetype_db.h
# Python-3.10.12/Objects/weakrefobject.c
# Python-3.10.12/Objects/fileobject.c
# Python-3.10.12/Objects/complexobject.c
# Python-3.10.12/Objects/README
# Python-3.10.12/Objects/odictobject.c
# Python-3.10.12/Objects/enumobject.c
# Python-3.10.12/Objects/cellobject.c
# Python-3.10.12/Objects/dict-common.h
# Python-3.10.12/Objects/sliceobject.c
# Python-3.10.12/Objects/longobject.c
# Python-3.10.12/Objects/genericaliasobject.c
# Python-3.10.12/Objects/bytesobject.c
# Python-3.10.12/Objects/object.c
# Python-3.10.12/Objects/exceptions.c
# Python-3.10.12/Objects/moduleobject.c
# Python-3.10.12/Objects/iterobject.c
# Python-3.10.12/Objects/descrobject.c
# Python-3.10.12/Objects/capsule.c
# Python-3.10.12/Objects/bytearrayobject.c
# Python-3.10.12/Objects/typeslots.inc
# Python-3.10.12/Objects/unicodeobject.c
# Python-3.10.12/Objects/frameobject.c
# Python-3.10.12/Objects/structseq.c
# Python-3.10.12/Objects/floatobject.c
# Python-3.10.12/Objects/call.c
# Python-3.10.12/Objects/stringlib/
# Python-3.10.12/Objects/stringlib/clinic/
# Python-3.10.12/Objects/stringlib/clinic/transmogrify.h.h
# Python-3.10.12/Objects/stringlib/stringdefs.h
# Python-3.10.12/Objects/stringlib/partition.h
# Python-3.10.12/Objects/stringlib/unicodedefs.h
# Python-3.10.12/Objects/stringlib/count.h
# Python-3.10.12/Objects/stringlib/ctype.h
# Python-3.10.12/Objects/stringlib/codecs.h
# Python-3.10.12/Objects/stringlib/ucs1lib.h
# Python-3.10.12/Objects/stringlib/README.txt
# Python-3.10.12/Objects/stringlib/unicode_format.h
# Python-3.10.12/Objects/stringlib/asciilib.h
# Python-3.10.12/Objects/stringlib/eq.h
# Python-3.10.12/Objects/stringlib/find_max_char.h
# Python-3.10.12/Objects/stringlib/undef.h
# Python-3.10.12/Objects/stringlib/split.h
# Python-3.10.12/Objects/stringlib/stringlib_find_two_way_notes.txt
# Python-3.10.12/Objects/stringlib/transmogrify.h
# Python-3.10.12/Objects/stringlib/find.h
# Python-3.10.12/Objects/stringlib/ucs4lib.h
# Python-3.10.12/Objects/stringlib/replace.h
# Python-3.10.12/Objects/stringlib/join.h
# Python-3.10.12/Objects/stringlib/ucs2lib.h
# Python-3.10.12/Objects/stringlib/localeutil.h
# Python-3.10.12/Objects/stringlib/fastsearch.h
# Python-3.10.12/Objects/setobject.c
# Python-3.10.12/Objects/funcobject.c
# Python-3.10.12/Objects/rangeobject.c
# Python-3.10.12/Objects/unicodectype.c
# Python-3.10.12/Objects/abstract.c
# Python-3.10.12/Objects/tupleobject.c
# Python-3.10.12/Objects/obmalloc.c
# Python-3.10.12/Objects/bytes_methods.c
# Python-3.10.12/Objects/classobject.c
# Python-3.10.12/Objects/interpreteridobject.c
# Python-3.10.12/Objects/typeslots.py
# Python-3.10.12/Objects/codeobject.c
# Python-3.10.12/Objects/typeobject.c
# Python-3.10.12/Objects/picklebufobject.c
# Python-3.10.12/Objects/accu.c
# Python-3.10.12/Objects/listobject.c
# Python-3.10.12/Objects/dictobject.c
# Python-3.10.12/Objects/genobject.c
# Python-3.10.12/Objects/methodobject.c
# Python-3.10.12/Objects/boolobject.c
# Python-3.10.12/Objects/memoryobject.c
# Python-3.10.12/Objects/namespaceobject.c
# Python-3.10.12/Objects/listsort.txt
# Python-3.10.12/Objects/dictnotes.txt
# Python-3.10.12/Programs/
# Python-3.10.12/Programs/README
# Python-3.10.12/Programs/python.c
# Python-3.10.12/Programs/_testembed.c
# Python-3.10.12/Programs/_freeze_importlib.c

# %%
# !pip install virtualenv

# %cd /kaggle/working
# !virtualenv venv -p $(which python3.10)
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.32.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.11/dist-packages (from virtualenv) (3.18.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv) (4.3.8)
# Downloading virtualenv-20.32.0-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 55.0 MB/s eta 0:00:0000:0100:01
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 34.2 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.4.0 virtualenv-20.32.0
# /kaggle/working
# created virtual environment CPython3.10.12.final.0-64 in 709ms
#   creator CPython3Posix(dest=/kaggle/working/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.1.1, setuptools==80.9.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/NLP2CT/kNN-TL.git
# Out:
# Cloning into 'kNN-TL'...
# remote: Enumerating objects: 1672, done.
# remote: Counting objects: 100% (1672/1672), done.
# remote: Compressing objects: 100% (1333/1333), done.
# remote: Total 1672 (delta 282), reused 1666 (delta 279), pack-reused 0 (from 0)
# Receiving objects: 100% (1672/1672), 14.82 MiB | 32.65 MiB/s, done.
# Resolving deltas: 100% (282/282), done.

# %%
cd /kaggle/working/kNN-TL/kNN-TL
# Out:
# /kaggle/working/kNN-TL/kNN-TL

# %%
# !/kaggle/working/venv/bin/pip install pip==24.0
# Out:
# Collecting pip==24.0
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-24.0

# %%
# !/kaggle/working/venv/bin/pip install --editable .
# Out:
# Obtaining file:///kaggle/working/kNN-TL/kNN-TL
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting cffi (from fairseq==0.12.0)
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting cython (from fairseq==0.12.0)
#   Using cached cython-3.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.0)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.0)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting numpy (from fairseq==0.12.0)
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting regex (from fairseq==0.12.0)
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.4 MB/s eta 0:00:00
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.0)
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.8 MB/s eta 0:00:00
# Collecting torch (from fairseq==0.12.0)
#   Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting tqdm (from fairseq==0.12.0)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.2 MB/s eta 0:00:00
# Collecting bitarray (from fairseq==0.12.0)
#   Downloading bitarray-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Collecting torchaudio>=0.8.0 (from fairseq==0.12.0)
#   Downloading torchaudio-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.0)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 4.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting PyYAML>=5.1.* (from omegaconf<2.1->fairseq==0.12.0)
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting typing-extensions (from omegaconf<2.1->fairseq==0.12.0)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.0)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting tabulate>=0.8.9 (from sacrebleu>=1.4.12->fairseq==0.12.0)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting colorama (from sacrebleu>=1.4.12->fairseq==0.12.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting lxml (from sacrebleu>=1.4.12->fairseq==0.12.0)
#   Downloading lxml-6.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch->fairseq==0.12.0)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy>=1.13.3 (from torch->fairseq==0.12.0)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch->fairseq==0.12.0)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->fairseq==0.12.0)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch->fairseq==0.12.0)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch->fairseq==0.12.0)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch->fairseq==0.12.0)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch->fairseq==0.12.0)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch->fairseq==0.12.0)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch->fairseq==0.12.0)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch->fairseq==0.12.0)
#   Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /kaggle/working/venv/lib/python3.10/site-packages (from triton==3.3.1->torch->fairseq==0.12.0) (80.9.0)
# Collecting pycparser (from cffi->fairseq==0.12.0)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->fairseq==0.12.0)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->fairseq==0.12.0)
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 4.6 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.0 MB/s eta 0:00:00
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Downloading torchaudio-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 13.0 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 100.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 64.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 45.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 6.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 840.4 kB/s eta 0:00:0000:01
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 5.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 7.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 10.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 8.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 70.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 6.8 MB/s eta 0:00:00
# Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading bitarray-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 22.6 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 27.3 MB/s eta 0:00:00
# Using cached cython-3.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 kB 43.6 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.5 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 39.9 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 101.4 MB/s eta 0:00:0000:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 15.9 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 10.3 MB/s eta 0:00:00
# Downloading lxml-6.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 101.5 MB/s eta 0:00:0000:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.4 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 9.3 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 37.5 MB/s eta 0:00:00
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.0-0.editable-cp310-cp310-linux_x86_64.whl size=9441 sha256=1deb999da6d5b837a81e499a02091ca1bbc767751e4f8c1e4efe6ce4c01db964
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4bj7shsl/wheels/40/6e/0d/497a471631de59eb3775b3430517fb387829683421dd0481b7
#   Building wheel for antlr4-python3-runtime (pyproject.toml) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141247 sha256=d3434422ffb2145f302c1efb077ca13687acb0d24cf9fc49456f3289c5d89c72
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, bitarray, antlr4-python3-runtime, typing-extensions, triton, tqdm, tabulate, sympy, regex, PyYAML, pycparser, portalocker, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, lxml, fsspec, filelock, cython, colorama, sacrebleu, omegaconf, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, cffi, nvidia-cusolver-cu12, hydra-core, torch, torchaudio, fairseq
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 antlr4-python3-runtime-4.8 bitarray-3.5.2 cffi-1.17.1 colorama-0.4.6 cython-3.1.2 fairseq-0.12.0 filelock-3.18.0 fsspec-2025.7.0 hydra-core-1.0.7 jinja2-3.1.6 lxml-6.0.0 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 omegaconf-2.0.6 portalocker-3.2.0 pycparser-2.22 regex-2024.11.6 sacrebleu-2.5.1 sympy-1.14.0 tabulate-0.9.0 torch-2.7.1 torchaudio-2.7.1 tqdm-4.67.1 triton-3.3.1 typing-extensions-4.14.1

# %%
cd ..
# Out:
# /kaggle/working/kNN-TL

# %%
# !/kaggle/working/venv/bin/pip install faiss-gpu-cu12
# Out:
# Collecting faiss-gpu-cu12
#   Downloading faiss_gpu_cu12-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy<2 (from faiss-gpu-cu12)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Collecting packaging (from faiss-gpu-cu12)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /kaggle/working/venv/lib/python3.10/site-packages (from faiss-gpu-cu12) (12.6.77)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /kaggle/working/venv/lib/python3.10/site-packages (from faiss-gpu-cu12) (12.6.4.1)
# Downloading faiss_gpu_cu12-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 MB 39.3 MB/s eta 0:00:00:00:0100:01
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 80.1 MB/s eta 0:00:00:00:0100:01
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.0 MB/s eta 0:00:00
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: packaging, numpy, faiss-gpu-cu12
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed faiss-gpu-cu12-1.11.0 numpy-1.26.4 packaging-25.0

# %%
# !/kaggle/working/venv/bin/pip install sacremoses==0.0.53
# Out:
# Collecting sacremoses==0.0.53
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 8.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: regex in /kaggle/working/venv/lib/python3.10/site-packages (from sacremoses==0.0.53) (2024.11.6)
# Collecting six (from sacremoses==0.0.53)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting click (from sacremoses==0.0.53)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting joblib (from sacremoses==0.0.53)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tqdm in /kaggle/working/venv/lib/python3.10/site-packages (from sacremoses==0.0.53) (4.67.1)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 6.3 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 9.7 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (pyproject.toml) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895307 sha256=878c4df8a656097616ebfa4b4083d01c4bafa28efcd02e207fb813bd723fd4b2
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: six, joblib, click, sacremoses
# Successfully installed click-8.2.1 joblib-1.5.1 sacremoses-0.0.53 six-1.17.0

# %%
# !/kaggle/working/venv/bin/pip freeze
# Out:
# antlr4-python3-runtime==4.8
# bitarray==3.5.2
# cffi==1.17.1
# click==8.2.1
# colorama==0.4.6
# Cython==3.1.2
# -e git+https://github.com/NLP2CT/kNN-TL.git@275945104d5a08d737d8e67c4e609dfff3a37317#egg=fairseq&subdirectory=kNN-TL
# faiss-gpu-cu12==1.11.0
# filelock==3.18.0
# fsspec==2025.7.0
# hydra-core==1.0.7
# Jinja2==3.1.6
# joblib==1.5.1
# lxml==6.0.0
# MarkupSafe==3.0.2
# mpmath==1.3.0
# networkx==3.4.2
# numpy==1.26.4
# nvidia-cublas-cu12==12.6.4.1
# nvidia-cuda-cupti-cu12==12.6.80
# nvidia-cuda-nvrtc-cu12==12.6.77
# nvidia-cuda-runtime-cu12==12.6.77
# nvidia-cudnn-cu12==9.5.1.17
# nvidia-cufft-cu12==11.3.0.4
# nvidia-cufile-cu12==1.11.1.6
# nvidia-curand-cu12==10.3.7.77
# nvidia-cusolver-cu12==11.7.1.2
# nvidia-cusparse-cu12==12.5.4.2
# nvidia-cusparselt-cu12==0.6.3
# nvidia-nccl-cu12==2.26.2
# nvidia-nvjitlink-cu12==12.6.85
# nvidia-nvtx-cu12==12.6.77
# omegaconf==2.0.6
# packaging==25.0
# portalocker==3.2.0
# pycparser==2.22
# PyYAML==6.0.2
# regex==2024.11.6
# sacrebleu==2.5.1
# sacremoses==0.0.53
# six==1.17.0
# sympy==1.14.0
# tabulate==0.9.0
# torch==2.7.1
# torchaudio==2.7.1
# tqdm==4.67.1
# triton==3.3.1
# typing_extensions==4.14.1

# %%
cd /kaggle/working/kNN-TL
# Out:
# /kaggle/working/kNN-TL

# %%
# !cd train-scripts

# %%
# !mkdir /kaggle/working/kNN-TL/kNN-TL/checkpoints

# %%
# !mkdir /kaggle/working/kNN-TL/kNN-TL/checkpoints/child

# %%
# !mkdir /kaggle/working/kNN-TL/kNN-TL/checkpoints/child2

# %%
# !mkdir /kaggle/working/kNN-TL/kNN-TL/logs

# %%
# !ls /kaggle/working/kNN-TL/kNN-TL/checkpoints
# Out:
# child  child2

# %%
# %%writefile /kaggle/working/kNN-TL/kNN-TL/preprocessing_scripts/TM.py
import copy
import argparse
import torch
from tqdm import tqdm
import torch.nn as nn
import copy
def main():
    torch.manual_seed(1)
    parser = argparse.ArgumentParser(description='token matching')
    parser.add_argument('--checkpoint', type=str, help='parent checkpoint')
    parser.add_argument('--output', type=str, help='path to write the embeddings to')
    parser.add_argument('--parent-dict', type=str, help='parent side dictionary')
    parser.add_argument('--child-dict', type=str, help='child side dict')
    parser.add_argument('--switch-dict', type=str, choices=['src', 'tgt'] )

    args = parser.parse_args()
    model = torch.load(args.checkpoint, weights_only=False)

    if args.switch_dict == 'tgt':
        parent_embeddings = model['model']['decoder.embed_tokens.weight']
    elif args.switch_dict == 'src':
        parent_embeddings = model['model']['encoder.embed_tokens.weight']
    parent_dict_file = open(args.parent_dict, 'r')
    parent_dict_lines = parent_dict_file.readlines()
    child_dict_file = open(args.child_dict, 'r')
    child_dict_lines = child_dict_file.readlines()

    p_dict_list = ['<s>','<pad>','</s>','<unk>']
    c_dict_list = ['<s>','<pad>','</s>','<unk>']

    for line in tqdm(parent_dict_lines):
        type = line.strip('\n').split()[0]
        p_dict_list.append(type)
    
    for line in tqdm(child_dict_lines):
        type = line.strip('\n').split()[0]
        c_dict_list.append(type)
    
    inter_list = list(set(p_dict_list).intersection(set(c_dict_list)))
    p_tensor_dict = {} 
    for idx in tqdm(range(len(p_dict_list))):
        p_tensor_dict[p_dict_list[idx]] = parent_embeddings[idx]
    embedding_dim=int(parent_embeddings.size()[-1])
    child_embeddings = torch.empty(len(c_dict_list), embedding_dim)
    nn.init.normal_(child_embeddings, mean=0, std=embedding_dim**-0.5)
    cnt = 0
    old_child_embeddings = copy.deepcopy(child_embeddings)
    for i in tqdm(range(len(c_dict_list))):
        if c_dict_list[i] in p_dict_list:
            child_embeddings[i] = p_tensor_dict[c_dict_list[i]]
            cnt += 1
    print(cnt)
    # assert old_child_embeddings != child_embeddings

    new_checkpoint = copy.deepcopy(model)
    if 'cfg' not in new_checkpoint.keys():
        model_cfg_dict = vars(new_checkpoint['args'])
        model_cfg_dict['share_decoder_input_output_embed'] = True
        model_cfg_dict['share_all_embeddings'] = False
    else:
        model_cfg_dict = vars(new_checkpoint['cfg']['model'])
        model_cfg_dict['share_decoder_input_output_embed'] = True
        model_cfg_dict['share_all_embeddings'] = False
    if 'cfg' not in new_checkpoint.keys():
        new_checkpoint['args'] = argparse.Namespace(**model_cfg_dict)
    else:
        new_checkpoint['cfg']['model'] = argparse.Namespace(**model_cfg_dict)
    if args.switch_dict == 'tgt':
        new_checkpoint['model']['decoder.embed_tokens.weight'] = child_embeddings
    elif args.switch_dict == 'src':
        new_checkpoint['model']['encoder.embed_tokens.weight'] = child_embeddings
    torch.save(new_checkpoint, args.output)

if __name__ == '__main__':
    main()
# Out:
# Overwriting /kaggle/working/kNN-TL/kNN-TL/preprocessing_scripts/TM.py

# %% [markdown]
# Initialize first child trained with PADIC

# %%
# !/kaggle/working/venv/bin/python /kaggle/working/kNN-TL/kNN-TL/preprocessing_scripts/TM.py --checkpoint "/kaggle/input/parent_best/pytorch/default/1/checkpoint_best.pt"  --output "/kaggle/working/kNN-TL/initial_child.pt" --parent-dict "/kaggle/input/hplt-bin/Bin_hplt/dict.en.txt" --child-dict "/kaggle/input/bin-padic/Bin_padic/dict.drj.txt" --switch-dict "src"
# Out:
# 100%|████████████████████████████████| 46116/46116 [00:00<00:00, 1241110.08it/s]
# 100%|███████████████████████████████████| 5492/5492 [00:00<00:00, 703856.68it/s]
# 100%|█████████████████████████████████| 46120/46120 [00:00<00:00, 229893.98it/s]
# 100%|█████████████████████████████████████| 5496/5496 [00:02<00:00, 2602.06it/s]
# 2378

# %% [markdown]
# Initialize second child trained with MADAR

# %%
# !/kaggle/working/venv/bin/python /kaggle/working/kNN-TL/kNN-TL/preprocessing_scripts/TM.py --checkpoint "/kaggle/input/parent_best/pytorch/default/1/checkpoint_best.pt"  --output "/kaggle/working/kNN-TL/initial_child2.pt" --parent-dict "/kaggle/input/hplt-bin/Bin_hplt/dict.en.txt" --child-dict "/kaggle/input/bin-madar/Bin_madar/dict.drj.txt" --switch-dict "src"
# Out:
# 100%|████████████████████████████████| 46116/46116 [00:00<00:00, 1627810.00it/s]
# 100%|██████████████████████████████████| 5964/5964 [00:00<00:00, 1652452.71it/s]
# 100%|█████████████████████████████████| 46120/46120 [00:00<00:00, 245635.69it/s]
# 100%|█████████████████████████████████████| 5968/5968 [00:01<00:00, 3034.71it/s]
# 3292

# %%
# %%writefile /kaggle/working/kNN-TL/kNN-TL/fairseq/trainer.py
# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

"""
Train a network across multiple GPUs.
"""

import contextlib
import logging
import os
import sys
import time
from argparse import Namespace
from itertools import chain
from typing import Any, Dict, List

import torch
from omegaconf import OmegaConf

from fairseq import checkpoint_utils, models, optim, utils
from fairseq.dataclass.configs import FairseqConfig
from fairseq.dataclass.utils import convert_namespace_to_omegaconf
from fairseq.distributed import utils as distributed_utils
from fairseq.file_io import PathManager
from fairseq.logging import meters, metrics
from fairseq.models.ema import build_ema
from fairseq.nan_detector import NanDetector
from fairseq.optim import lr_scheduler
from fairseq.utils import safe_hasattr


logger = logging.getLogger(__name__)


class Trainer(object):
    """Main class for data parallel training.

    This class supports synchronous distributed data parallel training,
    where multiple workers each have a full model replica and gradients
    are accumulated across workers before each update. We use
    :class:`~torch.nn.parallel.DistributedDataParallel` to handle
    communication of the gradients across workers.
    """

    def __init__(self, cfg: FairseqConfig, task, model, criterion, quantizer=None):

        if isinstance(cfg, Namespace):
            logger.warning(
                "argparse.Namespace configuration is deprecated! Automatically converting to OmegaConf"
            )
            cfg = convert_namespace_to_omegaconf(cfg)

        self.cfg = cfg
        self.task = task

        # catalog shared parameters
        shared_params = _catalog_shared_params(model)
        self.tpu = cfg.common.tpu
        self.cuda = torch.cuda.is_available() and not cfg.common.cpu and not self.tpu
        if self.cuda:
            self.device = torch.device("cuda")
        elif self.tpu:
            self.device = utils.get_tpu_device()
        else:
            self.device = torch.device("cpu")

        if self.is_fsdp:
            import fairscale

            if self.cfg.common.bf16:
                raise ValueError(
                    "FullyShardedDataParallel is not compatible with --bf16 or "
                    "--memory-efficient-bf16"
                )
            if self.cfg.distributed_training.zero_sharding != "none":
                raise ValueError(
                    "FullyShardedDataParallel is not compatible with --zero-sharding "
                    "option (it's already built in)"
                )
            if (
                max(self.cfg.optimization.update_freq) > 1
                and fairscale.__version__ < "0.4.0"
            ):
                raise RuntimeError(
                    "Please update to fairscale 0.4.0 or newer when combining "
                    "--update-freq with FullyShardedDataParallel"
                )
        else:
            if (
                hasattr(self.cfg.distributed_training, "cpu_offload")
                and self.cfg.distributed_training.cpu_offload
            ):
                raise ValueError("--cpu-offload requires --ddp-backend=fully_sharded")

        # copy model and criterion to current device/dtype
        self._criterion = criterion
        self._model = model
        if not self.is_fsdp:
            if cfg.common.fp16:
                assert not cfg.common.amp, "Cannot use fp16 and AMP together"
                self._criterion = self._criterion.half()
                self._model = self._model.half()
            elif cfg.common.bf16:
                self._criterion = self._criterion.to(dtype=torch.bfloat16)
                self._model = self._model.to(dtype=torch.bfloat16)
            elif cfg.common.amp:
                self._amp_retries = 0
        if (
            not cfg.distributed_training.pipeline_model_parallel
            # the DistributedFairseqModel wrapper will handle moving to device,
            # so only handle cases which don't use the wrapper
            and not self.use_distributed_wrapper
        ):
            self._criterion = self._criterion.to(device=self.device)
            self._model = self._model.to(device=self.device)
        self.pipeline_model_parallel = cfg.distributed_training.pipeline_model_parallel
        self.last_device = None
        if self.cuda and self.pipeline_model_parallel:
            self.last_device = torch.device(
                cfg.distributed_training.pipeline_devices[-1]
            )

        # check that shared parameters are preserved after device transfer
        for shared_param in shared_params:
            ref = _get_module_by_path(self._model, shared_param[0])
            for path in shared_param[1:]:
                logger.info(
                    "detected shared parameter: {} <- {}".format(shared_param[0], path)
                )
                _set_module_by_path(self._model, path, ref)

        self._dummy_batch = None  # indicates we don't have a dummy batch at first
        self._lr_scheduler = None
        self._num_updates = 0
        self._num_xla_compiles = 0  # for TPUs
        self._optim_history = None
        self._optimizer = None
        self._warn_once = set()
        self._wrapped_criterion = None
        self._wrapped_model = None
        self._ema = None

        # TODO(myleott): support tpu
        if self.cuda and self.data_parallel_world_size > 1:
            self._grad_norm_buf = torch.cuda.DoubleTensor(self.data_parallel_world_size)
            #change to self._grad_norm_buf = torch.zeros(self.data_parallel_world_size, dtype=torch.float64, device='cuda')
        else:
            self._grad_norm_buf = None

        self.quantizer = quantizer
        if self.quantizer is not None:
            self.quantizer.set_trainer(self)

        # get detailed cuda environment
        if self.cuda:
            self.cuda_env = utils.CudaEnvironment()
            if self.data_parallel_world_size > 1:
                self.cuda_env_arr = distributed_utils.all_gather_list(
                    self.cuda_env, group=distributed_utils.get_global_group()
                )
            else:
                self.cuda_env_arr = [self.cuda_env]
            if self.data_parallel_rank == 0:
                utils.CudaEnvironment.pretty_print_cuda_env_list(self.cuda_env_arr)
        else:
            self.cuda_env = None
            self.cuda_env_arr = None

        metrics.log_start_time("wall", priority=790, round=0)

        self._start_time = time.time()
        self._previous_training_time = 0
        self._cumulative_training_time = None

    def reinitialize(self):
        """Reinitialize the Trainer, typically after model params change."""
        self._lr_scheduler = None
        self._optimizer = None
        self._wrapped_criterion = None
        self._wrapped_model = None

    @property
    def data_parallel_world_size(self):
        if self.cfg.distributed_training.distributed_world_size == 1:
            return 1
        return distributed_utils.get_data_parallel_world_size()

    @property
    def data_parallel_process_group(self):
        return distributed_utils.get_data_parallel_group()

    @property
    def data_parallel_rank(self):
        if self.cfg.distributed_training.distributed_world_size == 1:
            return 0
        return distributed_utils.get_data_parallel_rank()

    @property
    def is_data_parallel_master(self):
        # NOTE: this returns true for all model parallel replicas with data
        # parallel rank 0
        return self.data_parallel_rank == 0

    @property
    def use_distributed_wrapper(self) -> bool:
        return (
            self.data_parallel_world_size > 1 and not self.cfg.optimization.use_bmuf
        ) or (self.is_fsdp and self.cfg.distributed_training.cpu_offload)

    @property
    def should_save_checkpoint_on_current_rank(self) -> bool:
        """Indicates whether to save checkpoints on the current DDP rank."""
        if (
            self.is_fsdp and self.cfg.distributed_training.use_sharded_state
        ) or getattr(self.cfg.model, "base_layers", 0) > 0:
            return True
        else:
            return self.is_data_parallel_master

    @property
    def always_call_state_dict_during_save_checkpoint(self) -> bool:
        if self.is_fsdp and not self.cfg.distributed_training.use_sharded_state:
            # FSDP calls communication collective when consolidating checkpoints
            return True
        else:
            return False

    @property
    def checkpoint_suffix(self) -> str:
        """Suffix to add to the checkpoint file name."""
        if self.is_fsdp and self.cfg.distributed_training.use_sharded_state:
            return self.cfg.checkpoint.checkpoint_suffix + "-shard{0}".format(
                self.data_parallel_rank
            )
        else:
            return self.cfg.checkpoint.checkpoint_suffix or ""

    @property
    def criterion(self):
        if self._wrapped_criterion is None:
            if utils.has_parameters(self._criterion) and self.use_distributed_wrapper:
                self._wrapped_criterion = models.DistributedFairseqModel(
                    self.cfg.distributed_training,
                    self._criterion,
                    process_group=self.data_parallel_process_group,
                    device=self.device,
                )
            else:
                self._wrapped_criterion = self._criterion
        return self._wrapped_criterion

    @property
    def model(self):
        if self._wrapped_model is None:
            if self.use_distributed_wrapper:
                self._wrapped_model = models.DistributedFairseqModel(
                    self.cfg.distributed_training,
                    self._model,
                    process_group=self.data_parallel_process_group,
                    device=self.device,
                )
            else:
                self._wrapped_model = self._model
        return self._wrapped_model

    @property
    def ema(self):
        if self._ema is None:
            self._build_ema()
        return self._ema

    def _build_ema(self):
        if self.cfg.ema.store_ema:
            self._ema = build_ema(self._model, self.cfg.ema, self.device)
            logger.info("Exponential Moving Average Shadow Model is initialized.")

    @property
    def optimizer(self):
        if self._optimizer is None:
            self._build_optimizer()
        return self._optimizer

    @property
    def lr_scheduler(self):
        if self._lr_scheduler is None:
            self._build_optimizer()  # this will initialize self._lr_scheduler
        return self._lr_scheduler

    def _build_optimizer(self):
        params = list(
            filter(
                lambda p: p.requires_grad,
                chain(self.model.parameters(), self.criterion.parameters()),
            )
        )

        if self.is_fsdp and self.cfg.common.fp16:
            # FullyShardedDataParallel always uses MemoryEfficientFP16 wrapper,
            # mostly for the grad scaling. But if we don't have the
            # --memory-efficient-fp16 flag set, then we're effectively doing
            # regular --fp16 and can allow the use of optimizers that would
            # otherwise be unsupported by MemoryEfficientFP16Optimizer.
            allow_unsupported = not self.cfg.common.memory_efficient_fp16
            self._optimizer = optim.MemoryEfficientFP16Optimizer.build_optimizer(
                self.cfg, params, allow_unsupported=allow_unsupported
            )
        elif self.cfg.common.fp16 or self.cfg.common.bf16 or self.cfg.common.amp:
            if self.cuda and torch.cuda.get_device_capability(0)[0] < 7:
                logger.info(
                    "NOTE: your device does NOT support faster training with --fp16 or --amp, "
                    "please switch to FP32 which is likely to be faster"
                )
            if (
                self.cfg.common.memory_efficient_fp16
                or self.cfg.common.memory_efficient_bf16
            ):
                self._optimizer = optim.MemoryEfficientFP16Optimizer.build_optimizer(
                    self.cfg, params
                )
            elif self.cfg.common.amp:
                self._optimizer = optim.AMPOptimizer.build_optimizer(self.cfg, params)
            else:
                self._optimizer = optim.FP16Optimizer.build_optimizer(self.cfg, params)
        else:
            if self.cuda and torch.cuda.get_device_capability(0)[0] >= 7:
                logger.info(
                    "NOTE: your device may support faster training with --fp16 or --amp"
                )
            self._optimizer = optim.build_optimizer(self.cfg.optimizer, params)

        if self.is_fsdp:
            assert (
                not self.cfg.optimization.use_bmuf
            ), "--ddp-backend=fully_sharded is not compatible with BMUF"
            assert self._optimizer.supports_flat_params, (
                "--ddp-backend=fully_sharded is only compatible with pointwise "
                "optimizers (e.g., Adam, AdamW, Adadelta, Adamax, SGD, etc.). "
                "However, the sharding will result in slightly different results when "
                "using non-pointwise optimizers (e.g., Adagrad, Adafactor, LAMB)"
            )

        if self.cfg.optimization.use_bmuf:
            self._optimizer = optim.FairseqBMUF(
                self.cfg.bmuf,
                self._optimizer,
            )

        if self.cfg.distributed_training.zero_sharding == "os":
            if (
                self.cfg.common.fp16
                and not self.cfg.common.memory_efficient_fp16
                and not self.cfg.common.memory_efficient_bf16
            ) and not self.cfg.common.fp16_no_flatten_grads:
                raise ValueError(
                    "ZeRO is incomptabile with fp16 and flattened grads. "
                    "Please use --fp16-no-flatten-grads"
                )
            else:
                optim.shard_(self._optimizer, self.data_parallel_process_group)

        # We should initialize the learning rate scheduler immediately after
        # building the optimizer, so that the initial learning rate is set.
        self._lr_scheduler = lr_scheduler.build_lr_scheduler(
            self.cfg.lr_scheduler,
            self.optimizer,
        )
        self._lr_scheduler.step_update(0)

    @property
    def is_fsdp(self):
        return self.cfg.distributed_training.ddp_backend == "fully_sharded"

    def consolidate_optimizer(self):
        """For OSS, we need to consolidate the state dict."""
        if self.cfg.checkpoint.no_save_optimizer_state:
            return
        self._gathered_optim_state = None
        if hasattr(self.optimizer.optimizer, "consolidate_state_dict"):
            self.optimizer.optimizer.consolidate_state_dict()
        elif self.is_fsdp and not self.model.use_sharded_state:
            st = self.model.gather_full_optim_state_dict(
                self.optimizer
            )  # only returns on rank 0
            self._gathered_optim_state = st

    def state_dict(self):
        state_dict = {
            "args": None,  # legacy
            "cfg": (
                OmegaConf.to_container(self.cfg, resolve=True, enum_to_str=True)
                if OmegaConf.is_config(self.cfg)
                else self.cfg
            ),
            "model": self.model.state_dict(),
            "criterion": (
                self.criterion.state_dict()
                if utils.has_parameters(self.criterion)
                else None
            ),
            "optimizer_history": (self._optim_history or [])
            + [
                {
                    "criterion_name": self.get_criterion().__class__.__name__,
                    "optimizer_name": self.optimizer.__class__.__name__,
                    "lr_scheduler_state": self.lr_scheduler.state_dict(),
                    "num_updates": self.get_num_updates(),
                }
            ],
            "task_state": self.task.state_dict() if self.task is not None else {},
            "extra_state": {
                "metrics": metrics.state_dict(),
                "previous_training_time": self.cumulative_training_time(),
            },
        }
        if self.cfg.ema.store_ema:
            # Save EMA model state as extra state
            state_dict["extra_state"]["ema"] = self.ema.get_model().state_dict()
            if self.cfg.ema.ema_fp32:
                # Save EMA params in fp32
                state_dict["extra_state"]["ema_fp32_params"] = self.ema.fp32_params
        if not self.cfg.checkpoint.no_save_optimizer_state:
            if self._gathered_optim_state is not None:
                state_dict["last_optimizer_state"] = self._gathered_optim_state
                self._gathered_optim_state = None
            else:
                state_dict["last_optimizer_state"] = self.optimizer.state_dict()
        if self.is_fsdp:
            # save meta data for recombining checkpoint upon loading
            state_dict["fsdp_metadata"] = self.model.local_metadata_dict()
        return state_dict

    def save_checkpoint(self, filename, extra_state):
        """Save all training state in a checkpoint file."""

        logger.info(f"Saving checkpoint to {os.path.abspath(filename)}")
        # call state_dict on all ranks in case it needs internal communication
        state_dict = utils.move_to_cpu(self.state_dict())
        state_dict["extra_state"].update(extra_state)
        if self.should_save_checkpoint_on_current_rank:
            checkpoint_utils.torch_persistent_save(
                state_dict,
                filename,
                async_write=self.cfg.checkpoint.write_checkpoints_asynchronously,
            )
        logger.info(f"Finished saving checkpoint to {os.path.abspath(filename)}")

    def load_checkpoint(
        self,
        filename,
        reset_optimizer=False,
        reset_lr_scheduler=False,
        optimizer_overrides=None,
        reset_meters=False,
    ):
        """
        Load all training state from a checkpoint file.
        rank = 0 will load the checkpoint, and then broadcast it to all
        other ranks.
        """
        extra_state, self._optim_history, last_optim_state = None, [], None

        logger.info(f"Preparing to load checkpoint {filename}")
        is_distributed = self.data_parallel_world_size > 1
        bexists = PathManager.isfile(filename)
        if bexists:
            load_on_all_ranks = (
                self.cfg.checkpoint.load_checkpoint_on_all_dp_ranks
                # TPUs don't support broadcast yet, so load checkpoints
                # on every worker for now
                or self.tpu
                # FSDP requires loading checkpoint shards on all ranks
                or (self.is_fsdp and self.cfg.distributed_training.use_sharded_state)
                or getattr(self.cfg.model, "base_layers", 0) > 0
            )

            if load_on_all_ranks or self.data_parallel_rank == 0:
                state = checkpoint_utils.load_checkpoint_to_cpu(
                    filename, load_on_all_ranks=load_on_all_ranks
                )
                last_optim_state = state.get("last_optimizer_state", None)

                # If doing zero_sharding, do not broadcast global optimizer
                # state. Later we will broadcast sharded states to each rank
                # to avoid memory from exploding.
                if (
                    not load_on_all_ranks
                    and self.cfg.distributed_training.zero_sharding == "os"
                    and "last_optimizer_state" in state
                    and is_distributed
                ):
                    state["last_optimizer_state"] = "SHARDED"
            else:
                last_optim_state = None
                state = None

            if is_distributed and not load_on_all_ranks:
                state = distributed_utils.broadcast_object(
                    state,
                    src_rank=0,
                    group=self.data_parallel_process_group,
                    dist_device=self.device,
                )
                if self.data_parallel_rank > 0:
                    last_optim_state = state.get("last_optimizer_state", None)

            # load model parameters
            try:
                if (
                    "optimizer_history" in state
                    and len(state["optimizer_history"]) > 0
                    and "num_updates" in state["optimizer_history"][-1]
                ):
                    self.model.set_num_updates(
                        state["optimizer_history"][-1]["num_updates"]
                    )

                # this is the code related to AdaPrune
                # In short, it removes redundant heads in multi-head attention module based on heads importance provided
                # For more info, please refer to the paper: https://openreview.net/forum?id=_CMSV7FTzGI
                # The idea of prune in mha can be summarized as
                # Fine tune model (e.g. roberta encoder) on a certain datasets with regularization
                # After the model is trained. User could use get_reserve_head_index and _adaptive_prune_heads functions to get the top X heads with most importance.
                # Then user uses the rank to prune a new roberta encoder and save the pruned ckpt manually.
                # User will fine tune the the new roberta encoder via the ckpt saved above
                # To get rid of registering different pruned version of Roberta, I use the argument --mha-heads-to-keep to prune the Roberta model into a pruned version which matches the pruned ckpt.
                if (
                    safe_hasattr(self.model, "args")
                    and safe_hasattr(self.model.args, "mha_heads_to_keep")
                    and self.model.args.mha_heads_to_keep != -1
                ):
                    logger.info(
                        f"Prune model: keep {self.model.args.mha_heads_to_keep} heads for each multihead attention module"
                    )
                    for layer in self.model.encoder.sentence_encoder.layers:
                        reserve_head_index = layer.self_attn._get_reserve_head_index(
                            num_heads_to_keep=self.model.args.mha_heads_to_keep
                        )
                        layer.self_attn._adaptive_prune_heads(
                            reserve_head_index=reserve_head_index
                        )
                        layer.self_attn._set_skip_embed_dim_check()
                    logger.info(self.model)
                # this is the code related to AdaPrune
                # In short, it removes redundant units in feedforward layer in each transformer layer based on importance
                # For more info, please refer to the paper: https://openreview.net/forum?id=_CMSV7FTzGI
                # The idea of prune in ffn can be summarized as
                # Fine tune model (e.g. roberta encoder) on a certain datasets with regularization
                # After the model is trained. User could use _get_fc_rank and _prune_fc_layer functions to get the top X units with most importance.
                # Then user uses the rank to prune a new roberta encoder and save the pruned ckpt manually.
                # User will fine tune the the new roberta encoder via the ckpt saved above
                # To get rid of registering different pruned version of Roberta, I use the argument --ffn-blocks-to-remove to prune the Roberta model into a pruned version which matches the pruned ckpt.
                if (
                    safe_hasattr(self.model, "args")
                    and safe_hasattr(self.model.args, "ffn_blocks_to_remove")
                    and self.model.args.ffn_blocks_to_remove != -1
                ):
                    logger.info(
                        f"Prune model: remove {self.model.args.ffn_blocks_to_remove} ffn blocks for each transformer layer"
                    )
                    for layer in self.model.encoder.sentence_encoder.layers:
                        remove_index = layer._get_fc_rank(
                            remove_num=self.model.args.ffn_blocks_to_remove
                        )
                        layer._prune_fc_layer(remove_index=remove_index)
                    logger.info(self.model)

                self.model.load_state_dict(
                    state["model"], strict=True, model_cfg=self.cfg.model
                )
                # save memory for later steps
                del state["model"]
                if utils.has_parameters(self.get_criterion()):
                    self.get_criterion().load_state_dict(
                        state["criterion"], strict=True
                    )
                    del state["criterion"]

            except Exception:
                raise Exception(
                    "Cannot load model parameters from checkpoint {}; "
                    "please ensure that the architectures match.".format(filename)
                )
            extra_state = state["extra_state"]
            self._optim_history = state["optimizer_history"]

        if last_optim_state is not None and not reset_optimizer:
            # rebuild optimizer after loading model, since params may have changed
            self._build_optimizer()

            # only reload optimizer and lr_scheduler if they match
            last_optim = self._optim_history[-1]
            assert (
                last_optim["criterion_name"] == self.get_criterion().__class__.__name__
            ), f"Criterion does not match; please reset the optimizer (--reset-optimizer). {last_optim['criterion_name']} vs {self.get_criterion().__class__.__name__}"
            assert (
                last_optim["optimizer_name"] == self.optimizer.__class__.__name__
            ), f"Optimizer does not match; please reset the optimizer (--reset-optimizer). {last_optim['optimizer_name']} vs {self.optimizer.__class__.__name__}"

            if not reset_lr_scheduler:
                self.lr_scheduler.load_state_dict(last_optim["lr_scheduler_state"])

            if self.is_fsdp and not self.model.use_sharded_state:
                # if use_sharded_state, the last_optim_state is already sharded, skip this
                last_optim_state = self.model.get_shard_from_optim_state_dict(
                    last_optim_state
                )
            elif not load_on_all_ranks and is_distributed:
                last_optim_state = self.optimizer.broadcast_global_state_dict(
                    last_optim_state
                )

            self.optimizer.load_state_dict(last_optim_state, optimizer_overrides)

            self.set_num_updates(last_optim["num_updates"])

        if extra_state is not None:
            itr_state = extra_state["train_iterator"]
            epoch = itr_state["epoch"]

            if "previous_training_time" in extra_state:
                self._previous_training_time = extra_state["previous_training_time"]
                self._start_time = time.time()

            self.lr_step(epoch)

            if (
                itr_state.get("version", 1) >= 2
                and itr_state["iterations_in_epoch"] == 0
            ):
                # reset meters at start of epoch
                reset_meters = True

            if "metrics" in extra_state and not reset_meters:
                metrics.load_state_dict(extra_state["metrics"])

                # reset TimeMeters, since their start times don't make sense anymore
                for meter in metrics.get_meters("default"):
                    if isinstance(meter, meters.TimeMeter):
                        meter.reset()

            if self.cfg.ema.store_ema:
                if "ema" not in extra_state:
                    logger.warn(
                        "EMA not found in checkpoint. But store_ema is True. "
                        "EMA is re-initialized from checkpoint."
                    )
                    self.ema.restore(
                        state["model"], build_fp32_params=self.cfg.ema.ema_fp32
                    )
                else:
                    logger.info("Loading EMA from checkpoint")
                    self.ema.restore(extra_state["ema"], build_fp32_params=False)

                    if self.cfg.ema.ema_fp32:
                        if "ema_fp32_params" in extra_state:
                            logger.info("Loading EMA fp32 params from checkpoint")
                            self.ema.build_fp32_params(extra_state["ema_fp32_params"])
                        else:
                            logger.info(
                                "Building EMA fp32 params from EMA model in checkpoint"
                            )
                            self.ema.build_fp32_params()

            logger.info(
                "Loaded checkpoint {} (epoch {} @ {} updates)".format(
                    filename, epoch, self.get_num_updates()
                )
            )

        else:
            logger.info("No existing checkpoint found {}".format(filename))

        return extra_state

    def get_train_iterator(
        self,
        epoch,
        combine=True,
        load_dataset=True,
        data_selector=None,
        shard_batch_itr=True,
        disable_iterator_cache=False,
    ):
        """Return an EpochBatchIterator over the training set for a given epoch."""
        if load_dataset:
            logger.info("loading train data for epoch {}".format(epoch))
            self.task.load_dataset(
                self.cfg.dataset.train_subset,
                epoch=epoch,
                combine=combine,
                data_selector=data_selector,
                tpu=self.tpu,
            )
        batch_iterator = self.task.get_batch_iterator(
            dataset=self.task.dataset(self.cfg.dataset.train_subset),
            max_tokens=self.cfg.dataset.max_tokens,
            max_sentences=self.cfg.dataset.batch_size,
            max_positions=utils.resolve_max_positions(
                self.task.max_positions(),
                self.model.max_positions(),
                self.cfg.dataset.max_tokens,
            ),
            ignore_invalid_inputs=True,
            required_batch_size_multiple=self.cfg.dataset.required_batch_size_multiple,
            seed=(self.cfg.common.seed + epoch)
            if self.cfg.dataset.update_ordered_indices_seed
            else self.cfg.common.seed,
            num_shards=self.data_parallel_world_size if shard_batch_itr else 1,
            shard_id=self.data_parallel_rank if shard_batch_itr else 0,
            num_workers=self.cfg.dataset.num_workers,
            epoch=epoch,
            data_buffer_size=self.cfg.dataset.data_buffer_size,
            disable_iterator_cache=disable_iterator_cache,
            skip_remainder_batch=self.cfg.optimization.skip_remainder_batch,
            grouped_shuffling=self.cfg.dataset.grouped_shuffling,
            update_epoch_batch_itr=self.cfg.dataset.update_epoch_batch_itr,
        )
        self.reset_dummy_batch(batch_iterator.first_batch)
        return batch_iterator

    def get_valid_iterator(
        self,
        subset,
        disable_iterator_cache=False,
    ):
        """Return an EpochBatchIterator over given validation subset for a given epoch."""
        batch_iterator = self.task.get_batch_iterator(
            dataset=self.task.dataset(subset),
            max_tokens=self.cfg.dataset.max_tokens_valid,
            max_sentences=self.cfg.dataset.batch_size_valid,
            max_positions=utils.resolve_max_positions(
                self.task.max_positions(),
                self.model.max_positions(),
            ),
            ignore_invalid_inputs=self.cfg.dataset.skip_invalid_size_inputs_valid_test,
            required_batch_size_multiple=self.cfg.dataset.required_batch_size_multiple,
            seed=self.cfg.common.seed,
            num_shards=self.data_parallel_world_size,
            shard_id=self.data_parallel_rank,
            num_workers=self.cfg.dataset.num_workers,
            # always pass a fixed "epoch" to keep validation data consistent
            # across training epochs
            epoch=1,
            data_buffer_size=self.cfg.dataset.data_buffer_size,
            disable_iterator_cache=disable_iterator_cache,
            skip_remainder_batch=False,
        )
        self.reset_dummy_batch(batch_iterator.first_batch)
        return batch_iterator

    def begin_epoch(self, epoch):
        """Called at the beginning of each epoch."""
        logger.info("begin training epoch {}".format(epoch))

        self.lr_step_begin_epoch(epoch)

        if self.quantizer is not None:
            self.quantizer.begin_epoch(epoch)

        # task specific setup per epoch
        self.task.begin_epoch(epoch, self.get_model())

        if self.tpu:
            import torch_xla.core.xla_model as xm

            xm.rendezvous("begin_epoch")  # wait for all workers
            xm.mark_step()

    def begin_valid_epoch(self, epoch):
        """Called at the beginning of each validation epoch."""

        # task specific setup per validation epoch
        self.task.begin_valid_epoch(epoch, self.get_model())

    def reset_dummy_batch(self, batch):
        self._dummy_batch = batch

    @metrics.aggregate("train")
    def train_step(self, samples, raise_oom=False, **kwargs):
        """Do forward, backward and parameter update."""
        self._set_seed()
        self.model.train()
        self.criterion.train()
        self.zero_grad()

        metrics.log_start_time("train_wall", priority=800, round=0)

        # If EMA is enabled through store_ema=True
        # and task.uses_ema is True, pass the EMA model as a keyword
        # argument to the task.
        extra_kwargs = {}
        if self.cfg.ema.store_ema and getattr(self.task, "uses_ema", False):
            extra_kwargs["ema_model"] = self.ema.get_model()

        if 'teacher' in kwargs:
            extra_kwargs['teacher'] = kwargs['teacher']

        # forward and backward pass
        logging_outputs, sample_size, ooms = [], 0, 0
        for i, sample in enumerate(samples):  # delayed update loop
            sample, is_dummy_batch = self._prepare_sample(sample)

            def maybe_no_sync():
                """
                Whenever *samples* contains more than one mini-batch, we
                want to accumulate gradients locally and only call
                all-reduce in the last backwards pass.
                """
                if (
                    self.data_parallel_world_size > 1
                    and hasattr(self.model, "no_sync")
                    and i < len(samples) - 1
                    # The no_sync context manager results in increased memory
                    # usage with FSDP, since full-size gradients will be
                    # accumulated on each GPU. It's typically a better tradeoff
                    # to do the extra communication with FSDP.
                    and not self.is_fsdp
                ):
                    return self.model.no_sync()
                else:
                    return contextlib.ExitStack()  # dummy contextmanager

            try:
                with maybe_no_sync():
                    # forward and backward
                    loss, sample_size_i, logging_output = self.task.train_step(
                        sample=sample,
                        model=self.model,
                        criterion=self.criterion,
                        optimizer=self.optimizer,
                        update_num=self.get_num_updates(),
                        ignore_grad=is_dummy_batch,
                        **extra_kwargs,
                    )
                    del loss

                logging_outputs.append(logging_output)
                sample_size += sample_size_i

                # emptying the CUDA cache after the first step can
                # reduce the chance of OOM
                if self.cuda and self.get_num_updates() == 0:
                    torch.cuda.empty_cache()
            except RuntimeError as e:
                if "out of memory" in str(e):
                    self._log_oom(e)
                    if raise_oom:
                        raise e
                    logger.warning(
                        "attempting to recover from OOM in forward/backward pass"
                    )
                    ooms += 1
                    self.zero_grad()
                    if self.cuda:
                        torch.cuda.empty_cache()
                    if self.cfg.distributed_training.distributed_world_size == 1:
                        return None
                else:
                    raise e
            except Exception:
                self.consolidate_optimizer()
                self.save_checkpoint(
                    os.path.join(self.cfg.checkpoint.save_dir, "crash.pt"), {}
                )
                raise

            if self.tpu and i < len(samples) - 1:
                # tpu-comment: every XLA operation before marking step is
                # appended to the IR graph, and processing too many batches
                # before marking step can lead to OOM errors.
                # To handle gradient accumulation use case, we explicitly
                # mark step here for every forward pass without a backward pass
                self._xla_markstep_and_send_to_cpu()

        if is_dummy_batch:
            if torch.is_tensor(sample_size):
                sample_size.zero_()
            else:
                sample_size *= 0.0

        if torch.is_tensor(sample_size):
            sample_size = sample_size.float()
        else:
            sample_size = float(sample_size)

        # gather logging outputs from all replicas
        if self._sync_stats():
            train_time = self._local_cumulative_training_time()
            (
                logging_outputs,
                (
                    sample_size,
                    ooms,
                    total_train_time,
                ),
            ) = self._aggregate_logging_outputs(
                logging_outputs, sample_size, ooms, train_time, ignore=is_dummy_batch
            )
            self._cumulative_training_time = (
                total_train_time / self.data_parallel_world_size
            )

        overflow = False
        try:
            with torch.autograd.profiler.record_function("reduce-grads"):
                # reduce gradients across workers
                self.optimizer.all_reduce_grads(self.model)
                if utils.has_parameters(self.criterion):
                    self.optimizer.all_reduce_grads(self.criterion)

            with torch.autograd.profiler.record_function("multiply-grads"):
                # multiply gradients by (data_parallel_size / sample_size) since
                # DDP normalizes by the number of data parallel workers for
                # improved fp16 precision.
                # Thus we get (sum_of_gradients / sample_size) at the end.
                # In case of fp16, this step also undoes loss scaling.
                # (Debugging note: Some optimizers perform this scaling on the
                # fly, so inspecting model.parameters() or optimizer.params may
                # still show the original, unscaled gradients.)
                numer = (
                    self.data_parallel_world_size
                    if not self.cfg.optimization.use_bmuf or self._sync_stats()
                    else 1
                )
                self.optimizer.multiply_grads(numer / (sample_size or 1.0))
                # Note: (sample_size or 1.0) handles the case of a zero gradient, in a
                # way that avoids CPU/device transfers in case sample_size is a GPU or
                # TPU object. The assumption is that the gradient itself is also 0.

            with torch.autograd.profiler.record_function("clip-grads"):
                # clip grads
                grad_norm = self.clip_grad_norm(self.cfg.optimization.clip_norm)

            # check that grad norms are consistent across workers
            # on tpu check tensor is slow
            if not self.tpu:
                if (
                    not self.cfg.optimization.use_bmuf
                    and self.cfg.distributed_training.ddp_backend != "slowmo"
                ):
                    self._check_grad_norms(grad_norm)
                if not torch.isfinite(grad_norm).all():
                    # in case of AMP, if gradients are Nan/Inf then
                    # optimizer step is still required
                    if self.cfg.common.amp:
                        overflow = True
                    else:
                        # check local gradnorm single GPU case, trigger NanDetector
                        raise FloatingPointError("gradients are Nan/Inf")

            with torch.autograd.profiler.record_function("optimizer"):
                # take an optimization step
                self.task.optimizer_step(
                    self.optimizer, model=self.model, update_num=self.get_num_updates()
                )
                if self.cfg.common.amp and overflow:
                    if self._amp_retries == self.cfg.common.amp_batch_retries:
                        logger.info("AMP: skipping this batch.")
                        self._amp_retries = 0
                    else:
                        self._amp_retries += 1
                        return self.train_step(
                            samples, raise_oom
                        )  # recursion to feed in same batch

        except FloatingPointError:

            self.consolidate_optimizer()
            self.save_checkpoint(
                os.path.join(self.cfg.checkpoint.save_dir, "crash.pt"), {}
            )

            # re-run the forward and backward pass with hooks attached to print
            # out where it fails
            self.zero_grad()
            with NanDetector(self.get_model()):
                for _, sample in enumerate(samples):
                    sample, _ = self._prepare_sample(sample)
                    self.task.train_step(
                        sample,
                        self.model,
                        self.criterion,
                        self.optimizer,
                        self.get_num_updates(),
                        ignore_grad=False,
                        **extra_kwargs,
                    )
            raise
        except OverflowError as e:
            overflow = True
            logger.info(
                f"NOTE: gradient overflow detected, ignoring gradient, {str(e)}"
            )
            grad_norm = torch.tensor(0.0).cuda()
            self.zero_grad()
        except RuntimeError as e:
            if "out of memory" in str(e):
                self._log_oom(e)
                logger.error("OOM during optimization, irrecoverable")
            raise e

        # Some distributed wrappers (e.g., SlowMo) need access to the optimizer
        # after the step
        if hasattr(self.model, "perform_slowmo"):
            self.model.perform_slowmo(
                self.optimizer.optimizer, getattr(self.optimizer, "fp32_params", None)
            )

        logging_output = None
        if not overflow or self.cfg.distributed_training.ddp_backend == "slowmo":
            self.set_num_updates(self.get_num_updates() + 1)

            if self.cfg.ema.store_ema:
                # Step EMA forward with new model.
                self.ema.step(
                    self.get_model(),
                    self.get_num_updates(),
                )
                metrics.log_scalar(
                    "ema_decay",
                    self.ema.get_decay(),
                    priority=10000,
                    round=5,
                    weight=0,
                )

            if self.tpu:
                import torch_xla.core.xla_model as xm

                # mark step on TPUs
                self._xla_markstep_and_send_to_cpu()

                # only log stats every log_interval steps
                # this causes wps to be misreported when log_interval > 1
                logging_output = {}
                if self.get_num_updates() % self.cfg.common.log_interval == 0:
                    # log memory usage
                    mem_info = xm.get_memory_info(self.device)
                    gb_free = mem_info["kb_free"] / 1024 / 1024
                    gb_total = mem_info["kb_total"] / 1024 / 1024
                    metrics.log_scalar(
                        "gb_free", gb_free, priority=1500, round=1, weight=0
                    )
                    metrics.log_scalar(
                        "gb_total", gb_total, priority=1600, round=1, weight=0
                    )
                    logging_outputs = self._xla_markstep_and_send_to_cpu(
                        logging_outputs
                    )
                    logging_output = self._reduce_and_log_stats(
                        logging_outputs, sample_size, grad_norm
                    )

                # log whenever there's an XLA compilation, since these
                # slow down training and may indicate opportunities for
                # optimization
                self._check_xla_compilation()
            else:
                if self.cuda and self.cuda_env is not None:
                    # log minimum free memory over the iteration
                    gb_used = torch.cuda.max_memory_allocated() / 1024 / 1024 / 1024
                    torch.cuda.reset_peak_memory_stats()
                    gb_free = self.cuda_env.total_memory_in_GB - gb_used
                    metrics.log_scalar(
                        "gb_free", gb_free, priority=1500, round=1, weight=0
                    )

                # log stats
                logging_output = self._reduce_and_log_stats(
                    logging_outputs, sample_size, grad_norm
                )

                # clear CUDA cache to reduce memory fragmentation
                if (
                    self.cuda
                    and self.cfg.common.empty_cache_freq > 0
                    and (
                        (self.get_num_updates() + self.cfg.common.empty_cache_freq - 1)
                        % self.cfg.common.empty_cache_freq
                    )
                    == 0
                ):
                    torch.cuda.empty_cache()

        if self.cfg.common.fp16 or self.cfg.common.amp:
            metrics.log_scalar(
                "loss_scale",
                (
                    self.optimizer.scaler.loss_scale
                    if self.cfg.common.fp16
                    else self.optimizer.scaler.get_scale()
                ),
                priority=700,
                round=4,
                weight=0,
            )

        metrics.log_stop_time("train_wall")
        return logging_output

    @metrics.aggregate("valid")
    def valid_step(self, sample, raise_oom=False):
        """Do forward pass in evaluation mode."""
        if self.tpu:
            import torch_xla.core.xla_model as xm

            xm.rendezvous("valid_step")  # wait for all workers

        # If EMA is enabled through store_ema=True
        # and task.uses_ema is True, pass the EMA model as a keyword
        # argument to the task.
        extra_kwargs = {}
        if self.cfg.ema.store_ema and getattr(self.task, "uses_ema", False):
            extra_kwargs["ema_model"] = self.ema.get_model()

        with torch.no_grad():
            self.model.eval()
            self.criterion.eval()

            sample, is_dummy_batch = self._prepare_sample(sample)

            try:
                _loss, sample_size, logging_output = self.task.valid_step(
                    sample, self.model, self.criterion, **extra_kwargs
                )
            except RuntimeError as e:
                if "out of memory" in str(e):
                    self._log_oom(e)
                    if not raise_oom:
                        logger.warning(
                            "ran out of memory in validation step, retrying batch"
                        )
                        for p in self.model.parameters():
                            if p.grad is not None:
                                p.grad = None  # free some memory
                        if self.cuda:
                            torch.cuda.empty_cache()
                        return self.valid_step(sample, raise_oom=True)
                raise e

            logging_outputs = [logging_output]
            if is_dummy_batch:
                if torch.is_tensor(sample_size):
                    sample_size.zero_()
                else:
                    sample_size *= 0.0

        # gather logging outputs from all replicas
        if self.data_parallel_world_size > 1:
            logging_outputs, (sample_size,) = self._aggregate_logging_outputs(
                logging_outputs,
                sample_size,
                ignore=is_dummy_batch,
            )

        # log validation stats
        if self.tpu:
            logging_outputs = self._xla_markstep_and_send_to_cpu(logging_outputs)
        logging_output = self._reduce_and_log_stats(logging_outputs, sample_size)

        return logging_output

    def zero_grad(self):
        self.optimizer.zero_grad()

    def lr_step_begin_epoch(self, epoch):
        """Adjust the learning rate at the beginning of the epoch."""
        self.lr_scheduler.step_begin_epoch(epoch)
        # prefer updating the LR based on the number of steps
        return self.lr_step_update()

    def lr_step(self, epoch, val_loss=None):
        """Adjust the learning rate at the end of the epoch."""
        self.lr_scheduler.step(epoch, val_loss)
        # prefer updating the LR based on the number of steps
        return self.lr_step_update()

    def lr_step_update(self):
        """Update the learning rate after each update."""
        new_lr = self.lr_scheduler.step_update(self.get_num_updates())
        if isinstance(new_lr, dict):
            for k, v in new_lr.items():
                metrics.log_scalar(f"lr_{k}", v, weight=0, priority=300)
            new_lr = new_lr.get("default", next(iter(new_lr.values())))
        else:
            metrics.log_scalar("lr", new_lr, weight=0, priority=300)
        return new_lr

    def get_lr(self):
        """Get the current learning rate."""
        return self.optimizer.get_lr()

    def get_model(self):
        """Get the (non-wrapped) model instance."""
        return self._model

    def get_criterion(self):
        """Get the (non-wrapped) criterion instance."""
        return self._criterion

    def get_meter(self, name):
        """[deprecated] Get a specific meter by name."""
        from fairseq import meters

        if "get_meter" not in self._warn_once:
            self._warn_once.add("get_meter")
            utils.deprecation_warning(
                "Trainer.get_meter is deprecated. Please use fairseq.metrics instead."
            )

        train_meters = metrics.get_meters("train")
        if train_meters is None:
            train_meters = {}

        if name == "train_loss" and "loss" in train_meters:
            return train_meters["loss"]
        elif name == "train_nll_loss":
            # support for legacy train.py, which assumed this meter is
            # always initialized
            m = train_meters.get("nll_loss", None)
            return m or meters.AverageMeter()
        elif name == "wall":
            # support for legacy train.py, which assumed this meter is
            # always initialized
            m = metrics.get_meter("default", "wall")
            return m or meters.TimeMeter()
        elif name == "wps":
            m = metrics.get_meter("train", "wps")
            return m or meters.TimeMeter()
        elif name in {"valid_loss", "valid_nll_loss"}:
            # support for legacy train.py, which assumed these meters
            # are always initialized
            k = name[len("valid_") :]
            m = metrics.get_meter("valid", k)
            return m or meters.AverageMeter()
        elif name == "oom":
            return meters.AverageMeter()
        elif name in train_meters:
            return train_meters[name]
        return None

    def get_num_updates(self):
        """Get the number of parameters updates."""
        return self._num_updates

    def set_num_updates(self, num_updates):
        """Set the number of parameters updates."""
        self._num_updates = num_updates
        self.lr_step_update()
        if self.quantizer:
            self.quantizer.step_update(self._num_updates)
        metrics.log_scalar("num_updates", self._num_updates, weight=0, priority=200)

    def clip_grad_norm(self, clip_norm):
        def agg_norm_fn(total_norm):
            total_norm = total_norm.cuda().float() ** 2
            total_norm = distributed_utils.all_reduce(
                total_norm, group=self.data_parallel_process_group
            )
            return total_norm**0.5

        should_agg_norm = self.is_fsdp and (
            self.data_parallel_process_group is not None
            or torch.distributed.is_initialized()
        )
        return self.optimizer.clip_grad_norm(
            clip_norm, aggregate_norm_fn=agg_norm_fn if should_agg_norm else None
        )

    def cumulative_training_time(self):
        if self._cumulative_training_time is None:
            # single GPU
            return self._local_cumulative_training_time()
        else:
            return self._cumulative_training_time

    def _local_cumulative_training_time(self):
        """Aggregate training time in seconds."""
        return time.time() - self._start_time + self._previous_training_time

    def _fp_convert_sample(self, sample):
        def apply_half(t):
            if t.dtype is torch.float32:
                return t.to(dtype=torch.half)
            return t

        def apply_bfloat16(t):
            if t.dtype is torch.float32:
                return t.to(dtype=torch.bfloat16)
            return t

        if self.cfg.common.fp16:
            sample = utils.apply_to_sample(apply_half, sample)

        if self.cfg.common.bf16:
            sample = utils.apply_to_sample(apply_bfloat16, sample)

        return sample

    def _prepare_sample(self, sample, is_dummy=False):
        if sample == "DUMMY":
            raise Exception(
                "Trying to use an uninitialized 'dummy' batch. This usually indicates "
                "that the total number of batches is smaller than the number of "
                "participating GPUs. Try reducing the batch size or using fewer GPUs."
            )

        if sample is None or len(sample) == 0:
            assert (
                self._dummy_batch is not None and len(self._dummy_batch) > 0
            ), "Invalid dummy batch: {}".format(self._dummy_batch)
            sample, _ = self._prepare_sample(self._dummy_batch, is_dummy=True)
            return sample, True

        # Given that PCIe/NVLink bandwidth is significantly smaller than DRAM bandwidth
        # it makes sense to do the format conversion on the CPU and then transfer
        # a smaller buffer to the device. This also saves GPU memory capacity.

        if self.cfg.common.on_cpu_convert_precision:
            sample = self._fp_convert_sample(sample)

        if self.cuda:
            if self.pipeline_model_parallel:
                if "target" in sample:
                    sample["target"] = utils.move_to_cuda(
                        sample["target"], device=self.last_device
                    )
            else:
                sample = utils.move_to_cuda(sample)
        elif self.tpu and is_dummy:
            # the dummy batch may not be on the appropriate device
            sample = utils.move_to_cuda(sample, device=self.device)

        if not self.cfg.common.on_cpu_convert_precision:
            sample = self._fp_convert_sample(sample)

        if self._dummy_batch == "DUMMY":
            self._dummy_batch = sample

        return sample, False

    def _set_seed(self):
        # Set seed based on args.seed and the update number so that we get
        # reproducible results when resuming from checkpoints
        seed = self.cfg.common.seed + self.get_num_updates()
        utils.set_torch_seed(seed)

    def _sync_stats(self):
        # Return True if it's using multiple GPUs and DDP or multiple GPUs with
        # BMUF and it's a bmuf sync with warmup iterations completed before.
        if self.data_parallel_world_size == 1:
            return False
        elif self.cfg.optimization.use_bmuf:
            return (
                self.get_num_updates() + 1
            ) % self.cfg.bmuf.global_sync_iter == 0 and (
                self.get_num_updates() + 1
            ) > self.cfg.bmuf.warmup_iterations
        else:
            return True

    def _log_oom(self, exc):
        msg = "OOM: Ran out of memory with exception: {}".format(exc)
        logger.warning(msg)
        if torch.cuda.is_available() and hasattr(torch.cuda, "memory_summary"):
            for device_idx in range(torch.cuda.device_count()):
                logger.warning(torch.cuda.memory_summary(device=device_idx))
        sys.stderr.flush()

    def _aggregate_logging_outputs(
        self,
        logging_outputs: List[Dict[str, Any]],
        *extra_stats_to_sum,
        ignore=False,
    ):
        if self.task.__class__.logging_outputs_can_be_summed(self.get_criterion()):
            return self._fast_stat_sync_sum(
                logging_outputs, *extra_stats_to_sum, ignore=ignore
            )
        else:
            return self._all_gather_list_sync(
                logging_outputs, *extra_stats_to_sum, ignore=ignore
            )

    def _all_gather_list_sync(
        self,
        logging_outputs: List[Dict[str, Any]],
        *extra_stats_to_sum,
        ignore=False,
    ):
        """
        Sync logging outputs across workers. all_gather_list_sync is
        suitable when logging outputs are complex types.
        """
        if self.tpu:
            raise NotImplementedError
        if ignore:
            logging_outputs = []
        results = list(
            zip(
                *distributed_utils.all_gather_list(
                    [logging_outputs] + list(extra_stats_to_sum),
                    max_size=getattr(self.cfg.common, "all_gather_list_size", 16384),
                    group=self.data_parallel_process_group,
                )
            )
        )
        logging_outputs, extra_stats_to_sum = results[0], results[1:]
        logging_outputs = list(chain.from_iterable(logging_outputs))
        extra_stats_to_sum = [sum(s) for s in extra_stats_to_sum]
        return logging_outputs, extra_stats_to_sum

    def _fast_stat_sync_sum(
        self,
        logging_outputs: List[Dict[str, Any]],
        *extra_stats_to_sum,
        ignore=False,
    ):
        """
        Sync logging outputs across workers. fast_stat_sync_sum is
        faster than all_gather_list_sync, but is only suitable when
        logging outputs are scalars and can be summed. Note that
        *logging_outputs* cannot contain any nested dicts/lists.
        """
        data = {}
        for i, stat in enumerate(extra_stats_to_sum):
            data["extra_stats_" + str(i)] = stat
        if len(logging_outputs) > 0:
            log_keys = list(logging_outputs[0].keys())
            for k in log_keys:
                if not ignore:
                    v = sum(log[k] for log in logging_outputs if k in log)
                else:
                    v = logging_outputs[0][k]
                    v = torch.zeros_like(v) if torch.is_tensor(v) else 0
                data["logging_outputs_" + k] = v
        else:
            log_keys = None

        data = distributed_utils.all_reduce_dict(
            data, device=self.device, group=self.data_parallel_process_group
        )

        extra_stats_to_sum = [
            data["extra_stats_" + str(i)] for i in range(len(extra_stats_to_sum))
        ]
        if log_keys is not None:
            logging_outputs = [{k: data["logging_outputs_" + k] for k in log_keys}]
        else:
            logging_outputs = []
        return logging_outputs, extra_stats_to_sum

    def _check_grad_norms(self, grad_norm):
        """Check that grad norms are consistent across workers."""
        if self._grad_norm_buf is not None:
            self._grad_norm_buf.zero_()
            self._grad_norm_buf[self.data_parallel_rank] = grad_norm
            distributed_utils.all_reduce(
                self._grad_norm_buf, group=self.data_parallel_process_group
            )

            def is_consistent(tensor):
                max_abs_diff = torch.max(torch.abs(tensor - tensor[0]))
                return (
                    (
                        torch.isfinite(tensor).all()
                        and (max_abs_diff / (tensor[0] + 1e-6) < 1e-6).all()
                    )
                    or (self.cfg.common.amp and not torch.isfinite(tensor).all())
                    # in case of amp non-finite grads are fine
                )

            if not is_consistent(self._grad_norm_buf):
                pretty_detail = "\n".join(
                    "rank {:3d} = {:.8f}".format(r, n)
                    for r, n in enumerate(self._grad_norm_buf.tolist())
                )
                error_detail = "grad_norm across the workers:\n{}\n".format(
                    pretty_detail
                )
                # use FloatingPointError to trigger NanDetector
                raise FloatingPointError(
                    "Fatal error: gradients are inconsistent between workers. "
                    "Try --ddp-backend=legacy_ddp. "
                    "Or are you mixing up different generation of GPUs in training?"
                    + "\n"
                    + "-" * 80
                    + "\n{}\n".format(error_detail)
                    + "-" * 80
                )

    def _reduce_and_log_stats(self, logging_outputs, sample_size, grad_norm=None):
        if grad_norm is not None and (
            not torch.is_tensor(grad_norm) or torch.isfinite(grad_norm)
        ):
            metrics.log_speed("ups", 1.0, priority=100, round=2)
            metrics.log_scalar("gnorm", grad_norm, priority=400, round=3)
            if self.cfg.optimization.clip_norm > 0:
                metrics.log_scalar(
                    "clip",
                    torch.where(
                        grad_norm > self.cfg.optimization.clip_norm,
                        grad_norm.new_tensor(100),
                        grad_norm.new_tensor(0),
                    ),
                    priority=500,
                    round=1,
                )

        with metrics.aggregate() as agg:
            if logging_outputs is not None:
                self.task.reduce_metrics(logging_outputs, self.get_criterion())
                del logging_outputs

            # extra warning for criterions that don't properly log a loss value
            if "loss" not in agg:
                if "loss" not in self._warn_once:
                    self._warn_once.add("loss")
                    logger.warning(
                        "Criterion.reduce_metrics did not log a 'loss' value, "
                        "which may break some functionality"
                    )
                metrics.log_scalar("loss", -1)

            # support legacy interface
            if self.tpu:
                logging_output = {}
            else:
                logging_output = agg.get_smoothed_values()
                logging_output["sample_size"] = sample_size
                for key_to_delete in ["ppl", "wps", "wpb", "bsz"]:
                    if key_to_delete in logging_output:
                        del logging_output[key_to_delete]
            return logging_output

    def _check_xla_compilation(self):
        import torch_xla.debug.metrics as met

        compile_stats = met.metric_data("CompileTime")
        if compile_stats is None:
            return
        num_xla_compiles = compile_stats[0]
        if num_xla_compiles > self._num_xla_compiles:
            logger.warning(
                "XLA compilation detected on device #{}; too many of these can lead "
                "to slow training, but we expect a few in the beginning".format(
                    self.cfg.distributed_training.distributed_rank
                )
            )
        self._num_xla_compiles = num_xla_compiles

    def _xla_markstep_and_send_to_cpu(self, data=None):
        import torch_xla.core.xla_model as xm

        xm.mark_step()
        if data is not None:
            from fairseq.utils import xla_device_to_cpu

            return xla_device_to_cpu(data)


def _catalog_shared_params(module, memo=None, prefix=""):
    if memo is None:
        first_call = True
        memo = {}
    else:
        first_call = False
    for name, param in module._parameters.items():
        param_prefix = prefix + ("." if prefix else "") + name
        if param not in memo:
            memo[param] = []
        memo[param].append(param_prefix)
    for name, m in module._modules.items():
        if m is None:
            continue
        submodule_prefix = prefix + ("." if prefix else "") + name
        _catalog_shared_params(m, memo, submodule_prefix)
    if first_call:
        return [x for x in memo.values() if len(x) > 1]


def _get_module_by_path(module, path):
    path = path.split(".")
    for name in path:
        module = getattr(module, name)
    return module


def _set_module_by_path(module, path, value):
    path = path.split(".")
    for name in path[:-1]:
        module = getattr(module, name)
    setattr(module, path[-1], value)
# Out:
# Overwriting /kaggle/working/kNN-TL/kNN-TL/fairseq/trainer.py

# %%
# %%writefile /kaggle/working/kNN-TL/kNN-TL/fairseq/tasks/translation.py
# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

from dataclasses import dataclass, field
import itertools
import json
import logging
import os
from typing import Optional
from argparse import Namespace
from omegaconf import II

import numpy as np
from fairseq import metrics, utils
from fairseq.data import (
    AppendTokenDataset,
    ConcatDataset,
    LanguagePairDataset,
    PrependTokenDataset,
    StripTokenDataset,
    TruncateDataset,
    data_utils,
    encoders,
    indexed_dataset,
)
from fairseq.data.indexed_dataset import get_available_dataset_impl
from fairseq.dataclass import ChoiceEnum, FairseqDataclass
from fairseq.tasks import FairseqTask, register_task
import torch
from fairseq.optim.amp_optimizer import AMPOptimizer
EVAL_BLEU_ORDER = 4

CUT_OFF = ChoiceEnum(['disentangled','normal','tri_cut_off','none', 'none_cut_off'])
MASK = ChoiceEnum(['word', 'span'])
TRI_FUNCTION = ChoiceEnum(['tri_kl','tri_js', 'tri_real_js'])
logger = logging.getLogger(__name__)


def load_langpair_dataset(
    data_path,
    split,
    src,
    src_dict,
    tgt,
    tgt_dict,
    combine,
    dataset_impl,
    upsample_primary,
    left_pad_source,
    left_pad_target,
    max_source_positions,
    max_target_positions,
    prepend_bos=False,
    load_alignments=False,
    truncate_source=False,
    append_source_id=False,
    num_buckets=0,
    shuffle=True,
    pad_to_multiple=1,
    prepend_bos_src=None,
    aux_src_lang='en',
    aux_src=None,
    aux_src_dict=None,
):
    def split_exists(split, src, tgt, lang, data_path):
        filename = os.path.join(data_path, "{}.{}-{}.{}".format(split, src, tgt, lang))
        return indexed_dataset.dataset_exists(filename, impl=dataset_impl)

    src_datasets = []
    tgt_datasets = []

    if (split == 'train') and (aux_src is not None):
        assert split_exists(split, aux_src_lang, 'None', aux_src_lang, aux_src)
        aux_src_prefix = os.path.join(aux_src, "{}.{}-{}.".format('train', aux_src_lang, 'None'))
        aux_src_dataset = data_utils.load_indexed_dataset(
            aux_src_prefix + aux_src_lang, aux_src_dict, dataset_impl
        )
        if truncate_source:
            aux_src_dataset = AppendTokenDataset(
                TruncateDataset(
                    StripTokenDataset(aux_src_dataset, aux_src_dict.eos()),
                    max_source_positions - 1,
                ),
                aux_src_dict.eos(),
            )
    else:
        aux_src_dataset = None
    for k in itertools.count():
        split_k = split + (str(k) if k > 0 else "")

        # infer langcode
        if split_exists(split_k, src, tgt, src, data_path):
            prefix = os.path.join(data_path, "{}.{}-{}.".format(split_k, src, tgt))
        elif split_exists(split_k, tgt, src, src, data_path):
            prefix = os.path.join(data_path, "{}.{}-{}.".format(split_k, tgt, src))
        else:
            if k > 0:
                break
            else:
                raise FileNotFoundError(
                    "Dataset not found: {} ({})".format(split, data_path)
                )

        src_dataset = data_utils.load_indexed_dataset(
            prefix + src, src_dict, dataset_impl
        )
        if truncate_source:
            src_dataset = AppendTokenDataset(
                TruncateDataset(
                    StripTokenDataset(src_dataset, src_dict.eos()),
                    max_source_positions - 1,
                ),
                src_dict.eos(),
            )
        src_datasets.append(src_dataset)

        tgt_dataset = data_utils.load_indexed_dataset(
            prefix + tgt, tgt_dict, dataset_impl
        )
        if tgt_dataset is not None:
            tgt_datasets.append(tgt_dataset)

        logger.info(
            "{} {} {}-{} {} examples".format(
                data_path, split_k, src, tgt, len(src_datasets[-1])
            )
        )

        if not combine:
            break

    assert len(src_datasets) == len(tgt_datasets) or len(tgt_datasets) == 0

    if len(src_datasets) == 1:
        src_dataset = src_datasets[0]
        tgt_dataset = tgt_datasets[0] if len(tgt_datasets) > 0 else None
    else:
        sample_ratios = [1] * len(src_datasets)
        sample_ratios[0] = upsample_primary
        src_dataset = ConcatDataset(src_datasets, sample_ratios)
        if len(tgt_datasets) > 0:
            tgt_dataset = ConcatDataset(tgt_datasets, sample_ratios)
        else:
            tgt_dataset = None

    if prepend_bos:
        assert hasattr(src_dict, "bos_index") and hasattr(tgt_dict, "bos_index")
        src_dataset = PrependTokenDataset(src_dataset, src_dict.bos())
        if tgt_dataset is not None:
            tgt_dataset = PrependTokenDataset(tgt_dataset, tgt_dict.bos())
    elif prepend_bos_src is not None:
        logger.info(f"prepending src bos: {prepend_bos_src}")
        src_dataset = PrependTokenDataset(src_dataset, prepend_bos_src)

    eos = None
    if append_source_id:
        src_dataset = AppendTokenDataset(
            src_dataset, src_dict.index("[{}]".format(src))
        )
        if tgt_dataset is not None:
            tgt_dataset = AppendTokenDataset(
                tgt_dataset, tgt_dict.index("[{}]".format(tgt))
            )
        eos = tgt_dict.index("[{}]".format(tgt))

    align_dataset = None
    if load_alignments:
        align_path = os.path.join(data_path, "{}.align.{}-{}".format(split, src, tgt))
        if indexed_dataset.dataset_exists(align_path, impl=dataset_impl):
            align_dataset = data_utils.load_indexed_dataset(
                align_path, None, dataset_impl
            )

    tgt_dataset_sizes = tgt_dataset.sizes if tgt_dataset is not None else None
    return LanguagePairDataset(
        src_dataset,
        src_dataset.sizes,
        src_dict,
        tgt_dataset,
        tgt_dataset_sizes,
        tgt_dict,
        left_pad_source=left_pad_source,
        left_pad_target=left_pad_target,
        align_dataset=align_dataset,
        eos=eos,
        num_buckets=num_buckets,
        shuffle=shuffle,
        pad_to_multiple=pad_to_multiple,
        aux_src=aux_src_dataset,
        aux_src_dict=aux_src_dict,
    )


@dataclass
class TranslationConfig(FairseqDataclass):
    data: Optional[str] = field(
        default=None,
        metadata={
            "help": "colon separated path to data directories list, will be iterated upon during epochs "
            "in round-robin manner; however, valid and test data are always in the first directory "
            "to avoid the need for repeating them in all directories"
        },
    )
    source_lang: Optional[str] = field(
        default=None,
        metadata={
            "help": "source language",
            "argparse_alias": "-s",
        },
    )
    target_lang: Optional[str] = field(
        default=None,
        metadata={
            "help": "target language",
            "argparse_alias": "-t",
        },
    )
    load_alignments: bool = field(
        default=False, metadata={"help": "load the binarized alignments"}
    )
    left_pad_source: bool = field(
        default=True, metadata={"help": "pad the source on the left"}
    )
    left_pad_target: bool = field(
        default=False, metadata={"help": "pad the target on the left"}
    )
    max_source_positions: int = field(
        default=1024, metadata={"help": "max number of tokens in the source sequence"}
    )
    max_target_positions: int = field(
        default=1024, metadata={"help": "max number of tokens in the target sequence"}
    )
    upsample_primary: int = field(
        default=-1, metadata={"help": "the amount of upsample primary dataset"}
    )
    truncate_source: bool = field(
        default=False, metadata={"help": "truncate source to max-source-positions"}
    )
    num_batch_buckets: int = field(
        default=0,
        metadata={
            "help": "if >0, then bucket source and target lengths into "
            "N buckets and pad accordingly; this is useful on TPUs to minimize the number of compilations"
        },
    )
    train_subset: str = II("dataset.train_subset")
    dataset_impl: Optional[ChoiceEnum(get_available_dataset_impl())] = II(
        "dataset.dataset_impl"
    )
    required_seq_len_multiple: int = II("dataset.required_seq_len_multiple")

    # options for reporting BLEU during validation
    eval_bleu: bool = field(
        default=False, metadata={"help": "evaluation with BLEU scores"}
    )
    eval_bleu_args: Optional[str] = field(
        default="{}",
        metadata={
            "help": 'generation args for BLUE scoring, e.g., \'{"beam": 4, "lenpen": 0.6}\', as JSON string'
        },
    )
    eval_bleu_detok: str = field(
        default="space",
        metadata={
            "help": "detokenize before computing BLEU (e.g., 'moses'); required if using --eval-bleu; "
            "use 'space' to disable detokenization; see fairseq.data.encoders for other options"
        },
    )
    eval_bleu_detok_args: Optional[str] = field(
        default="{}",
        metadata={"help": "args for building the tokenizer, if needed, as JSON string"},
    )
    eval_tokenized_bleu: bool = field(
        default=False, metadata={"help": "compute tokenized BLEU instead of sacrebleu"}
    )
    eval_bleu_remove_bpe: Optional[str] = field(
        default=None,
        metadata={
            "help": "remove BPE before computing BLEU",
            "argparse_const": "@@ ",
        },
    )
    eval_bleu_print_samples: bool = field(
        default=False, metadata={"help": "print sample generations during validation"}
    )
    aux_src_lang: str = field(default='de')
    aux_src: Optional[str] = field(default=None)
    ignore_grad: bool = field(default=False)
    # cut_off_type: str = field(default='')
    # augment: str = field(default='')
    # masking_schema: str = field(default='')
    # src_masking_prob: str = field(default='')
    # src_max_masking_ratio: str = field(default='')
    #cut off
    cut_off_type: CUT_OFF = field(default='normal')
    augment: bool = field(
        default=False
        )
    masking_schema:MASK = field(
        default='word'
        )
    src_masking_prob:float = field(
        default=0.15
        )
    src_max_masking_ratio: float = field(
        default=1.0
        )
    tgt_masking_prob:float = field(
        default=0.15
        )
    tgt_max_masking_ratio: float = field(
        default=1.0
    )
    reg_weight: float = field(default=5.0)
    aug_weight: float = field(default=0.0)
    bi_kl: bool = field(default=False)
    js_loss: bool = field(default=False)
    share_forward: bool = field(default=False)
    tri_function: TRI_FUNCTION = field(default='tri_js')
    prior_tau: float = field(default=1.0)
    mix_ratio: float = field(default=0.0)

    #new
    dataset_aug: bool = field(default=False)
    dataset_src_masking_prob: float = field(default=0.0)
    dataset_tgt_masking_prob: float = field(default=0.0)
    dataset_src_masking_prob_rest: float = field(default=0.0)
    dataset_tgt_masking_prob_rest: float = field(default=0.0)
    prefix_aug: bool = field(default=False) #shift left
    #transform
    word_aug: bool = field(default=False)
    word_guided_subword_aug: bool = field(default=False)
    src_subword_mask: Optional[str] = field(default=None)
    tgt_subword_mask: Optional[str] = field(default=None)
    src_word_mask: Optional[str] = field(default=None)
    tgt_word_mask: Optional[str] = field(default=None)
    src_word_mapping: Optional[str] = field(default=None)
    tgt_word_mapping: Optional[str] = field(default=None)

    #random mask
    src_random_mask: bool = field(default=False)
    tgt_random_mask: bool = field(default=False)

    ignore_grad: bool = field(default=False)
    using_spm: bool = field(default=False)
    spm_model: Optional[str] = field(default=None)

@register_task("translation", dataclass=TranslationConfig)
class TranslationTask(FairseqTask):
    """
    Translate from one (source) language to another (target) language.

    Args:
        src_dict (~fairseq.data.Dictionary): dictionary for the source language
        tgt_dict (~fairseq.data.Dictionary): dictionary for the target language

    .. note::

        The translation task is compatible with :mod:`fairseq-train`,
        :mod:`fairseq-generate` and :mod:`fairseq-interactive`.
    """

    cfg: TranslationConfig

    def __init__(self, cfg: TranslationConfig, src_dict, tgt_dict):
        super().__init__(cfg)
        self.src_dict = src_dict
        self.tgt_dict = tgt_dict

    @classmethod
    def setup_task(cls, cfg: TranslationConfig, **kwargs):
        """Setup the task (e.g., load dictionaries).

        Args:
            args (argparse.Namespace): parsed command-line arguments
        """

        paths = utils.split_paths(cfg.data)
        assert len(paths) > 0
        # find language pair automatically
        if cfg.source_lang is None or cfg.target_lang is None:
            cfg.source_lang, cfg.target_lang = data_utils.infer_language_pair(paths[0])
        if cfg.source_lang is None or cfg.target_lang is None:
            raise Exception(
                "Could not infer language pair, please provide it explicitly"
            )

        # load dictionaries
        src_dict = cls.load_dictionary(
            os.path.join(paths[0], "dict.{}.txt".format(cfg.source_lang))
        )
        tgt_dict = cls.load_dictionary(
            os.path.join(paths[0], "dict.{}.txt".format(cfg.target_lang))
        )
        assert src_dict.pad() == tgt_dict.pad()
        assert src_dict.eos() == tgt_dict.eos()
        assert src_dict.unk() == tgt_dict.unk()
        logger.info("[{}] dictionary: {} types".format(cfg.source_lang, len(src_dict)))
        logger.info("[{}] dictionary: {} types".format(cfg.target_lang, len(tgt_dict)))

        return cls(cfg, src_dict, tgt_dict)

    def load_dataset(self, split, epoch=1, combine=False, **kwargs):
        """Load a given dataset split.

        Args:
            split (str): name of the split (e.g., train, valid, test)
        """
        paths = utils.split_paths(self.cfg.data)
        assert len(paths) > 0
        if split != self.cfg.train_subset:
            # if not training data set, use the first shard for valid and test
            paths = paths[:1]
        data_path = paths[(epoch - 1) % len(paths)]

        # infer langcode
        src, tgt = self.cfg.source_lang, self.cfg.target_lang
        
        if self.cfg.aux_src is not None:
            aux_src_dict = self.load_dictionary(
            os.path.join(self.cfg.aux_src, "dict.{}.txt".format(self.cfg.aux_src_lang)),
            )
        else:
            aux_src_dict = None
        if split == 'train':
            self.datasets[split] = load_langpair_dataset(
                data_path,
                split,
                src,
                self.src_dict,
                tgt,
                self.tgt_dict,
                combine=combine,
                dataset_impl=self.cfg.dataset_impl,
                upsample_primary=self.cfg.upsample_primary,
                left_pad_source=self.cfg.left_pad_source,
                left_pad_target=self.cfg.left_pad_target,
                max_source_positions=self.cfg.max_source_positions,
                max_target_positions=self.cfg.max_target_positions,
                load_alignments=self.cfg.load_alignments,
                truncate_source=self.cfg.truncate_source,
                num_buckets=self.cfg.num_batch_buckets,
                shuffle=(split != "test"),
                pad_to_multiple=self.cfg.required_seq_len_multiple,
                aux_src_lang=self.cfg.aux_src_lang,
                aux_src=self.cfg.aux_src,
                aux_src_dict=aux_src_dict,
            )
        else:
            self.datasets[split] = load_langpair_dataset(
                data_path,
                split,
                src,
                self.src_dict,
                tgt,
                self.tgt_dict,
                combine=combine,
                dataset_impl=self.cfg.dataset_impl,
                upsample_primary=self.cfg.upsample_primary,
                left_pad_source=self.cfg.left_pad_source,
                left_pad_target=self.cfg.left_pad_target,
                max_source_positions=self.cfg.max_source_positions,
                max_target_positions=self.cfg.max_target_positions,
                load_alignments=self.cfg.load_alignments,
                truncate_source=self.cfg.truncate_source,
                num_buckets=self.cfg.num_batch_buckets,
                shuffle=(split != "test"),
                pad_to_multiple=self.cfg.required_seq_len_multiple,
            )
    def build_dataset_for_inference(self, src_tokens, src_lengths, constraints=None):
        return LanguagePairDataset(
            src_tokens,
            src_lengths,
            self.source_dictionary,
            tgt_dict=self.target_dictionary,
            constraints=constraints,
        )

    def build_model(self, cfg, from_checkpoint=False):
        model = super().build_model(cfg, from_checkpoint)
        if self.cfg.eval_bleu:
            detok_args = json.loads(self.cfg.eval_bleu_detok_args)
            self.tokenizer = encoders.build_tokenizer(
                Namespace(tokenizer=self.cfg.eval_bleu_detok, **detok_args)
            )

            gen_args = json.loads(self.cfg.eval_bleu_args)
            self.sequence_generator = self.build_generator(
                [model], Namespace(**gen_args)
            )
        return model
    
    def train_step(
        self, sample, model, criterion, optimizer, update_num, ignore_grad=False, **kwargs
    ):
        """
        Do forward and backward, and return the loss as computed by *criterion*
        for the given *model* and *sample*.

        Args:
            sample (dict): the mini-batch. The format is defined by the
                :class:`~fairseq.data.FairseqDataset`.
            model (~fairseq.models.BaseFairseqModel): the model
            criterion (~fairseq.criterions.FairseqCriterion): the criterion
            optimizer (~fairseq.optim.FairseqOptimizer): the optimizer
            update_num (int): the current update
            ignore_grad (bool): multiply loss by 0 if this is set to True

        Returns:
            tuple:
                - the loss
                - the sample size, which is used as the denominator for the
                  gradient
                - logging outputs to display while training
        """
        model.train()
        model.set_num_updates(update_num)
        with torch.autograd.profiler.record_function("forward"):
            with torch.amp.autocast('cuda', enabled=(isinstance(optimizer, AMPOptimizer))):
                loss, sample_size, logging_output = criterion(model, sample, **kwargs)
        if ignore_grad or self.cfg.ignore_grad:
            loss *= 0
        if not self.cfg.ignore_grad:
            with torch.autograd.profiler.record_function("backward"):
                optimizer.backward(loss)
        return loss, sample_size, logging_output

    def valid_step(self, sample, model, criterion):
        loss, sample_size, logging_output = super().valid_step(sample, model, criterion)
        if self.cfg.eval_bleu:
            bleu = self._inference_with_bleu(self.sequence_generator, sample, model)
            logging_output["_bleu_sys_len"] = bleu.sys_len
            logging_output["_bleu_ref_len"] = bleu.ref_len
            # we split counts into separate entries so that they can be
            # summed efficiently across workers using fast-stat-sync
            assert len(bleu.counts) == EVAL_BLEU_ORDER
            for i in range(EVAL_BLEU_ORDER):
                logging_output["_bleu_counts_" + str(i)] = bleu.counts[i]
                logging_output["_bleu_totals_" + str(i)] = bleu.totals[i]
        return loss, sample_size, logging_output

    def reduce_metrics(self, logging_outputs, criterion):
        super().reduce_metrics(logging_outputs, criterion)
        if self.cfg.eval_bleu:

            def sum_logs(key):
                import torch

                result = sum(log.get(key, 0) for log in logging_outputs)
                if torch.is_tensor(result):
                    result = result.cpu()
                return result

            counts, totals = [], []
            for i in range(EVAL_BLEU_ORDER):
                counts.append(sum_logs("_bleu_counts_" + str(i)))
                totals.append(sum_logs("_bleu_totals_" + str(i)))

            if max(totals) > 0:
                # log counts as numpy arrays -- log_scalar will sum them correctly
                metrics.log_scalar("_bleu_counts", np.array(counts))
                metrics.log_scalar("_bleu_totals", np.array(totals))
                metrics.log_scalar("_bleu_sys_len", sum_logs("_bleu_sys_len"))
                metrics.log_scalar("_bleu_ref_len", sum_logs("_bleu_ref_len"))

                def compute_bleu(meters):
                    import inspect

                    try:
                        from sacrebleu.metrics import BLEU

                        comp_bleu = BLEU.compute_bleu
                    except ImportError:
                        # compatibility API for sacrebleu 1.x
                        import sacrebleu

                        comp_bleu = sacrebleu.compute_bleu

                    fn_sig = inspect.getfullargspec(comp_bleu)[0]
                    if "smooth_method" in fn_sig:
                        smooth = {"smooth_method": "exp"}
                    else:
                        smooth = {"smooth": "exp"}
                    bleu = comp_bleu(
                        correct=meters["_bleu_counts"].sum,
                        total=meters["_bleu_totals"].sum,
                        sys_len=int(meters["_bleu_sys_len"].sum),
                        ref_len=int(meters["_bleu_ref_len"].sum),
                        **smooth,
                    )
                    return round(bleu.score, 2)

                metrics.log_derived("bleu", compute_bleu)

    def max_positions(self):
        """Return the max sentence length allowed by the task."""
        return (self.cfg.max_source_positions, self.cfg.max_target_positions)

    @property
    def source_dictionary(self):
        """Return the source :class:`~fairseq.data.Dictionary`."""
        return self.src_dict

    @property
    def target_dictionary(self):
        """Return the target :class:`~fairseq.data.Dictionary`."""
        return self.tgt_dict

    def _inference_with_bleu(self, generator, sample, model):
        import sacrebleu

        def decode(toks, escape_unk=False):
            s = self.tgt_dict.string(
                toks.int().cpu(),
                self.cfg.eval_bleu_remove_bpe,
                # The default unknown string in fairseq is `<unk>`, but
                # this is tokenized by sacrebleu as `< unk >`, inflating
                # BLEU scores. Instead, we use a somewhat more verbose
                # alternative that is unlikely to appear in the real
                # reference, but doesn't get split into multiple tokens.
                unk_string=("UNKNOWNTOKENINREF" if escape_unk else "UNKNOWNTOKENINHYP"),
            )
            if self.tokenizer:
                s = self.tokenizer.decode(s)
            return s

        gen_out = self.inference_step(generator, [model], sample, prefix_tokens=None)
        hyps, refs = [], []
        for i in range(len(gen_out)):
            hyps.append(decode(gen_out[i][0]["tokens"]))
            refs.append(
                decode(
                    utils.strip_pad(sample["target"][i], self.tgt_dict.pad()),
                    escape_unk=True,  # don't count <unk> as matches to the hypo
                )
            )
        if self.cfg.eval_bleu_print_samples:
            logger.info("example hypothesis: " + hyps[0])
            logger.info("example reference: " + refs[0])
        if self.cfg.eval_tokenized_bleu:
            return sacrebleu.metrics.BLEU().corpus_score(hyps, [refs])
        else:
            return sacrebleu.metrics.BLEU(trg_lang=self.cfg.target_lang).corpus_score(
                hyps, [refs]
            )
# Out:
# Overwriting /kaggle/working/kNN-TL/kNN-TL/fairseq/tasks/translation.py

# %%
# %%writefile /kaggle/working/kNN-TL/kNN-TL/fairseq/checkpoint_utils.py
# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

import ast
import collections
import contextlib
import inspect
import logging
import os
import re
import time
import traceback
from collections import OrderedDict
from pathlib import Path
from typing import Any, Dict, Optional, Union

import numpy as np
import torch
from fairseq.data import data_utils
from fairseq.dataclass.configs import CheckpointConfig
from fairseq.dataclass.utils import (
    convert_namespace_to_omegaconf,
    overwrite_args_by_name,
)
from fairseq.distributed.fully_sharded_data_parallel import FSDP, has_FSDP
from fairseq.file_io import PathManager
from fairseq.models import FairseqDecoder, FairseqEncoder
from omegaconf import DictConfig, OmegaConf, open_dict

logger = logging.getLogger(__name__)


def save_checkpoint(cfg: CheckpointConfig, trainer, epoch_itr, val_loss):
    from fairseq import meters

    # only one worker should attempt to create the required dir
    if trainer.data_parallel_rank == 0:
        os.makedirs(cfg.save_dir, exist_ok=True)

    prev_best = getattr(save_checkpoint, "best", val_loss)
    if val_loss is not None:
        best_function = max if cfg.maximize_best_checkpoint_metric else min
        save_checkpoint.best = best_function(val_loss, prev_best)

    if cfg.no_save:
        return

    trainer.consolidate_optimizer()  # TODO(SS): do we need this if no_save_optimizer_state

    if not trainer.should_save_checkpoint_on_current_rank:
        if trainer.always_call_state_dict_during_save_checkpoint:
            trainer.state_dict()
        return

    write_timer = meters.StopwatchMeter()
    write_timer.start()

    epoch = epoch_itr.epoch
    end_of_epoch = epoch_itr.end_of_epoch()
    updates = trainer.get_num_updates()

    logger.info(f"Preparing to save checkpoint for epoch {epoch} @ {updates} updates")

    def is_better(a, b):
        return a >= b if cfg.maximize_best_checkpoint_metric else a <= b

    suffix = trainer.checkpoint_suffix
    checkpoint_conds = collections.OrderedDict()
    checkpoint_conds["checkpoint{}{}.pt".format(epoch, suffix)] = (
        end_of_epoch and not cfg.no_epoch_checkpoints and epoch % cfg.save_interval == 0
    )
    checkpoint_conds["checkpoint_{}_{}{}.pt".format(epoch, updates, suffix)] = (
        not end_of_epoch
        and cfg.save_interval_updates > 0
        and updates % cfg.save_interval_updates == 0
    )
    checkpoint_conds["checkpoint_best{}.pt".format(suffix)] = val_loss is not None and (
        not hasattr(save_checkpoint, "best")
        or is_better(val_loss, save_checkpoint.best)
    )
    if val_loss is not None and cfg.keep_best_checkpoints > 0:
        worst_best = getattr(save_checkpoint, "best", None)
        chkpts = checkpoint_paths(
            cfg.save_dir,
            pattern=r"checkpoint\.best_{}_(\d+\.?\d*){}\.pt".format(
                cfg.best_checkpoint_metric, suffix
            ),
        )
        if len(chkpts) > 0:
            p = chkpts[-1] if cfg.maximize_best_checkpoint_metric else chkpts[0]
            worst_best = float(p.rsplit("_")[-1].replace("{}.pt".format(suffix), ""))
        # add random digits to resolve ties
        with data_utils.numpy_seed(epoch, updates, val_loss):
            rand_sfx = np.random.randint(0, cfg.keep_best_checkpoints)

        checkpoint_conds[
            "checkpoint.best_{}_{:.3f}{}{}.pt".format(
                cfg.best_checkpoint_metric, val_loss, rand_sfx, suffix
            )
        ] = worst_best is None or is_better(val_loss, worst_best)
    checkpoint_conds[
        "checkpoint_last{}.pt".format(suffix)
    ] = not cfg.no_last_checkpoints

    extra_state = {"train_iterator": epoch_itr.state_dict(), "val_loss": val_loss}
    if hasattr(save_checkpoint, "best"):
        extra_state.update({"best": save_checkpoint.best})

    checkpoints = [
        os.path.join(cfg.save_dir, fn) for fn, cond in checkpoint_conds.items() if cond
    ]
    if len(checkpoints) > 0 and trainer.should_save_checkpoint_on_current_rank:
        trainer.save_checkpoint(checkpoints[0], extra_state)
        for cp in checkpoints[1:]:
            if cfg.write_checkpoints_asynchronously:
                # TODO[ioPath]: Need to implement a delayed asynchronous
                # file copying/moving feature.
                logger.warning(
                    f"ioPath is not copying {checkpoints[0]} to {cp} "
                    "since async write mode is on."
                )
            else:
                assert PathManager.copy(
                    checkpoints[0], cp, overwrite=True
                ), f"Failed to copy {checkpoints[0]} to {cp}"

        write_timer.stop()
        logger.info(
            "Saved checkpoint {} (epoch {} @ {} updates, score {}) (writing took {} seconds)".format(
                checkpoints[0], epoch, updates, val_loss, write_timer.sum
            )
        )

    if not end_of_epoch and cfg.keep_interval_updates > 0:
        # remove old checkpoints; checkpoints are sorted in descending order
        if cfg.keep_interval_updates_pattern == -1:
            checkpoints = checkpoint_paths(
                cfg.save_dir, pattern=r"checkpoint_\d+_(\d+){}\.pt".format(suffix)
            )
        else:
            checkpoints = checkpoint_paths(
                cfg.save_dir,
                pattern=r"checkpoint_\d+_(\d+){}\.pt".format(suffix),
                keep_match=True,
            )
            checkpoints = [
                x[0]
                for x in checkpoints
                if x[1] % cfg.keep_interval_updates_pattern != 0
            ]

        for old_chk in checkpoints[cfg.keep_interval_updates :]:
            if os.path.lexists(old_chk):
                os.remove(old_chk)
            elif PathManager.exists(old_chk):
                PathManager.rm(old_chk)

    if cfg.keep_last_epochs > 0:
        # remove old epoch checkpoints; checkpoints are sorted in descending order
        checkpoints = checkpoint_paths(
            cfg.save_dir, pattern=r"checkpoint(\d+){}\.pt".format(suffix)
        )
        for old_chk in checkpoints[cfg.keep_last_epochs :]:
            if os.path.lexists(old_chk):
                os.remove(old_chk)
            elif PathManager.exists(old_chk):
                PathManager.rm(old_chk)

    if cfg.keep_best_checkpoints > 0:
        # only keep the best N checkpoints according to validation metric
        checkpoints = checkpoint_paths(
            cfg.save_dir,
            pattern=r"checkpoint\.best_{}_(\d+\.?\d*){}\.pt".format(
                cfg.best_checkpoint_metric, suffix
            ),
        )
        if not cfg.maximize_best_checkpoint_metric:
            checkpoints = checkpoints[::-1]
        for old_chk in checkpoints[cfg.keep_best_checkpoints :]:
            if os.path.lexists(old_chk):
                os.remove(old_chk)
            elif PathManager.exists(old_chk):
                PathManager.rm(old_chk)


def load_checkpoint(cfg: CheckpointConfig, trainer, **passthrough_args):
    """
    Load a checkpoint and restore the training iterator.

    *passthrough_args* will be passed through to
    ``trainer.get_train_iterator``.
    """

    reset_optimizer = cfg.reset_optimizer
    reset_lr_scheduler = cfg.reset_lr_scheduler
    optimizer_overrides = ast.literal_eval(cfg.optimizer_overrides)
    reset_meters = cfg.reset_meters
    reset_dataloader = cfg.reset_dataloader

    if cfg.finetune_from_model is not None and (
        reset_optimizer or reset_lr_scheduler or reset_meters or reset_dataloader
    ):
        raise ValueError(
            "--finetune-from-model can not be set together with either --reset-optimizer"
            " or reset_lr_scheduler or reset_meters or reset_dataloader"
        )

    suffix = trainer.checkpoint_suffix
    if (
        cfg.restore_file == "checkpoint_last.pt"
    ):  # default value of restore_file is 'checkpoint_last.pt'
        checkpoint_path = os.path.join(
            cfg.save_dir, "checkpoint_last{}.pt".format(suffix)
        )
        first_launch = not PathManager.exists(checkpoint_path)
        if first_launch and getattr(cfg, "continue_once", None) is not None:
            checkpoint_path = cfg.continue_once
        elif cfg.finetune_from_model is not None and first_launch:
            # if there is no last checkpoint to restore, start the finetune from pretrained model
            # else just use usual logic to load checkpoint, e.g. restart from last checkpoint and etc.
            if PathManager.exists(cfg.finetune_from_model):
                checkpoint_path = cfg.finetune_from_model
                reset_optimizer = True
                reset_lr_scheduler = True
                reset_meters = True
                reset_dataloader = True
                logger.info(
                    f"loading pretrained model from {checkpoint_path}: "
                    "optimizer, lr scheduler, meters, dataloader will be reset"
                )
            else:
                raise ValueError(
                    f"--finetune-from-model {cfg.finetune_from_model} does not exist"
                )
    elif suffix is not None:
        checkpoint_path = cfg.restore_file.replace(".pt", suffix + ".pt")
    else:
        checkpoint_path = cfg.restore_file

    if cfg.restore_file != "checkpoint_last.pt" and cfg.finetune_from_model:
        raise ValueError(
            "--finetune-from-model and --restore-file (non-default value) "
            "can not be specified together: " + str(cfg)
        )

    extra_state = trainer.load_checkpoint(
        checkpoint_path,
        reset_optimizer,
        reset_lr_scheduler,
        optimizer_overrides,
        reset_meters=reset_meters,
    )

    if (
        extra_state is not None
        and "best" in extra_state
        and not reset_optimizer
        and not reset_meters
    ):
        save_checkpoint.best = extra_state["best"]

    if extra_state is not None and not reset_dataloader:
        # restore iterator from checkpoint
        itr_state = extra_state["train_iterator"]
        epoch_itr = trainer.get_train_iterator(
            epoch=itr_state["epoch"], load_dataset=True, **passthrough_args
        )
        epoch_itr.load_state_dict(itr_state)
    else:
        epoch_itr = trainer.get_train_iterator(
            epoch=1, load_dataset=True, **passthrough_args
        )

    trainer.lr_step(epoch_itr.epoch)

    return extra_state, epoch_itr


def load_checkpoint_to_cpu(path, arg_overrides=None, load_on_all_ranks=False):
    """Loads a checkpoint to CPU (with upgrading for backward compatibility).

    If doing single-GPU training or if the checkpoint is only being loaded by at
    most one process on each node (current default behavior is for only rank 0
    to read the checkpoint from disk), load_on_all_ranks should be False to
    avoid errors from torch.distributed not having been initialized or
    torch.distributed.barrier() hanging.

    If all processes on each node may be loading the checkpoint
    simultaneously, load_on_all_ranks should be set to True to avoid I/O
    conflicts.

    There's currently no support for > 1 but < all processes loading the
    checkpoint on each node.
    """
    local_path = PathManager.get_local_path(path)
    # The locally cached file returned by get_local_path() may be stale for
    # remote files that are periodically updated/overwritten (ex:
    # checkpoint_last.pt) - so we remove the local copy, sync across processes
    # (if needed), and then download a fresh copy.
    if local_path != path and PathManager.path_requires_pathmanager(path):
        try:
            os.remove(local_path)
        except FileNotFoundError:
            # With potentially multiple processes removing the same file, the
            # file being missing is benign (missing_ok isn't available until
            # Python 3.8).
            pass
        if load_on_all_ranks:
            torch.distributed.barrier()
        local_path = PathManager.get_local_path(path)

    with open(local_path, "rb") as f:
        state = torch.load(f, map_location=torch.device("cpu"), weights_only=False)

    if "args" in state and state["args"] is not None and arg_overrides is not None:
        args = state["args"]
        for arg_name, arg_val in arg_overrides.items():
            setattr(args, arg_name, arg_val)

    if "cfg" in state and state["cfg"] is not None:

        # hack to be able to set Namespace in dict config. this should be removed when we update to newer
        # omegaconf version that supports object flags, or when we migrate all existing models
        from omegaconf import _utils

        old_primitive = _utils.is_primitive_type
        _utils.is_primitive_type = lambda _: True

        state["cfg"] = OmegaConf.create(state["cfg"])

        _utils.is_primitive_type = old_primitive
        OmegaConf.set_struct(state["cfg"], True)

        if arg_overrides is not None:
            overwrite_args_by_name(state["cfg"], arg_overrides)

    state = _upgrade_state_dict(state)
    return state


def load_model_ensemble(
    filenames,
    arg_overrides: Optional[Dict[str, Any]] = None,
    task=None,
    strict=True,
    suffix="",
    num_shards=1,
    state=None,
):
    """Loads an ensemble of models.

    Args:
        filenames (List[str]): checkpoint files to load
        arg_overrides (Dict[str,Any], optional): override model args that
            were used during model training
        task (fairseq.tasks.FairseqTask, optional): task to use for loading
    """
    assert not (
        strict and num_shards > 1
    ), "Cannot load state dict with strict=True and checkpoint shards > 1"
    ensemble, args, _task = load_model_ensemble_and_task(
        filenames,
        arg_overrides,
        task,
        strict,
        suffix,
        num_shards,
        state,
    )
    return ensemble, args


def get_maybe_sharded_checkpoint_filename(
    filename: str, suffix: str, shard_idx: int, num_shards: int
) -> str:
    orig_filename = filename
    filename = filename.replace(".pt", suffix + ".pt")
    fsdp_filename = filename[:-3] + f"-shard{shard_idx}.pt"
    model_parallel_filename = orig_filename[:-3] + f"_part{shard_idx}.pt"
    if PathManager.exists(fsdp_filename):
        return fsdp_filename
    elif num_shards > 1:
        return model_parallel_filename
    else:
        return filename


def load_model_ensemble_and_task(
    filenames,
    arg_overrides: Optional[Dict[str, Any]] = None,
    task=None,
    strict=True,
    suffix="",
    num_shards=1,
    state=None,
):
    assert state is None or len(filenames) == 1

    from fairseq import tasks

    assert not (
        strict and num_shards > 1
    ), "Cannot load state dict with strict=True and checkpoint shards > 1"
    ensemble = []
    cfg = None
    for filename in filenames:
        orig_filename = filename
        model_shard_state = {"shard_weights": [], "shard_metadata": []}
        assert num_shards > 0
        st = time.time()
        for shard_idx in range(num_shards):
            filename = get_maybe_sharded_checkpoint_filename(
                orig_filename, suffix, shard_idx, num_shards
            )

            if not PathManager.exists(filename):
                raise IOError("Model file not found: {}".format(filename))
            if state is None:
                state = load_checkpoint_to_cpu(filename, arg_overrides)
            if "args" in state and state["args"] is not None:
                cfg = convert_namespace_to_omegaconf(state["args"])
            elif "cfg" in state and state["cfg"] is not None:
                cfg = state["cfg"]
            else:
                raise RuntimeError(
                    f"Neither args nor cfg exist in state keys = {state.keys()}"
                )

            if task is None:
                task = tasks.setup_task(cfg.task)

            if "task_state" in state:
                task.load_state_dict(state["task_state"])

            if "fsdp_metadata" in state and num_shards > 1:
                model_shard_state["shard_weights"].append(state["model"])
                model_shard_state["shard_metadata"].append(state["fsdp_metadata"])
                # check FSDP import before the code goes too far
                if not has_FSDP:
                    raise ImportError(
                        "Cannot find FullyShardedDataParallel. "
                        "Please install fairscale with: pip install fairscale"
                    )
                if shard_idx == num_shards - 1:
                    consolidated_model_state = FSDP.consolidate_shard_weights(
                        shard_weights=model_shard_state["shard_weights"],
                        shard_metadata=model_shard_state["shard_metadata"],
                    )
                    model = task.build_model(cfg.model)
                    if (
                        "optimizer_history" in state
                        and len(state["optimizer_history"]) > 0
                        and "num_updates" in state["optimizer_history"][-1]
                    ):
                        model.set_num_updates(
                            state["optimizer_history"][-1]["num_updates"]
                        )
                    model.load_state_dict(
                        consolidated_model_state, strict=strict, model_cfg=cfg.model
                    )
            else:
                # model parallel checkpoint or unsharded checkpoint
                # support old external tasks

                argspec = inspect.getfullargspec(task.build_model)
                if "from_checkpoint" in argspec.args:
                    model = task.build_model(cfg.model, from_checkpoint=True)
                else:
                    model = task.build_model(cfg.model)
                if (
                    "optimizer_history" in state
                    and len(state["optimizer_history"]) > 0
                    and "num_updates" in state["optimizer_history"][-1]
                ):
                    model.set_num_updates(state["optimizer_history"][-1]["num_updates"])
                model.load_state_dict(
                    state["model"], strict=strict, model_cfg=cfg.model
                )

            # reset state so it gets loaded for the next model in ensemble
            state = None
            if shard_idx % 10 == 0 and shard_idx > 0:
                elapsed = time.time() - st
                logger.info(
                    f"Loaded {shard_idx} shards in {elapsed:.2f}s, {elapsed / (shard_idx+1):.2f}s/shard"
                )

        # build model for ensemble
        ensemble.append(model)
    return ensemble, cfg, task


def load_model_ensemble_and_task_from_hf_hub(
    model_id,
    cache_dir: Optional[str] = None,
    arg_overrides: Optional[Dict[str, Any]] = None,
    **kwargs: Any,
):
    try:
        from huggingface_hub import snapshot_download
    except ImportError:
        raise ImportError(
            "You need to install huggingface_hub to use `load_from_hf_hub`. "
            "See https://pypi.org/project/huggingface-hub/ for installation."
        )

    library_name = "fairseq"
    cache_dir = cache_dir or (Path.home() / ".cache" / library_name).as_posix()
    cache_dir = snapshot_download(
        model_id, cache_dir=cache_dir, library_name=library_name, **kwargs
    )

    _arg_overrides = arg_overrides or {}
    _arg_overrides["data"] = cache_dir
    return load_model_ensemble_and_task(
        [p.as_posix() for p in Path(cache_dir).glob("*.pt")],
        arg_overrides=_arg_overrides,
    )


def checkpoint_paths(path, pattern=r"checkpoint(\d+)\.pt", keep_match=False):
    """Retrieves all checkpoints found in `path` directory.

    Checkpoints are identified by matching filename to the specified pattern. If
    the pattern contains groups, the result will be sorted by the first group in
    descending order.
    """
    pt_regexp = re.compile(pattern)
    files = PathManager.ls(path)

    entries = []
    for i, f in enumerate(files):
        m = pt_regexp.fullmatch(f)
        if m is not None:
            idx = float(m.group(1)) if len(m.groups()) > 0 else i
            entries.append((idx, m.group(0)))
    if keep_match:
        return [(os.path.join(path, x[1]), x[0]) for x in sorted(entries, reverse=True)]
    else:
        return [os.path.join(path, x[1]) for x in sorted(entries, reverse=True)]


def torch_persistent_save(obj, filename, async_write: bool = False):
    if async_write:
        with PathManager.opena(filename, "wb") as f:
            _torch_persistent_save(obj, f)
    else:
        if PathManager.supports_rename(filename):
            # do atomic save
            with PathManager.open(filename + ".tmp", "wb") as f:
                _torch_persistent_save(obj, f)
            PathManager.rename(filename + ".tmp", filename)
        else:
            # fallback to non-atomic save
            with PathManager.open(filename, "wb") as f:
                _torch_persistent_save(obj, f)


def _torch_persistent_save(obj, f):
    if isinstance(f, str):
        with PathManager.open(f, "wb") as h:
            torch_persistent_save(obj, h)
        return
    for i in range(3):
        try:
            return torch.save(obj, f)
        except Exception:
            if i == 2:
                logger.error(traceback.format_exc())
                raise


def _upgrade_state_dict(state):
    """Helper for upgrading old model checkpoints."""

    # add optimizer_history
    if "optimizer_history" not in state:
        state["optimizer_history"] = [
            {"criterion_name": "CrossEntropyCriterion", "best_loss": state["best_loss"]}
        ]
        state["last_optimizer_state"] = state["optimizer"]
        del state["optimizer"]
        del state["best_loss"]
    # move extra_state into sub-dictionary
    if "epoch" in state and "extra_state" not in state:
        state["extra_state"] = {
            "epoch": state["epoch"],
            "batch_offset": state["batch_offset"],
            "val_loss": state["val_loss"],
        }
        del state["epoch"]
        del state["batch_offset"]
        del state["val_loss"]
    # reduce optimizer history's memory usage (only keep the last state)
    if "optimizer" in state["optimizer_history"][-1]:
        state["last_optimizer_state"] = state["optimizer_history"][-1]["optimizer"]
        for optim_hist in state["optimizer_history"]:
            del optim_hist["optimizer"]
    # record the optimizer class name
    if "optimizer_name" not in state["optimizer_history"][-1]:
        state["optimizer_history"][-1]["optimizer_name"] = "FairseqNAG"
    # move best_loss into lr_scheduler_state
    if "lr_scheduler_state" not in state["optimizer_history"][-1]:
        state["optimizer_history"][-1]["lr_scheduler_state"] = {
            "best": state["optimizer_history"][-1]["best_loss"]
        }
        del state["optimizer_history"][-1]["best_loss"]
    # keep track of number of updates
    if "num_updates" not in state["optimizer_history"][-1]:
        state["optimizer_history"][-1]["num_updates"] = 0
    # use stateful training data iterator
    if "train_iterator" not in state["extra_state"]:
        state["extra_state"]["train_iterator"] = {
            "epoch": state["extra_state"].get("epoch", 0),
            "iterations_in_epoch": state["extra_state"].get("batch_offset", 0),
        }

    # backward compatibility, cfg updates
    if "args" in state and state["args"] is not None:
        # old model checkpoints may not have separate source/target positions
        if hasattr(state["args"], "max_positions") and not hasattr(
            state["args"], "max_source_positions"
        ):
            state["args"].max_source_positions = state["args"].max_positions
            state["args"].max_target_positions = state["args"].max_positions
        # default to translation task
        if not hasattr(state["args"], "task"):
            state["args"].task = "translation"
        # --raw-text and --lazy-load are deprecated
        if getattr(state["args"], "raw_text", False):
            state["args"].dataset_impl = "raw"
        elif getattr(state["args"], "lazy_load", False):
            state["args"].dataset_impl = "lazy"
        # epochs start at 1
        if state["extra_state"]["train_iterator"] is not None:
            state["extra_state"]["train_iterator"]["epoch"] = max(
                state["extra_state"]["train_iterator"].get("epoch", 1), 1
            )
        # --remove-bpe ==> --postprocess
        if hasattr(state["args"], "remove_bpe"):
            state["args"].post_process = state["args"].remove_bpe
        # --min-lr ==> --stop-min-lr
        if hasattr(state["args"], "min_lr"):
            state["args"].stop_min_lr = state["args"].min_lr
            del state["args"].min_lr
        # binary_cross_entropy / kd_binary_cross_entropy => wav2vec criterion
        if hasattr(state["args"], "criterion") and state["args"].criterion in [
            "binary_cross_entropy",
            "kd_binary_cross_entropy",
        ]:
            state["args"].criterion = "wav2vec"
        # remove log_keys if it's None (criteria will supply a default value of [])
        if hasattr(state["args"], "log_keys") and state["args"].log_keys is None:
            delattr(state["args"], "log_keys")
        # speech_pretraining => audio pretraining
        if (
            hasattr(state["args"], "task")
            and state["args"].task == "speech_pretraining"
        ):
            state["args"].task = "audio_pretraining"
        # audio_cpc => wav2vec
        if hasattr(state["args"], "arch") and state["args"].arch == "audio_cpc":
            state["args"].arch = "wav2vec"
        # convert legacy float learning rate to List[float]
        if hasattr(state["args"], "lr") and isinstance(state["args"].lr, float):
            state["args"].lr = [state["args"].lr]
        # convert task data arg to a string instead of List[string]
        if (
            hasattr(state["args"], "data")
            and isinstance(state["args"].data, list)
            and len(state["args"].data) > 0
        ):
            state["args"].data = state["args"].data[0]

        state["cfg"] = convert_namespace_to_omegaconf(state["args"])

    if "cfg" in state and state["cfg"] is not None:
        cfg = state["cfg"]
        with open_dict(cfg):
            # any upgrades for Hydra-based configs
            if (
                "task" in cfg
                and "eval_wer_config" in cfg.task
                and isinstance(cfg.task.eval_wer_config.print_alignment, bool)
            ):
                cfg.task.eval_wer_config.print_alignment = "hard"
            if "generation" in cfg and isinstance(cfg.generation.print_alignment, bool):
                cfg.generation.print_alignment = (
                    "hard" if cfg.generation.print_alignment else None
                )
            if (
                "model" in cfg
                and "w2v_args" in cfg.model
                and cfg.model.w2v_args is not None
                and (
                    hasattr(cfg.model.w2v_args, "task") or "task" in cfg.model.w2v_args
                )
                and hasattr(cfg.model.w2v_args.task, "eval_wer_config")
                and cfg.model.w2v_args.task.eval_wer_config is not None
                and isinstance(
                    cfg.model.w2v_args.task.eval_wer_config.print_alignment, bool
                )
            ):
                cfg.model.w2v_args.task.eval_wer_config.print_alignment = "hard"

    return state


def prune_state_dict(state_dict, model_cfg: Optional[DictConfig]):
    """Prune the given state_dict if desired for LayerDrop
    (https://arxiv.org/abs/1909.11556).

    Training with LayerDrop allows models to be robust to pruning at inference
    time. This function prunes state_dict to allow smaller models to be loaded
    from a larger model and re-maps the existing state_dict for this to occur.

    It's called by functions that load models from checkpoints and does not
    need to be called directly.
    """
    arch = None
    if model_cfg is not None:
        arch = (
            model_cfg._name
            if isinstance(model_cfg, DictConfig)
            else getattr(model_cfg, "arch", None)
        )

    if not model_cfg or arch is None or arch == "ptt_transformer":
        # args should not be none, but don't crash if it is.
        return state_dict

    encoder_layers_to_keep = getattr(model_cfg, "encoder_layers_to_keep", None)
    decoder_layers_to_keep = getattr(model_cfg, "decoder_layers_to_keep", None)

    if not encoder_layers_to_keep and not decoder_layers_to_keep:
        return state_dict

    # apply pruning
    logger.info(
        "Pruning model to specified layer configuration - this works best if the model was trained with LayerDrop"
    )

    def create_pruning_pass(layers_to_keep, layer_name):
        keep_layers = sorted(
            int(layer_string) for layer_string in layers_to_keep.split(",")
        )
        mapping_dict = {}
        for i in range(len(keep_layers)):
            mapping_dict[str(keep_layers[i])] = str(i)

        regex = re.compile(r"^{layer}.*\.layers\.(\d+)".format(layer=layer_name))
        return {"substitution_regex": regex, "mapping_dict": mapping_dict}

    pruning_passes = []
    if encoder_layers_to_keep:
        pruning_passes.append(create_pruning_pass(encoder_layers_to_keep, "encoder"))
    if decoder_layers_to_keep:
        pruning_passes.append(create_pruning_pass(decoder_layers_to_keep, "decoder"))

    new_state_dict = {}
    for layer_name in state_dict.keys():
        match = re.search(r"\.layers\.(\d+)\.", layer_name)
        # if layer has no number in it, it is a supporting layer, such as an
        # embedding
        if not match:
            new_state_dict[layer_name] = state_dict[layer_name]
            continue

        # otherwise, layer should be pruned.
        original_layer_number = match.group(1)
        # figure out which mapping dict to replace from
        for pruning_pass in pruning_passes:
            if original_layer_number in pruning_pass["mapping_dict"] and pruning_pass[
                "substitution_regex"
            ].search(layer_name):
                new_layer_number = pruning_pass["mapping_dict"][original_layer_number]
                substitution_match = pruning_pass["substitution_regex"].search(
                    layer_name
                )
                new_state_key = (
                    layer_name[: substitution_match.start(1)]
                    + new_layer_number
                    + layer_name[substitution_match.end(1) :]
                )
                new_state_dict[new_state_key] = state_dict[layer_name]

    # Since layers are now pruned, *_layers_to_keep are no longer needed.
    # This is more of "It would make it work fix" rather than a proper fix.
    if isinstance(model_cfg, DictConfig):
        context = open_dict(model_cfg)
    else:
        context = contextlib.ExitStack()
    with context:
        if hasattr(model_cfg, "encoder_layers_to_keep"):
            model_cfg.encoder_layers_to_keep = None
        if hasattr(model_cfg, "decoder_layers_to_keep"):
            model_cfg.decoder_layers_to_keep = None

    return new_state_dict


def load_pretrained_component_from_model(
    component: Union[FairseqEncoder, FairseqDecoder],
    checkpoint: str,
    strict: bool = True,
):
    """
    Load a pretrained FairseqEncoder or FairseqDecoder from checkpoint into the
    provided `component` object. If state_dict fails to load, there may be a
    mismatch in the architecture of the corresponding `component` found in the
    `checkpoint` file.
    """
    if not PathManager.exists(checkpoint):
        raise IOError("Model file not found: {}".format(checkpoint))
    state = load_checkpoint_to_cpu(checkpoint)
    if isinstance(component, FairseqEncoder):
        component_type = "encoder"
    elif isinstance(component, FairseqDecoder):
        component_type = "decoder"
    else:
        raise ValueError(
            "component to load must be either a FairseqEncoder or "
            "FairseqDecoder. Loading other component types are not supported."
        )
    component_state_dict = OrderedDict()
    for key in state["model"].keys():
        if key.startswith(component_type):
            # encoder.input_layers.0.0.weight --> input_layers.0.0.weight
            component_subkey = key[len(component_type) + 1 :]
            component_state_dict[component_subkey] = state["model"][key]
    component.load_state_dict(component_state_dict, strict=strict)
    return component


def verify_checkpoint_directory(save_dir: str) -> None:
    if not os.path.exists(save_dir):
        os.makedirs(save_dir, exist_ok=True)
    temp_file_path = os.path.join(save_dir, "dummy")
    try:
        with open(temp_file_path, "w"):
            pass
    except OSError as e:
        logger.warning(
            "Unable to access checkpoint save directory: {}".format(save_dir)
        )
        raise e
    else:
        os.remove(temp_file_path)


def save_ema_as_checkpoint(src_path, dst_path):
    state = load_ema_from_checkpoint(src_path)
    torch_persistent_save(state, dst_path)


def load_ema_from_checkpoint(fpath):
    """Loads exponential moving averaged (EMA) checkpoint from input and
    returns a model with ema weights.

    Args:
      fpath: A string path of checkpoint to load from.

    Returns:
      A dict of string keys mapping to various values. The 'model' key
      from the returned dict should correspond to an OrderedDict mapping
      string parameter names to torch Tensors.
    """
    params_dict = collections.OrderedDict()
    new_state = None

    with PathManager.open(fpath, "rb") as f:
        new_state = torch.load(
            f,
            map_location=(
                lambda s, _: torch.serialization.default_restore_location(s, "cpu")
            ),
        )

        # EMA model is stored in a separate "extra state"
        model_params = new_state["extra_state"]["ema"]

        for key in list(model_params.keys()):
            p = model_params[key]
            if isinstance(p, torch.HalfTensor):
                p = p.float()
            if key not in params_dict:
                params_dict[key] = p.clone()
                # NOTE: clone() is needed in case of p is a shared parameter
            else:
                raise ValueError("Key {} is repeated in EMA model params.".format(key))

        if len(params_dict) == 0:
            raise ValueError(
                f"Input checkpoint path '{fpath}' does not contain "
                "ema model weights, is this model trained with EMA?"
            )

    new_state["model"] = params_dict
    return new_state
# Out:
# Overwriting /kaggle/working/kNN-TL/kNN-TL/fairseq/checkpoint_utils.py

# %% [markdown]
# Train the child model with parent representation alignment using PADIC dataset as the child data

# %%
# %%writefile /kaggle/working/kNN-TL/train-scripts/train_child.sh
# PROJECT_PATH="/kaggle/working/kNN-TL/kNN-TL"
# warmup=1000
# seed=1
# lr=0.0003
# bsz=1000
# using_gpus=1
# w_decay=0.0
# max_epoch=200
# attn_dropout=0.1
# act_dropout=0.1
# freq=1
# kd_weight=0.01
# aug_weight=0.0
# prior_tau=1.0
# loss_type=mse
# kd_type=full_frozen
# aux_src_lang=en
#
# #source language
# src_lang=drj
# #INPUT
# aux_src="/kaggle/input/pseudo-data-bin/pseudo-bin"
#
# parent_model="/kaggle/input/parent_best/pytorch/default/1/checkpoint_best.pt"
# parent_data="/kaggle/input/hplt-bin/Bin_hplt" #OMG!!! i was working with child data -_-
# child_data="/kaggle/input/bin-padic/Bin_padic"
# child_model="/kaggle/working/kNN-TL/initial_child.pt"
#
# keep_dir=child
# logdir=$PROJECT_PATH/child_tensorboard_save_non_early_stop/$keep_dir
# save_dir=$PROJECT_PATH/checkpoints/$keep_dir
# train_log=/home/lynn/kNN-TL/kNN-TL/checkpoints/logs
#
# MKL_THREADING_LAYER=GNU CUDA_VISIBLE_DEVICES=0,1 /kaggle/working/venv/bin/python $PROJECT_PATH/train_transfer.py \
#     /kaggle/input/bin-padic/Bin_padic \
#     --arch transformer_from_pretrained_mt \
#     --share-decoder-input-output-embed \
#     --ddp-backend=no_c10d \
#     --pretrained-mt-checkpoint $child_model \
#     --aux-src-lang $aux_src_lang --aux-src $aux_src \
#     --teacher-data $parent_data \
#     --kd-weight $kd_weight --prior-tau $prior_tau --teacher-dir $parent_model --loss-type $loss_type \
#     --update-freq $freq \
#     --max-tokens $bsz \
#     --tensorboard-logdir clean_train \
#     --save-dir $save_dir \
#     --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
#     --lr $lr --lr-scheduler inverse_sqrt --warmup-updates $warmup --warmup-init-lr 1e-07 \
#     --dropout 0.3 --weight-decay $w_decay \
#     --attention-dropout $attn_dropout \
#     --activation-dropout $act_dropout \
#     --seed $seed \
#     --eval-bleu \
#     --max-epoch $max_epoch \
#     --keep-best-checkpoints 2 \
#     --keep-last-epochs 1 \
#     --eval-bleu-args '{"beam": 5, "lenpen":1}' \
#     --eval-bleu-detok moses \
#     --eval-bleu-remove-bpe \
#     --eval-bleu-print-samples \
#     --best-checkpoint-metric bleu --maximize-best-checkpoint-metric \
#     --criterion label_smoothed_cross_entropy_xkd --label-smoothing 0.1 \
#     --fp16 \
#     --log-format=json --log-interval=100 2>&1    |  tee -a  /kaggle/working/kNN-TL/kNN-TL/logs/child_training_log.log 2>&1
# Out:
# Overwriting /kaggle/working/kNN-TL/train-scripts/train_child.sh

# %%
# !bash /kaggle/working/kNN-TL/train-scripts/train_child.sh
# Out:
# 2025-07-21 10:24:35 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:24:40 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:24:40 | INFO | fairseq.distributed.utils | distributed init (rank 0): tcp://localhost:17743
# 2025-07-21 10:24:41 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:24:41 | INFO | fairseq.distributed.utils | distributed init (rank 1): tcp://localhost:17743
# 2025-07-21 10:24:41 | INFO | fairseq.distributed.utils | initialized host 99d74f068e06 as rank 1
# 2025-07-21 10:24:41 | INFO | fairseq.distributed.utils | initialized host 99d74f068e06 as rank 0
# 2025-07-21 10:24:41 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': 'json', 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': 'clean_train', 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 2, 'distributed_num_procs': 2, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': 'tcp://localhost:17743', 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'no_c10d', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 2, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 1000, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 1000, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0003], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/kaggle/working/kNN-TL/kNN-TL/checkpoints/child', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 1, 'keep_best_checkpoints': 2, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'bleu', 'maximize_best_checkpoint_metric': True, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'loa ...
# 2025-07-21 10:24:42 | INFO | fairseq.tasks.translation | [drj] dictionary: 5496 types
# 2025-07-21 10:24:42 | INFO | fairseq.tasks.translation | [ar] dictionary: 46120 types
# /kaggle/working/kNN-TL/kNN-TL/fairseq/trainer.py:147: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   self._grad_norm_buf = torch.cuda.DoubleTensor(self.data_parallel_world_size)
# 158
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | TransformerFromPretrainedMTModel(
#   (encoder): TransformerEncoderFromPretrainedMT(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(5496, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0-5): 6 x TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderFromPretrainedMT(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(46120, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0-5): 6 x TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=46120, bias=False)
#   )
# )
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | task: TranslationTask
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | model: TransformerFromPretrainedMTModel
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropy_XKD_Criterion
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | num. shared model params: 70,565,888 (num. trained: 70,565,888)
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2025-07-21 10:24:45 | INFO | fairseq.data.data_utils | loaded 899 examples from: /kaggle/input/bin-padic/Bin_padic/valid.drj-ar.drj
# 2025-07-21 10:24:45 | INFO | fairseq.data.data_utils | loaded 899 examples from: /kaggle/input/bin-padic/Bin_padic/valid.drj-ar.ar
# 2025-07-21 10:24:45 | INFO | fairseq.tasks.translation | /kaggle/input/bin-padic/Bin_padic valid drj-ar 899 examples
# 2025-07-21 10:24:45 | INFO | fairseq.trainer | detected shared parameter: decoder.embed_tokens.weight <- decoder.output_projection.weight
# /kaggle/working/kNN-TL/kNN-TL/fairseq/trainer.py:147: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   self._grad_norm_buf = torch.cuda.DoubleTensor(self.data_parallel_world_size)
# 2025-07-21 10:24:45 | INFO | fairseq.utils | ***********************CUDA enviroments for all 2 workers***********************
# 2025-07-21 10:24:45 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 14.741 GB ; name = Tesla T4
# 2025-07-21 10:24:45 | INFO | fairseq.utils | rank   1: capabilities =  7.5  ; total memory = 14.741 GB ; name = Tesla T4
# 2025-07-21 10:24:45 | INFO | fairseq.utils | ***********************CUDA enviroments for all 2 workers***********************
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | training on 2 devices (GPUs/TPUs)
# 2025-07-21 10:24:45 | INFO | fairseq_cli.train | max tokens per device = 1000 and max sentences per device = None
# 2025-07-21 10:24:45 | INFO | fairseq.trainer | Preparing to load checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint_last.pt
# 2025-07-21 10:24:45 | INFO | fairseq.trainer | No existing checkpoint found /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint_last.pt
# 2025-07-21 10:24:45 | INFO | fairseq.trainer | loading train data for epoch 1
# 2025-07-21 10:24:45 | INFO | fairseq.data.data_utils | loaded 4,024 examples from: /kaggle/input/pseudo-data-bin/pseudo-bin/train.en-None.en
# 2025-07-21 10:24:45 | INFO | fairseq.data.data_utils | loaded 4,024 examples from: /kaggle/input/bin-padic/Bin_padic/train.drj-ar.drj
# 2025-07-21 10:24:45 | INFO | fairseq.data.data_utils | loaded 4,024 examples from: /kaggle/input/bin-padic/Bin_padic/train.drj-ar.ar
# 2025-07-21 10:24:45 | INFO | fairseq.tasks.translation | /kaggle/input/bin-padic/Bin_padic train drj-ar 4024 examples
# 2025-07-21 10:24:46 | INFO | fairseq_cli.train | loading teacher model
# 2025-07-21 10:24:47 | INFO | fairseq.tasks.translation | [en] dictionary: 46120 types
# 2025-07-21 10:24:47 | INFO | fairseq.tasks.translation | [ar] dictionary: 46120 types
# 2025-07-21 10:24:48 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:24:48 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:24:48 | INFO | fairseq.trainer | begin training epoch 1
# 2025-07-21 10:24:48 | INFO | fairseq_cli.train | Start iterating over samples
# 158
# 2025-07-21 10:24:51 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:24:51 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# /kaggle/working/venv/lib/python3.10/site-packages/torch/nn/functional.py:5962: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /kaggle/working/venv/lib/python3.10/site-packages/torch/nn/functional.py:5962: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 2025-07-21 10:24:52 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# 2025-07-21 10:24:53 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# 2025-07-21 10:24:59 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:24:59 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:25:02 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:02 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:05 | INFO | fairseq.tasks.translation | example hypothesis: قم بإلغاء الآن ، قم بإلغاء الآن!
# 2025-07-21 10:25:05 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:25:08 | INFO | fairseq.tasks.translation | example hypothesis: ابتابتابتابتابتابتابتلألألأنأنأنأن"
# 2025-07-21 10:25:08 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:25:10 | INFO | fairseq.tasks.translation | example hypothesis: تعتعتعتعتعتعتعتعتعتعتعتعتعيشيشيشيشيشكلكلكلكلكلكلكلكلكلكلكلكلكلكلكل
# 2025-07-21 10:25:10 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:25:12 | INFO | fairseq.tasks.translation | example hypothesis: بصبصبصبصبصبصمات متمتمتمتمتمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمثمث
# 2025-07-21 10:25:12 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:25:14 | INFO | fairseq.tasks.translation | example hypothesis: يسلسلسلسلسلسلسلسلسلسلسلسيسيسيسيسيسيسيسيسيفي
# 2025-07-21 10:25:14 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:25:17 | INFO | fairseq.tasks.translation | example hypothesis: !!!!!!!!!!!!!!!!!!!
# 2025-07-21 10:25:17 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:25:19 | INFO | fairseq.tasks.translation | example hypothesis: على الرغم من أن اللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللاللالل
# 2025-07-21 10:25:19 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:25:20 | INFO | fairseq.tasks.translation | example hypothesis: في كل مرة أخرى ، كل كل كل!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! مرة مرة مرة مرة مرة مرة مرة مرة مرة!!!!!!!!!!!!!!!!!!!!!!!!!!
# 2025-07-21 10:25:20 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:25:22 | INFO | valid | {"epoch": 1, "valid_loss": "12.242", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "11.647", "valid_ppl": "3206.08", "valid_bleu": "0.04", "valid_wps": "484.3", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "24"}
# 2025-07-21 10:25:22 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 24 updates
# 2025-07-21 10:25:22 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint1.pt
# 2025-07-21 10:25:24 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint1.pt
# 2025-07-21 10:25:25 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:26 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint1.pt (epoch 1 @ 24 updates, score 0.04) (writing took 4.482741171000043 seconds)
# 2025-07-21 10:25:26 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2025-07-21 10:25:26 | INFO | train | {"epoch": 1, "train_loss": "27.652", "train_aux_loss": "9.112", "train_mse_loss": "1394.73", "train_kd_loss": "0", "train_nll_loss": "13.286", "train_ppl": "9985.57", "train_wps": "1034.9", "train_ups": "0.69", "train_wpb": "1501.9", "train_bsz": "159", "train_num_updates": "24", "train_lr": "7.2976e-06", "train_gnorm": "30.138", "train_loss_scale": "32", "train_train_wall": "8", "train_gb_free": "12.4", "train_wall": "41"}
# 2025-07-21 10:25:26 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:25:26 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:25:26 | INFO | fairseq.trainer | begin training epoch 2
# 2025-07-21 10:25:26 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:25:30 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:38 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:25:38 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:25:40 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:40 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:41 | INFO | fairseq.tasks.translation | example hypothesis: ما عليك ؟
# 2025-07-21 10:25:41 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:25:42 | INFO | fairseq.tasks.translation | example hypothesis: في كل ما عليك ؟
# 2025-07-21 10:25:42 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:25:42 | INFO | fairseq.tasks.translation | example hypothesis: لا يمكن أن يكون
# 2025-07-21 10:25:42 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:25:42 | INFO | fairseq.tasks.translation | example hypothesis: ما هو ما هو ؟
# 2025-07-21 10:25:42 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:25:43 | INFO | fairseq.tasks.translation | example hypothesis: في الوقت الذي لم يسبق لك.
# 2025-07-21 10:25:43 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:25:43 | INFO | fairseq.tasks.translation | example hypothesis: ما هو ؟ ؟
# 2025-07-21 10:25:43 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:25:44 | INFO | fairseq.tasks.translation | example hypothesis: إذا كنت لا تريد أن لا تسلم ؟
# 2025-07-21 10:25:44 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:25:44 | INFO | fairseq.tasks.translation | example hypothesis: في هذه الحالة ، لا يمكن أن لا تأخفي.
# 2025-07-21 10:25:44 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:25:44 | INFO | valid | {"epoch": 2, "valid_loss": "11.115", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "10.424", "valid_ppl": "1373.97", "valid_bleu": "0.07", "valid_wps": "2928", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "50", "valid_best_bleu": "0.07"}
# 2025-07-21 10:25:44 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 50 updates
# 2025-07-21 10:25:44 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint2.pt
# 2025-07-21 10:25:46 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint2.pt
# 2025-07-21 10:25:47 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:25:51 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint2.pt (epoch 2 @ 50 updates, score 0.07) (writing took 6.997648276999826 seconds)
# 2025-07-21 10:25:51 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2025-07-21 10:25:51 | INFO | train | {"epoch": 2, "train_loss": "21.253", "train_aux_loss": "9.147", "train_mse_loss": "908.249", "train_kd_loss": "0", "train_nll_loss": "11.598", "train_ppl": "3098.98", "train_wps": "1553.8", "train_ups": "1.04", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "50", "train_lr": "1.5095e-05", "train_gnorm": "10.787", "train_loss_scale": "32", "train_train_wall": "7", "train_gb_free": "12.3", "train_wall": "66"}
# 2025-07-21 10:25:51 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:25:51 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:25:51 | INFO | fairseq.trainer | begin training epoch 3
# 2025-07-21 10:25:51 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:25:54 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:02 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:26:02 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:26:05 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:05 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:06 | INFO | fairseq.tasks.translation | example hypothesis: لا يمكنك أن تفعل ذلك.
# 2025-07-21 10:26:06 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:26:06 | INFO | fairseq.tasks.translation | example hypothesis: في هذه الحالة ، يجب أن يكون هناك
# 2025-07-21 10:26:06 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:26:06 | INFO | fairseq.tasks.translation | example hypothesis: لا تخلو من أي شيء.
# 2025-07-21 10:26:06 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:26:07 | INFO | fairseq.tasks.translation | example hypothesis: في هذه الحالة ، لا تقتصر على ما هو عليه.
# 2025-07-21 10:26:07 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:26:07 | INFO | fairseq.tasks.translation | example hypothesis: في هذه الحالة ، يجب أن يكون في هذه الحالة.
# 2025-07-21 10:26:07 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:26:08 | INFO | fairseq.tasks.translation | example hypothesis: في هذا اليوم ، يجب أن يكون كل ما هو عليه ؟
# 2025-07-21 10:26:08 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:26:08 | INFO | fairseq.tasks.translation | example hypothesis: في هذه الحالة ، يجب أن يكون من الممكن أن يكون على ما إذا كان من الممكن أن يكون في أي وقت ، على سبيل المثال.
# 2025-07-21 10:26:08 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:26:09 | INFO | fairseq.tasks.translation | example hypothesis: في هذه الحالة ، يجب أن يكون من الممكن أن يكون في أي وقت ، أن يكون من الممكن أن يكون من الممكن أن يكون في أي وقت.
# 2025-07-21 10:26:09 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:26:09 | INFO | valid | {"epoch": 3, "valid_loss": "10.61", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "9.851", "valid_ppl": "923.71", "valid_bleu": "0.13", "valid_wps": "2532.8", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "76", "valid_best_bleu": "0.13"}
# 2025-07-21 10:26:09 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 76 updates
# 2025-07-21 10:26:09 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint3.pt
# 2025-07-21 10:26:11 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint3.pt
# 2025-07-21 10:26:12 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:16 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint3.pt (epoch 3 @ 76 updates, score 0.13) (writing took 7.364280752000013 seconds)
# 2025-07-21 10:26:17 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2025-07-21 10:26:17 | INFO | train | {"epoch": 3, "train_loss": "18.807", "train_aux_loss": "9.141", "train_mse_loss": "736.876", "train_kd_loss": "0", "train_nll_loss": "10.817", "train_ppl": "1804.08", "train_wps": "1533.2", "train_ups": "1.03", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "76", "train_lr": "2.28924e-05", "train_gnorm": "6.485", "train_loss_scale": "32", "train_train_wall": "7", "train_gb_free": "12.4", "train_wall": "92"}
# 2025-07-21 10:26:17 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:26:17 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:26:17 | INFO | fairseq.trainer | begin training epoch 4
# 2025-07-21 10:26:17 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:26:20 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:27 | INFO | train_inner | {"epoch": 4, "update": 3.923, "loss": "21.231", "aux_loss": "9.134", "mse_loss": "916.51", "kd_loss": "0", "nll_loss": "11.49", "ppl": "2876.99", "wps": "1589.3", "ups": "1.06", "wpb": "1502.9", "bsz": "157.4", "num_updates": "100", "lr": "3.009e-05", "gnorm": "13.058", "loss_scale": "32", "train_wall": "28", "gb_free": "12.3", "wall": "102"}
# 2025-07-21 10:26:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:26:27 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:26:30 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:30 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:31 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يمكن أن يكون هناك
# 2025-07-21 10:26:31 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:26:31 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يمكن أن يكون هناك أي شيء ؟
# 2025-07-21 10:26:31 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:26:31 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يمكن أن يكون هناك أي شيء ؟
# 2025-07-21 10:26:31 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:26:32 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، ما هو ما هو عليه ؟
# 2025-07-21 10:26:32 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:26:32 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يجب أن يكون هناك أي شيء في هذه الحالة
# 2025-07-21 10:26:32 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:26:33 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يجب أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون هذا الأمر.
# 2025-07-21 10:26:33 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:26:34 | INFO | fairseq.tasks.translation | example hypothesis: في هذا الوقت ، يجب أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون في هذا الأمر.
# 2025-07-21 10:26:34 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:26:35 | INFO | fairseq.tasks.translation | example hypothesis: إذا كنت لا تريد أن تتجلى في هذه الحالة ، فأنا لا تتجلى على أن تتجلى في ذلك ، لا تتجلى في أي وقت ، إلا أن هذا الأمر لا يعني أن هناك أي شيء في أي وقت ، إلا أنه لا يوجد في أي وقت مضى.
# 2025-07-21 10:26:35 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:26:35 | INFO | valid | {"epoch": 4, "valid_loss": "10.429", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "9.64", "valid_ppl": "797.93", "valid_bleu": "0.15", "valid_wps": "2059.8", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "102", "valid_best_bleu": "0.15"}
# 2025-07-21 10:26:35 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 102 updates
# 2025-07-21 10:26:35 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint4.pt
# 2025-07-21 10:26:36 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint4.pt
# 2025-07-21 10:26:38 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:41 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint4.pt (epoch 4 @ 102 updates, score 0.15) (writing took 6.251022153000122 seconds)
# 2025-07-21 10:26:41 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2025-07-21 10:26:41 | INFO | train | {"epoch": 4, "train_loss": "17.433", "train_aux_loss": "9.142", "train_mse_loss": "642.437", "train_kd_loss": "0", "train_nll_loss": "10.326", "train_ppl": "1283.81", "train_wps": "1566.7", "train_ups": "1.05", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "102", "train_lr": "3.06898e-05", "train_gnorm": "5.506", "train_loss_scale": "32", "train_train_wall": "7", "train_gb_free": "12.4", "train_wall": "116"}
# 2025-07-21 10:26:41 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:26:41 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:26:41 | INFO | fairseq.trainer | begin training epoch 5
# 2025-07-21 10:26:41 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:26:44 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:52 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:26:52 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:26:55 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:55 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:26:55 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يوجد شيء
# 2025-07-21 10:26:55 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:26:56 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يوجد في هذا الأمر
# 2025-07-21 10:26:56 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:26:56 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أذهب إلى أي شيء ؟
# 2025-07-21 10:26:56 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:26:57 | INFO | fairseq.tasks.translation | example hypothesis: في هذا الوقت ، يجب أن يكون من الممكن أن يكون من الممكن أن يكون هناك أي شيء.
# 2025-07-21 10:26:57 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:26:58 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أذهب إلى أبعد من ذلك ؟
# 2025-07-21 10:26:58 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:26:59 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أذهب إلى أي شيء في هذا الأمر ، فأنا لا أذهب إلى أي شيء ؟
# 2025-07-21 10:26:59 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:27:00 | INFO | fairseq.tasks.translation | example hypothesis: في هذا الأمر ، يجب أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون هناك أي شيء.
# 2025-07-21 10:27:00 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:27:01 | INFO | fairseq.tasks.translation | example hypothesis: إذا لم يكن هناك أي شيء في هذا الأمر ، فأنا لا أذهب إلى أي شيء ، إلا أن هذا الأمر لا يعني أن هذا هو أن هذا الأمر لا يقال له أن هذا الأمر لا يقال له ، إلا أنه لا يعني أن هناك أي شيء في أي وقت من الأيام ، إلا أنه لا يوجد أي شيء ، إلا أنه لا يوجد أي شيء في هذا الأمر.
# 2025-07-21 10:27:01 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:27:01 | INFO | valid | {"epoch": 5, "valid_loss": "10.232", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "9.41", "valid_ppl": "680.36", "valid_bleu": "0.08", "valid_wps": "1552.6", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "128", "valid_best_bleu": "0.15"}
# 2025-07-21 10:27:01 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 5 @ 128 updates
# 2025-07-21 10:27:01 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint5.pt
# 2025-07-21 10:27:03 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint5.pt
# 2025-07-21 10:27:03 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:04 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint5.pt (epoch 5 @ 128 updates, score 0.08) (writing took 3.443080112000189 seconds)
# 2025-07-21 10:27:04 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2025-07-21 10:27:04 | INFO | train | {"epoch": 5, "train_loss": "16.809", "train_aux_loss": "9.144", "train_mse_loss": "608.59", "train_kd_loss": "0", "train_nll_loss": "9.996", "train_ppl": "1020.93", "train_wps": "1691.1", "train_ups": "1.13", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "128", "train_lr": "3.84872e-05", "train_gnorm": "5.604", "train_loss_scale": "32", "train_train_wall": "7", "train_gb_free": "12.3", "train_wall": "139"}
# 2025-07-21 10:27:04 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:27:04 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:27:04 | INFO | fairseq.trainer | begin training epoch 6
# 2025-07-21 10:27:04 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:27:07 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:15 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:27:15 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:27:18 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:18 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:18 | INFO | fairseq.tasks.translation | example hypothesis: نعم نعم
# 2025-07-21 10:27:18 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:27:19 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يوجد شيء آخر
# 2025-07-21 10:27:19 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:27:19 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لا يوجد شيء في هذا الأمر
# 2025-07-21 10:27:19 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:27:20 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أذهب إلى أبعد من ذلك ؟
# 2025-07-21 10:27:20 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:27:21 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، لم يكن هناك أي شيء في هذا الأمر ، إلا أنه من الممكن أن يكون من الممكن أن يكون هناك أي شيء آخر.
# 2025-07-21 10:27:21 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:27:23 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أذهب إلى أبعد من أن أذهب إلى أبعد من أن أذهب إلى أبعد من ذلك ، لم يكن هناك أي شيء في هذا الأمر.
# 2025-07-21 10:27:23 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:27:24 | INFO | fairseq.tasks.translation | example hypothesis: و في هذا الوقت الذي كان من المفترض أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون من الممكن أن يكون هناك أي شيء من ذلك.
# 2025-07-21 10:27:24 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:27:26 | INFO | fairseq.tasks.translation | example hypothesis: إذا كان هناك أي شيء في هذا الأمر ، فقال لي أنه من الممكن أن يكون هناك أي شيء في أي وقت مضى على أن يكون من الممكن أن يكون هناك أي شيء في هذا الأمر ، كما هو الحال في هذا الوقت الذي لا يقال له أن يكون هناك أي شيء في أي وقت من الأيام التي تأخذه في هذا الأمر ، إلا أنه لا يوجد شيء آخر ، إلا أنه من الممكن أن يكون هناك أي شيء في أي وقت مضى.
# 2025-07-21 10:27:26 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:27:26 | INFO | valid | {"epoch": 6, "valid_loss": "9.999", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "9.135", "valid_ppl": "562.26", "valid_bleu": "0.1", "valid_wps": "1048.5", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "154", "valid_best_bleu": "0.15"}
# 2025-07-21 10:27:26 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 6 @ 154 updates
# 2025-07-21 10:27:26 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint6.pt
# 2025-07-21 10:27:28 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint6.pt
# 2025-07-21 10:27:29 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:30 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint6.pt (epoch 6 @ 154 updates, score 0.1) (writing took 3.6353815759998724 seconds)
# 2025-07-21 10:27:30 | INFO | fairseq_cli.train | end of epoch 6 (average epoch stats below)
# 2025-07-21 10:27:30 | INFO | train | {"epoch": 6, "train_loss": "16.348", "train_aux_loss": "9.144", "train_mse_loss": "591.942", "train_kd_loss": "0", "train_nll_loss": "9.655", "train_ppl": "806.43", "train_wps": "1521.2", "train_ups": "1.02", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "154", "train_lr": "4.62846e-05", "train_gnorm": "5.31", "train_loss_scale": "32", "train_train_wall": "7", "train_gb_free": "12.3", "train_wall": "165"}
# 2025-07-21 10:27:30 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:27:30 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:27:30 | INFO | fairseq.trainer | begin training epoch 7
# 2025-07-21 10:27:30 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:27:32 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:40 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:27:40 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:27:43 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:43 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:27:44 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أعرف
# 2025-07-21 10:27:44 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:27:44 | INFO | fairseq.tasks.translation | example hypothesis: نعم نعم ، لا يوجد شيء
# 2025-07-21 10:27:44 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:27:45 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أعرف أن هذا الأمر
# 2025-07-21 10:27:45 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:27:45 | INFO | fairseq.tasks.translation | example hypothesis: و هل أنت في هذا الأمر ؟
# 2025-07-21 10:27:45 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:27:45 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أعرف أن هذا الأمر لا يعني أن هناك أي شيء
# 2025-07-21 10:27:45 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:27:46 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أعرف أن هذا الأمر لا يعني أنه من الممكن أن يكون هناك أي شيء ؟
# 2025-07-21 10:27:46 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:27:46 | INFO | fairseq.tasks.translation | example hypothesis: نعم ، أنا لا أعرف أن هذا الأمر لا يعني أن هناك أي شيء في أي مكان آخر.
# 2025-07-21 10:27:46 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:27:46 | INFO | fairseq.tasks.translation | example hypothesis: إذا كان هناك أي شيء في هذا الأمر ، فقال لي أنه من الممكن أن يكون هناك أي شيء في هذا الأمر.
# 2025-07-21 10:27:46 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:27:46 | INFO | valid | {"epoch": 7, "valid_loss": "9.728", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "8.821", "valid_ppl": "452.2", "valid_bleu": "0.17", "valid_wps": "3078.7", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "180", "valid_best_bleu": "0.17"}
# 2025-07-21 10:27:46 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 7 @ 180 updates
# 2025-07-21 10:27:46 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint7.pt
# ...
# 2025-07-21 10:53:50 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:53:51 | INFO | fairseq.tasks.translation | example hypothesis: قالت لي الموضوع UNKNOWNTOKENINHYP من قبل أن UNKNOWNTOKENINHYP ما رأيك في أن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP
# 2025-07-21 10:53:51 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:53:51 | INFO | fairseq.tasks.translation | example hypothesis: إنتبهت من الأUNKNOWNTOKENINHYP لأن الترجمة صعبة و تتوقف عن UNKNOWNTOKENINHYP النقود
# 2025-07-21 10:53:51 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:53:52 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP لم يكن هناك الكثير لأن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP ، و بقي على UNKNOWNTOKENINHYP لأنه UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP عندما كنت UNKNOWNTOKENINHYP مع عمل UNKNOWNTOKENINHYP ، لم UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP على UNKNOWNTOKENINHYP
# 2025-07-21 10:53:52 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:53:52 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP يرا ما UNKNOWNTOKENINHYP به ، لا UNKNOWNTOKENINHYP سوى فكرة حتى على أي UNKNOWNTOKENINHYP ، و أنا لا UNKNOWNTOKENINHYP أن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP ذلك اليوم عندما UNKNOWNTOKENINHYP كل شيء لا UNKNOWNTOKENINHYP على أن UNKNOWNTOKENINHYP ده UNKNOWNTOKENINHYP قبل أن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP و لا UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP عن أي خبرة UNKNOWNTOKENINHYP فقط
# 2025-07-21 10:53:52 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:53:52 | INFO | valid | {"epoch": 73, "valid_loss": "6.876", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "5.536", "valid_ppl": "46.38", "valid_bleu": "6.14", "valid_wps": "2847.9", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "1896", "valid_best_bleu": "6.94"}
# 2025-07-21 10:53:52 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 73 @ 1896 updates
# 2025-07-21 10:53:52 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint73.pt
# 2025-07-21 10:53:54 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint73.pt
# 2025-07-21 10:53:55 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:53:55 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint73.pt (epoch 73 @ 1896 updates, score 6.14) (writing took 3.242792110999744 seconds)
# 2025-07-21 10:53:56 | INFO | fairseq_cli.train | end of epoch 73 (average epoch stats below)
# 2025-07-21 10:53:56 | INFO | train | {"epoch": 73, "train_loss": "6.245", "train_aux_loss": "9.145", "train_mse_loss": "377.398", "train_kd_loss": "0", "train_nll_loss": "0.609", "train_ppl": "1.53", "train_wps": "1872.3", "train_ups": "1.25", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "1896", "train_lr": "0.000217872", "train_gnorm": "1.983", "train_loss_scale": "32", "train_train_wall": "8", "train_gb_free": "12.3", "train_wall": "1751"}
# 2025-07-21 10:53:56 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:53:56 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:53:56 | INFO | fairseq.trainer | begin training epoch 74
# 2025-07-21 10:53:56 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:53:58 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:00 | INFO | train_inner | {"epoch": 74, "update": 73.154, "loss": "6.271", "aux_loss": "9.133", "mse_loss": "378.523", "kd_loss": "0", "nll_loss": "0.626", "ppl": "1.54", "wps": "1474.6", "ups": "0.99", "wpb": "1493.6", "bsz": "157.7", "num_updates": "1900", "lr": "0.000217643", "gnorm": "1.963", "loss_scale": "32", "train_wall": "31", "gb_free": "12.4", "wall": "1755"}
# 2025-07-21 10:54:07 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:54:07 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:54:09 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:09 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:10 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP تضر UNKNOWNTOKENINHYP
# 2025-07-21 10:54:10 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:54:10 | INFO | fairseq.tasks.translation | example hypothesis: لكن مع الطلبة غير UNKNOWNTOKENINHYP ين
# 2025-07-21 10:54:10 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:54:11 | INFO | fairseq.tasks.translation | example hypothesis: هذا ما UNKNOWNTOKENINHYP لها ، أنا أيضا UNKNOWNTOKENINHYP يا UNKNOWNTOKENINHYP
# 2025-07-21 10:54:11 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:54:11 | INFO | fairseq.tasks.translation | example hypothesis: و كانت UNKNOWNTOKENINHYP قاطنة و الجو غاUNKNOWNTOKENINHYP لأنه غاUNKNOWNTOKENINHYP
# 2025-07-21 10:54:11 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:54:11 | INFO | fairseq.tasks.translation | example hypothesis: قالت لي هذا الموضوع UNKNOWNTOKENINHYP من قبل UNKNOWNTOKENINHYP ما رأيك في أن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP
# 2025-07-21 10:54:11 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:54:12 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP من الأمثلة لا UNKNOWNTOKENINHYP لأنهم أصليون و يتكاثروا إلى UNKNOWNTOKENINHYP
# 2025-07-21 10:54:12 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:54:12 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP لم يكن هناك الكثير لأن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP ، و بقي على UNKNOWNTOKENINHYP لأنه UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP عندما كنت UNKNOWNTOKENINHYP العمل مع UNKNOWNTOKENINHYP ، UNKNOWNTOKENINHYP لم UNKNOWNTOKENINHYP على أحد الأمثلة
# 2025-07-21 10:54:12 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:54:13 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP يرا ما UNKNOWNTOKENINHYP به ، لا UNKNOWNTOKENINHYP فقط عن أي فكرة لUNKNOWNTOKENINHYP و أنا أيضا لم أUNKNOWNTOKENINHYP عن أي يوم ، عندما UNKNOWNTOKENINHYP كل UNKNOWNTOKENINHYP على الإحتبار UNKNOWNTOKENINHYP ين أن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP ه قبل أن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP و لا UNKNOWNTOKENINHYP عن أي فكرة عنهم
# 2025-07-21 10:54:13 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:54:13 | INFO | valid | {"epoch": 74, "valid_loss": "6.908", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "5.574", "valid_ppl": "47.64", "valid_bleu": "6.25", "valid_wps": "2746.4", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "1922", "valid_best_bleu": "6.94"}
# 2025-07-21 10:54:13 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 74 @ 1922 updates
# 2025-07-21 10:54:13 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint74.pt
# 2025-07-21 10:54:15 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint74.pt
# 2025-07-21 10:54:16 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:16 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint74.pt (epoch 74 @ 1922 updates, score 6.25) (writing took 3.241143490000013 seconds)
# 2025-07-21 10:54:16 | INFO | fairseq_cli.train | end of epoch 74 (average epoch stats below)
# 2025-07-21 10:54:16 | INFO | train | {"epoch": 74, "train_loss": "6.184", "train_aux_loss": "9.152", "train_mse_loss": "374.449", "train_kd_loss": "0", "train_nll_loss": "0.574", "train_ppl": "1.49", "train_wps": "1868.9", "train_ups": "1.25", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "1922", "train_lr": "0.000216394", "train_gnorm": "1.663", "train_loss_scale": "32", "train_train_wall": "8", "train_gb_free": "12.5", "train_wall": "1772"}
# 2025-07-21 10:54:17 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:54:17 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:54:17 | INFO | fairseq.trainer | begin training epoch 75
# 2025-07-21 10:54:17 | INFO | fairseq_cli.train | Start iterating over samples
# 2025-07-21 10:54:19 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2025-07-21 10:54:27 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:54:30 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:30 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:31 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP تلني UNKNOWNTOKENINHYP
# 2025-07-21 10:54:31 | INFO | fairseq.tasks.translation | example reference: أنا UNKNOWNTOKENINREF تؤUNKNOWNTOKENINREF
# 2025-07-21 10:54:31 | INFO | fairseq.tasks.translation | example hypothesis: لكن مع الطلبة غير موجودين
# 2025-07-21 10:54:31 | INFO | fairseq.tasks.translation | example reference: ولكن مع أولئك الطلبة لا UNKNOWNTOKENINREF
# 2025-07-21 10:54:32 | INFO | fairseq.tasks.translation | example hypothesis: هذا ما UNKNOWNTOKENINHYP لها أنا أيضا UNKNOWNTOKENINHYP يا UNKNOWNTOKENINHYP
# 2025-07-21 10:54:32 | INFO | fairseq.tasks.translation | example reference: هذا ما UNKNOWNTOKENINREF لها أترين يا UNKNOWNTOKENINREF
# 2025-07-21 10:54:32 | INFO | fairseq.tasks.translation | example hypothesis: و كانت UNKNOWNTOKENINHYP قبعة و الجو غاUNKNOWNTOKENINHYP لأن الجو غاUNKNOWNTOKENINHYP
# 2025-07-21 10:54:32 | INFO | fairseq.tasks.translation | example reference: و كانت ترUNKNOWNTOKENINREF قبعة و الجو مUNKNOWNTOKENINREF بسبب الغيوم
# 2025-07-21 10:54:32 | INFO | fairseq.tasks.translation | example hypothesis: قالت لي هذا الموضوع UNKNOWNTOKENINHYP من قبل أن UNKNOWNTOKENINHYP ما رأيك في ذلك المUNKNOWNTOKENINHYP UNKNOWNTOKENINHYP
# 2025-07-21 10:54:32 | INFO | fairseq.tasks.translation | example reference: قالت لي هذا الموضوع عولج من قبل فما رأيك في هذا UNKNOWNTOKENINREF
# 2025-07-21 10:54:33 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP من الأمثلة لا UNKNOWNTOKENINHYP لأنهم أصليون و يتوقفون لنا UNKNOWNTOKENINHYP
# 2025-07-21 10:54:33 | INFO | fairseq.tasks.translation | example reference: احذروا من UNKNOWNTOKENINREF لأن UNKNOWNTOKENINREF متها صعبة و تفسد لنا "لو بلو"
# 2025-07-21 10:54:33 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP لم يكن هناك الكثير لأن UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP ، و بقي على UNKNOWNTOKENINHYP لأنه UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP عندما كنت UNKNOWNTOKENINHYP في العمل UNKNOWNTOKENINHYP لم UNKNOWNTOKENINHYP عن الإسلام
# 2025-07-21 10:54:33 | INFO | fairseq.tasks.translation | example reference: فرحت كثيرا أن الله UNKNOWNTOKENINREF ه للإسلام ، و UNKNOWNTOKENINREF نت كثيرا UNKNOWNTOKENINREF UNKNOWNTOKENINREF نفسي: أين كنت في هذه الفترة عن العاملين معي ؟ لم UNKNOWNTOKENINREF UNKNOWNTOKENINREF عن الإسلام
# 2025-07-21 10:54:34 | INFO | fairseq.tasks.translation | example hypothesis: الاUNKNOWNTOKENINHYP لا UNKNOWNTOKENINHYP فقط عن أي فكرة لUNKNOWNTOKENINHYP و أنا أيضا لم UNKNOWNTOKENINHYP اUNKNOWNTOKENINHYP ذلك اليوم عندما UNKNOWNTOKENINHYP كل شيء UNKNOWNTOKENINHYP على قياسي UNKNOWNTOKENINHYP ته قبل أن UNKNOWNTOKENINHYP ه و لا UNKNOWNTOKENINHYP عن أي فكرة عنهم
# 2025-07-21 10:54:34 | INFO | fairseq.tasks.translation | example reference: الإUNKNOWNTOKENINREF ص وضعته عشوائيا ، ليس لدي أية فكرة عن أي تخصص ، حتى UNKNOWNTOKENINREF لم UNKNOWNTOKENINREF حاضرة ذلك اليوم أين UNKNOWNTOKENINREF كل مسؤول عن UNKNOWNTOKENINREF ه لكي تكون لدى الطلبة فكرة قبل أن يختاروا ، و بما UNKNOWNTOKENINREF ليست لدي أي فكرة عن أي تخصص وضعت عشوائيا
# 2025-07-21 10:54:34 | INFO | valid | {"epoch": 75, "valid_loss": "6.927", "valid_aux_loss": "0", "valid_mse_loss": "0", "valid_kd_loss": "0", "valid_nll_loss": "5.587", "valid_ppl": "48.08", "valid_bleu": "6.21", "valid_wps": "2666.1", "valid_wpb": "1188.1", "valid_bsz": "112.4", "valid_num_updates": "1948", "valid_best_bleu": "6.94"}
# 2025-07-21 10:54:34 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 75 @ 1948 updates
# 2025-07-21 10:54:34 | INFO | fairseq.trainer | Saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint75.pt
# 2025-07-21 10:54:36 | INFO | fairseq.trainer | Finished saving checkpoint to /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint75.pt
# 2025-07-21 10:54:36 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2025-07-21 10:54:37 | INFO | fairseq.checkpoint_utils | Saved checkpoint /kaggle/working/kNN-TL/kNN-TL/checkpoints/child/checkpoint75.pt (epoch 75 @ 1948 updates, score 6.21) (writing took 3.29954096199981 seconds)
# 2025-07-21 10:54:37 | INFO | fairseq_cli.train | end of epoch 75 (average epoch stats below)
# 2025-07-21 10:54:37 | INFO | train | {"epoch": 75, "train_loss": "6.163", "train_aux_loss": "9.148", "train_mse_loss": "373.159", "train_kd_loss": "0", "train_nll_loss": "0.567", "train_ppl": "1.48", "train_wps": "1860.8", "train_ups": "1.25", "train_wpb": "1493", "train_bsz": "154.8", "train_num_updates": "1948", "train_lr": "0.000214945", "train_gnorm": "1.7", "train_loss_scale": "32", "train_train_wall": "8", "train_gb_free": "12.4", "train_wall": "1792"}
# 2025-07-21 10:54:37 | INFO | fairseq.data.iterators | grouped total_num_itrs = 26
# 2025-07-21 10:54:37 | WARNING | fairseq.logging.progress_bar | tensorboard not found, please install with: pip install tensorboard
# 2025-07-21 10:54:37 | INFO | fairseq.trainer | begin training epoch 76
# 2025-07-21 10:54:37 | INFO | fairseq_cli.train | Start iterating over samples
# ^C

# %% [markdown]
# Trained the child for 153 epochs. BLEU score peaked at 6.94 (low) and lots of unknownref tokens + Awful translations!, can be justified given that the child target data was preprocessed using the parent target dictionary!

# %% [markdown]
# Train the child model with parent representation alignment using MADAR dataset as the child data

# %%
# %%writefile /kaggle/working/kNN-TL/train-scripts/train_child2.sh
# PROJECT_PATH="/kaggle/working/kNN-TL/kNN-TL"
# warmup=1000
# seed=1
# lr=0.0003
# bsz=1000
# using_gpus=1
# w_decay=0.0
# max_epoch=200
# attn_dropout=0.1
# act_dropout=0.1
# freq=1
# kd_weight=0.01
# aug_weight=0.0
# prior_tau=1.0
# loss_type=mse
# kd_type=full_frozen
# aux_src_lang=en
#
# #source language
# src_lang=drj
# #INPUT
# aux_src="/kaggle/input/pseudo-madar/psmada-bin"
#
# parent_model="/kaggle/input/parent_best/pytorch/default/1/checkpoint_best.pt"
# parent_data="/kaggle/input/hplt-bin/Bin_hplt"
# child_data="/kaggle/input/bin-madar/Bin_madar"
# child_model="/kaggle/working/kNN-TL/initial_child2.pt"
#
# keep_dir=child2
# logdir=$PROJECT_PATH/child2_tensorboard_save_non_early_stop/$keep_dir
# save_dir=$PROJECT_PATH/checkpoints/$keep_dir
# train_log=/home/lynn/kNN-TL/kNN-TL/checkpoints/logs
#
# MKL_THREADING_LAYER=GNU CUDA_VISIBLE_DEVICES=0,1 /kaggle/working/venv/bin/python $PROJECT_PATH/train_transfer.py \
#     /kaggle/input/bin-madar/Bin_madar \
#     --arch transformer_from_pretrained_mt \
#     --share-decoder-input-output-embed \
#     --ddp-backend=no_c10d \
#     --pretrained-mt-checkpoint $child_model \
#     --aux-src-lang $aux_src_lang --aux-src $aux_src \
#     --teacher-data $parent_data \
#     --kd-weight $kd_weight --prior-tau $prior_tau --teacher-dir $parent_model --loss-type $loss_type \
#     --update-freq $freq \
#     --max-tokens $bsz \
#     --tensorboard-logdir clean_train \
#     --save-dir $save_dir \
#     --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
#     --lr $lr --lr-scheduler inverse_sqrt --warmup-updates $warmup --warmup-init-lr 1e-07 \
#     --dropout 0.3 --weight-decay $w_decay \
#     --attention-dropout $attn_dropout \
#     --activation-dropout $act_dropout \
#     --seed $seed \
#     --eval-bleu \
#     --max-epoch $max_epoch \
#     --keep-best-checkpoints 1 \
#     --keep-last-epochs 1 \
#     --eval-bleu-args '{"beam": 5, "lenpen":1}' \
#     --eval-bleu-detok moses \
#     --eval-bleu-remove-bpe \
#     --eval-bleu-print-samples \
#     --best-checkpoint-metric bleu --maximize-best-checkpoint-metric \
#     --criterion label_smoothed_cross_entropy_xkd --label-smoothing 0.1 \
#     --fp16 \
#     --log-format=json --log-interval=100 2>&1    |  tee -a  /kaggle/working/kNN-TL/kNN-TL/logs/child2_training_log.log 2>&1

# %%
# !bash /kaggle/working/kNN-TL/train-scripts/train_child2.sh

# %% [markdown]
# Training stopped after 100 epochs, BLEU score peaked at 10.11. Lots of unknownref tokens too. Predictions are awful even with parent representation alignment.

# %% [markdown]
# Let's train a model from scratch to translate from darija to msa using MADAR

# %%
# !mkdir /kaggle/working/kNN-TL/kNN-TL/checkpoints/scratch_drjar_madar

# %%
# %%writefile /kaggle/working/kNN-TL/train-scripts/raw_child2.sh
# #I'm going now to train a raw child (vanilla transformer) on padic data tokenized using padic
# PROJECT_PATH="/kaggle/working/kNN-TL/kNN-TL"
# CHILDREN='/home/lynn/kNN-TL/raw_children'
# warmup=1000
# seed=1
# dropout=0.3
# max_epoch=200
# lr=0.0003
# act_drop=0.1
# attn_drop=0.1
# s="drj"
# t="ar"
# child_data="/kaggle/input/bin-madar/Bin_madar" #/home/lynn/kNN-TL/binarized_data/ar_drj.tokenized.drj-ar #other data(doda):/home/lynn/kNN-TL/data-process-moses/Binarized_child
# #other data(padic with moses): /home/lynn/kNN-TL/data-process-moses/Binarized_childpadic
# #other data (padic with moses and the arabic target is binarized using the arabic parent dictionary): /home/lynn/kNN-TL/data-process-moses/Binarized_child2
# keep_dir=scratch_drjar_madar
# logdir=$PROJECT_PATH/rawchild2_tensorboard_save_non_early_stop/$keep_dir
# save_dir=$PROJECT_PATH/checkpoints/$keep_dir
# train_log=/home/lynn/kNN-TL/kNN-TL/checkpoints/logs
#
#
# CUDA_VISIBLE_DEVICES=0,1 MKL_THREADING_LAYER=GNU /kaggle/working/venv/bin/fairseq-train \
#     /kaggle/input/bin-madar/Bin_madar \
#     -s "drj" -t "ar" \
#     --arch transformer \
#     --reset-optimizer \
#     --reset-dataloader \
#     --activation-dropout $act_drop --attention-dropout $attn_drop \
#     --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
#     --lr $lr --lr-scheduler inverse_sqrt --warmup-updates $warmup --warmup-init-lr 1e-07 \
#     --dropout $dropout --weight-decay 0.0 \
#     --tensorboard-logdir $logdir \
#     --save-dir $save_dir --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
#     --max-tokens 1000 \
#     --seed $seed \
#     --max-epoch $max_epoch \
#     --no-epoch-checkpoints \
#     --keep-last-epochs 1 \
#     --keep-best-checkpoints 1 \
#     --eval-bleu \
#     --eval-bleu-args '{"beam": 5, "lenpen":1.0}' \
#     --eval-tokenized-bleu \
#     --eval-bleu-remove-bpe \
#     --eval-bleu-print-samples \
#     --best-checkpoint-metric bleu --maximize-best-checkpoint-metric \
#     --fp16  \
#     --log-format=json --log-interval=100 2>&1    |  tee -a /kaggle/working/kNN-TL/kNN-TL/logs/training_log_rawchild2.log

# %%
# !bash /kaggle/working/kNN-TL/train-scripts/raw_child2.sh

# %% [markdown]
# Awful performance as expected. Peak BLEU reached 5.52

# %% [markdown]
# Let's train a (drj to msa) model initialized with parent knowledge and token-matching (TM-TL)

# %%
# !mkdir /kaggle/working/kNN-TL/kNN-TL/checkpoints/tmtlchild2

# %%
# !cp /kaggle/working/kNN-TL/initial_child2.pt /kaggle/working/kNN-TL/kNN-TL/checkpoints/tmtlchild2/checkpoint_last.pt

# %%
# %%writefile /kaggle/working/kNN-TL/train-scripts/tmtl_child2.sh
# #I'm going now to train a raw child (vanilla transformer) on padic data tokenized using padic
# PROJECT_PATH="/kaggle/working/kNN-TL/kNN-TL"
# CHILDREN='/home/lynn/kNN-TL/raw_children'
# warmup=1000
# seed=1
# dropout=0.3
# max_epoch=200
# lr=0.0003
# act_drop=0.1
# attn_drop=0.1
# s="drj"
# t="ar"
# child_data="/kaggle/input/bin-madar/Bin_madar" #/home/lynn/kNN-TL/binarized_data/ar_drj.tokenized.drj-ar #other data(doda):/home/lynn/kNN-TL/data-process-moses/Binarized_child
# #other data(padic with moses): /home/lynn/kNN-TL/data-process-moses/Binarized_childpadic
# #other data (padic with moses and the arabic target is binarized using the arabic parent dictionary): /home/lynn/kNN-TL/data-process-moses/Binarized_child2
# keep_dir=tmtlchild2
# logdir=$PROJECT_PATH/tmtlchild2_tensorboard_save_non_early_stop/$keep_dir
# save_dir=$PROJECT_PATH/checkpoints/$keep_dir
# train_log=/home/lynn/kNN-TL/kNN-TL/checkpoints/logs
#
#
#
# CUDA_VISIBLE_DEVICES=0,1 MKL_THREADING_LAYER=GNU /kaggle/working/venv/bin/fairseq-train \
#     /kaggle/input/bin-madar/Bin_madar \
#     -s "drj" -t "ar" \
#     --arch transformer \
#     --reset-optimizer \
#     --reset-dataloader \
#     --activation-dropout $act_drop --attention-dropout $attn_drop \
#     --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
#     --lr $lr --lr-scheduler inverse_sqrt --warmup-updates $warmup --warmup-init-lr 1e-07 \
#     --dropout $dropout --weight-decay 0.0 \
#     --tensorboard-logdir $logdir \
#     --save-dir $save_dir --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
#     --max-tokens 1000 \
#     --seed $seed \
#     --max-epoch $max_epoch \
#     --no-epoch-checkpoints \
#     --keep-last-epochs 1 \
#     --keep-best-checkpoints 1 \
#     --eval-bleu \
#     --eval-bleu-args '{"beam": 5, "lenpen":1.0}' \
#     --eval-tokenized-bleu \
#     --eval-bleu-remove-bpe \
#     --eval-bleu-print-samples \
#     --best-checkpoint-metric bleu --maximize-best-checkpoint-metric \
#     --fp16  \
#     --log-format=json --log-interval=100 2>&1    |  tee -a /kaggle/working/kNN-TL/kNN-TL/logs/training_log_tmtlchild2.log
# Out:
# Writing /kaggle/working/kNN-TL/train-scripts/tmtl_child2.sh

# %% [markdown]
# Need to modify distributed/utils.py so that the tm-tl script works. however this modification hinders the work of other training scripts. be careful.

# %%
# %%writefile /kaggle/working/kNN-TL/kNN-TL/fairseq/distributed/utils.py
# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

import io
import logging
import os
import pickle
import random
import socket
import struct
import subprocess
import warnings
from argparse import Namespace
from collections import OrderedDict
from dataclasses import dataclass
from typing import Any, Dict, List, Mapping, Optional

import torch
import torch.distributed as dist
from fairseq.dataclass.configs import DistributedTrainingConfig, FairseqConfig
from omegaconf import open_dict

try:
    import torch_xla.core.xla_model as xm
except ImportError:
    xm = None


# Flag to indicate if we're using Megatron
# NOTE: this is a temporary hack until we move away from Megatron's model parallel init
_USE_MEGATRON = False

# Whether to use XLA ops (e.g., on TPUs) instead of CUDA ops.
_USE_XLA = False


logger = logging.getLogger(__name__)


def is_master(cfg: DistributedTrainingConfig):
    return cfg.distributed_rank == 0


def infer_init_method(cfg: DistributedTrainingConfig, force_distributed=False):
    if cfg.distributed_init_method is not None or cfg.tpu:
        return

    num_pipelines_per_node = None
    if cfg.pipeline_model_parallel:
        num_pipeline_devices, num_pipelines_per_node = _pipeline_parallel_pre_init(cfg)

    if all(
        key in os.environ
        for key in ["MASTER_ADDR", "MASTER_PORT", "WORLD_SIZE", "RANK"]
    ):
        # support torch.distributed.launch
        _infer_torch_distributed_launch_init(cfg)
    elif cfg.distributed_port > 0:
        # we can determine the init method automatically for Slurm
        _infer_slurm_init(cfg, num_pipelines_per_node)
    elif cfg.distributed_world_size > 1 or force_distributed:
        # fallback for single node with multiple GPUs
        _infer_single_node_init(cfg)

    if cfg.pipeline_model_parallel:
        _pipeline_parallel_post_init(cfg, num_pipeline_devices, num_pipelines_per_node)
    elif not cfg.distributed_no_spawn:
        with open_dict(cfg):
            cfg.distributed_num_procs = min(
                torch.cuda.device_count(), cfg.distributed_world_size
            )


def _infer_torch_distributed_launch_init(cfg: DistributedTrainingConfig):
    cfg.distributed_init_method = "env://"
    cfg.distributed_world_size = int(os.environ["WORLD_SIZE"])
    cfg.distributed_rank = int(os.environ["RANK"])
    # processes are created by torch.distributed.launch
    cfg.distributed_no_spawn = True


def _infer_slurm_init(cfg: DistributedTrainingConfig, num_pipelines_per_node):
    node_list = os.environ.get("SLURM_STEP_NODELIST")
    if node_list is None:
        node_list = os.environ.get("SLURM_JOB_NODELIST")
    if node_list is not None:
        try:
            hostnames = subprocess.check_output(
                ["scontrol", "show", "hostnames", node_list]
            )
            cfg.distributed_init_method = "tcp://{host}:{port}".format(
                host=hostnames.split()[0].decode("utf-8"),
                port=cfg.distributed_port,
            )
            nnodes = int(os.environ.get("SLURM_NNODES"))
            ntasks_per_node = os.environ.get("SLURM_NTASKS_PER_NODE")
            if ntasks_per_node is not None:
                ntasks_per_node = int(ntasks_per_node)
            else:
                ntasks = int(os.environ.get("SLURM_NTASKS"))
                nnodes = int(os.environ.get("SLURM_NNODES"))
                assert ntasks % nnodes == 0
                ntasks_per_node = int(ntasks / nnodes)
            if ntasks_per_node == 1:
                gpus_per_node = torch.cuda.device_count()
                node_id = int(os.environ.get("SLURM_NODEID"))
                cfg.distributed_rank = node_id * gpus_per_node
                cfg.distributed_world_size = nnodes * gpus_per_node
            elif cfg.pipeline_model_parallel:
                assert ntasks_per_node == num_pipelines_per_node, (
                    "SLURM --ntasks-per-node must match number of pipelines per "
                    "node (={})".format(num_pipelines_per_node)
                )
                cfg.distributed_no_spawn = True
                # For 4-way MP on nodes with 8 GPUs, ranks will be [0, 1] on
                # the first node, [1, 2] on the second node, etc. This
                # matches torch.distributed.launch.
                node_id = int(os.environ.get("SLURM_NODEID"))
                local_id = int(os.environ.get("SLURM_LOCALID"))
                cfg.distributed_rank = node_id * num_pipelines_per_node + local_id
                # In the above example, device_id will always be in [0, 1],
                # which also matches torch.distributed.launch.
                cfg.device_id = local_id
                # We also want to set distributed_world_size to be the total
                # number of pipelines across all nodes.
                cfg.distributed_world_size = nnodes * num_pipelines_per_node
            else:
                assert ntasks_per_node == cfg.distributed_world_size // nnodes
                cfg.distributed_no_spawn = True
                cfg.distributed_rank = int(os.environ.get("SLURM_PROCID"))
                cfg.device_id = int(os.environ.get("SLURM_LOCALID"))
        except subprocess.CalledProcessError as e:  # scontrol failed
            raise e
        except FileNotFoundError:  # Slurm is not installed
            pass


def _infer_single_node_init(cfg: DistributedTrainingConfig):
    assert (
        cfg.distributed_world_size <= torch.cuda.device_count()
    ), f"world size is {cfg.distributed_world_size} but have {torch.cuda.device_count()} available devices"
    port = random.randint(10000, 20000)
    cfg.distributed_init_method = "tcp://localhost:{port}".format(port=port)


def _pipeline_parallel_pre_init(cfg: DistributedTrainingConfig):
    from fairseq import utils

    balance_exists = (
        cfg.pipeline_balance is not None
        or cfg.pipeline_encoder_balance is not None
        or cfg.pipeline_decoder_balance is not None
    )
    devices_exist = (
        cfg.pipeline_devices is not None
        or cfg.pipeline_encoder_devices is not None
        or cfg.pipeline_decoder_devices is not None
    )
    if not balance_exists:
        raise ValueError(
            "--pipeline-balance is currently required for pipeline model parallelism"
        )
    if not devices_exist:
        raise ValueError(
            "--pipeline-devices is currently required for pipeline model parallelism"
        )

    cfg.pipeline_balance = utils.eval_str_list(cfg.pipeline_balance, type=int)
    if cfg.pipeline_devices is not None:
        cfg.pipeline_devices = utils.eval_str_list(cfg.pipeline_devices, type=int)
        num_pipeline_devices = len(set(cfg.pipeline_devices))
    else:
        cfg.pipeline_encoder_devices = utils.eval_str_list(
            cfg.pipeline_encoder_devices, type=int
        )
        cfg.pipeline_decoder_devices = utils.eval_str_list(
            cfg.pipeline_decoder_devices, type=int
        )
        num_pipeline_devices = len(
            set(cfg.pipeline_encoder_devices + cfg.pipeline_decoder_devices)
        )
    gpus_per_node = torch.cuda.device_count()
    assert (
        gpus_per_node >= num_pipeline_devices
        and gpus_per_node % num_pipeline_devices == 0
    ), (
        "the number of unique device IDs in --pipeline-devices must evenly divide "
        "the number of GPUs per node (multi-node pipelining is not yet supported)"
    )
    num_pipelines_per_node = gpus_per_node // num_pipeline_devices
    return num_pipeline_devices, num_pipelines_per_node


def _pipeline_parallel_post_init(
    cfg: DistributedTrainingConfig, num_pipeline_devices, num_pipelines_per_node
):
    if not cfg.distributed_no_spawn:
        # When distributed_no_spawn is False, we expect distributed_rank and
        # distributed_world_size to be based on the total number of GPUs, so
        # we need to correct them to be based on the number of pipelines.
        assert cfg.distributed_world_size % num_pipeline_devices == 0
        cfg.distributed_world_size = cfg.distributed_world_size // num_pipeline_devices
        # In the case of 4-way MP on nodes with 8 GPUs, we want
        # distributed_rank to be the starting GPU index for each pipeline
        # i.e., 0, 2, ...
        gpus_per_node = torch.cuda.device_count()
        assert cfg.distributed_rank % gpus_per_node == 0
        assert cfg.distributed_rank % num_pipeline_devices == 0

        with open_dict(cfg):
            cfg.distributed_rank = cfg.distributed_rank // num_pipeline_devices
            # launch one process per pipeline
            cfg.distributed_num_procs = num_pipelines_per_node

    # if we have 4-way MP on a node with 8 GPUs, we want device_ids to be 0
    # and 4, indicating the starting device IDs for each pipeline
    cfg.device_id *= num_pipeline_devices

    if cfg.device_id > 0:
        # if there's multiple pipelines on a node (e.g., 4-way MP on an 8
        # GPU node), we need to adjust pipeline_devices accordingly
        logger.debug(
            "setting CUDA device={} on rank {}".format(
                cfg.device_id, cfg.distributed_rank
            )
        )
        torch.cuda.set_device(cfg.device_id)
        with open_dict(cfg):
            cfg.pipeline_devices = [cfg.device_id + d for d in cfg.pipeline_devices]
        logger.info(
            "setting pipeline_devices={} on rank {}".format(
                cfg.pipeline_devices, cfg.distributed_rank
            )
        )


def distributed_init(cfg: FairseqConfig):
    if isinstance(cfg, Namespace):
        from fairseq.dataclass.utils import convert_namespace_to_omegaconf

        cfg = convert_namespace_to_omegaconf(cfg)

    if not cfg.common.tpu:
        if torch.distributed.is_available() and torch.distributed.is_initialized():
            warnings.warn(
                "Distributed is already initialized, cannot initialize twice!"
            )
        else:
            logger.info(
                "distributed init (rank {}): {}".format(
                    cfg.distributed_training.distributed_rank,
                    cfg.distributed_training.distributed_init_method,
                )
            )
            dist.init_process_group(
                backend=cfg.distributed_training.distributed_backend,
                init_method=cfg.distributed_training.distributed_init_method,
                world_size=cfg.distributed_training.distributed_world_size,
                rank=cfg.distributed_training.distributed_rank,
            )
            logger.info(
                "initialized host {} as rank {}".format(
                    socket.gethostname(),
                    cfg.distributed_training.distributed_rank,
                )
            )

            # perform a dummy all-reduce to initialize the NCCL communicator
            if torch.cuda.is_available():
                dist.all_reduce(torch.zeros(1).cuda())

        cfg.distributed_training.distributed_rank = torch.distributed.get_rank()
    else:
        assert xm.xrt_world_size() == cfg.distributed_training.distributed_world_size
        global _USE_XLA
        _USE_XLA = True
        cfg.distributed_training.device_id = xm.get_local_ordinal()
        cfg.distributed_training.distributed_rank = xm.get_ordinal()
        xm.rendezvous("distributed_init")  # wait for all workers

    if is_master(cfg.distributed_training):
        logging.getLogger().setLevel(logging.INFO)
    else:
        logging.getLogger().setLevel(logging.WARNING)

    if cfg.common.model_parallel_size > 1:
        try:
            from fairseq.model_parallel.megatron.mpu import (
                initialize_model_parallel,
                model_parallel_cuda_manual_seed,
            )
        except ImportError:
            raise ImportError(
                "\n\nPlease install the megatron submodule:"
                "\n\n  git submodule update --init "
                "fairseq/model_parallel/megatron"
            )
        global _USE_MEGATRON
        _USE_MEGATRON = True
        initialize_model_parallel(cfg.common.model_parallel_size)
        model_parallel_cuda_manual_seed(cfg.common.seed)
        model_part_number = get_model_parallel_rank()
        cfg.checkpoint.checkpoint_suffix += "-model_part-{0}".format(model_part_number)

    if hasattr(cfg, "model") and getattr(cfg.model, "base_layers", 0) > 0:
        cfg.checkpoint.checkpoint_suffix = (
            f"-rank-{cfg.distributed_training.distributed_rank}"
        )

    return cfg.distributed_training.distributed_rank


def distributed_main(i, main, cfg: FairseqConfig, kwargs):
    cfg.distributed_training.device_id = i
    if torch.cuda.is_available() and not cfg.common.cpu and not cfg.common.tpu:
        torch.cuda.set_device(cfg.distributed_training.device_id)
    if cfg.distributed_training.distributed_rank is None:  # torch.multiprocessing.spawn
        cfg.distributed_training.distributed_rank = kwargs.pop("start_rank", 0) + i

    cfg.distributed_training.distributed_rank = distributed_init(cfg)

    after_distributed_init_fn = kwargs.pop("after_distributed_init_fn", None)
    if after_distributed_init_fn:
        cfg = after_distributed_init_fn(cfg)

    main(cfg, **kwargs)

    if torch.distributed.is_initialized():
        torch.distributed.barrier(get_global_group())


def call_main(cfg: FairseqConfig, main, **kwargs):
    if cfg.distributed_training.distributed_init_method is None:
        infer_init_method(cfg.distributed_training)

    if cfg.distributed_training.distributed_init_method is not None:
        # distributed training
        if not cfg.distributed_training.distributed_no_spawn:
            start_rank = cfg.distributed_training.distributed_rank
            cfg.distributed_training.distributed_rank = None  # assign automatically
            kwargs["start_rank"] = start_rank
            torch.multiprocessing.spawn(
                fn=distributed_main,
                args=(main, cfg, kwargs),
                nprocs=min(
                    torch.cuda.device_count(),
                    cfg.distributed_training.distributed_world_size,
                ),
                join=True,
            )
        else:
            distributed_main(cfg.distributed_training.device_id, main, cfg, kwargs)
    elif cfg.common.tpu and cfg.distributed_training.distributed_world_size > 1:
        import torch_xla.distributed.xla_multiprocessing as xmp

        torch.multiprocessing.set_sharing_strategy("file_system")
        xmp.spawn(
            fn=distributed_main,
            args=(main, cfg, kwargs),
            # tpu-comment:
            #   8 devices in one TPU VM, is the max processes to be spawned.
            #   The rest is driven by xm.distributed.xla_dist
            nprocs=min(cfg.distributed_training.distributed_world_size, 8),
        )
    else:
        # single GPU main
        main(cfg, **kwargs)


def use_xla():
    global _USE_XLA
    return _USE_XLA


def new_groups(grouped_ranks: List[List[int]]):
    if use_xla():
        return ("tpu", grouped_ranks)
    else:
        groups = [dist.new_group(g) for g in grouped_ranks]
        my_group_idx = _find_my_group_index(grouped_ranks)
        return groups[my_group_idx]


def _find_my_group_index(grouped_ranks):
    my_rank = get_global_rank()
    for i, group in enumerate(grouped_ranks):
        if my_rank in group:
            return i
    raise RuntimeError


def _find_my_group(grouped_ranks):
    index = _find_my_group_index(grouped_ranks)
    return grouped_ranks[index]


def get_rank(group):
    if use_xla():
        assert group[0] == "tpu"
        my_group = _find_my_group(group[1])
        return my_group.index(get_global_rank())
    else:
        return dist.get_rank(group=group)


def get_world_size(group):
    if use_xla():
        assert group[0] == "tpu"
        my_group = _find_my_group(group[1])
        return len(my_group)
    elif torch.distributed.is_initialized():
        return dist.get_world_size(group=group)
    else:
        return 1


def get_global_group():
    if use_xla():
        return new_groups([list(range(get_global_world_size()))])
    elif torch.distributed.is_initialized():
        if not hasattr(get_global_group, "_global_group"):
            # ideally we could use torch.distributed.group.WORLD, but it seems
            # to cause random NCCL hangs in some cases
            get_global_group._global_group = dist.new_group()
        return get_global_group._global_group
    else:
        return None


def get_global_rank():
    if use_xla():
        return xm.get_ordinal()
    elif torch.distributed.is_initialized():
        return torch.distributed.get_rank()
    else:
        return 0


def get_global_world_size():
    if use_xla():
        return xm.xrt_world_size()
    elif torch.distributed.is_initialized():
        return torch.distributed.get_world_size()
    else:
        return 1


def get_data_parallel_group():
    """Get the data parallel group the caller rank belongs to."""
    global _USE_MEGATRON
    if _USE_MEGATRON:
        from fairseq.model_parallel.megatron import mpu

        return mpu.get_data_parallel_group()
    else:
        return get_global_group()


def get_data_parallel_rank():
    """Return my rank for the data parallel group."""
    return get_rank(get_data_parallel_group())


def get_data_parallel_world_size():
    """Return world size for the data parallel group."""
    return get_world_size(get_data_parallel_group())


def get_model_parallel_group():
    global _USE_MEGATRON
    if _USE_MEGATRON:
        from fairseq.model_parallel.megatron import mpu

        return mpu.get_model_parallel_group()
    else:
        return None


def get_model_parallel_rank():
    """Return my rank for the model parallel group."""
    return get_rank(get_model_parallel_group())


def get_model_parallel_world_size():
    """Return world size for the model parallel group."""
    return get_world_size(get_model_parallel_group())


def all_reduce(tensor, group, op="sum"):
    if use_xla():
        assert isinstance(group, tuple) and group[0] == "tpu"
        tensor = [tensor]  # wrap in a list to make xm.all_reduce in-place
        return xm.all_reduce(op, tensor, groups=group[1])[0]
    else:
        if op == "sum":
            op = dist.ReduceOp.SUM
        elif op == "max":
            op = dist.ReduceOp.MAX
        else:
            raise NotImplementedError
        dist.all_reduce(tensor, op=op, group=group)
        return tensor


def broadcast(tensor, src, group):
    if use_xla():
        # XLA doesn't support broadcast, hack it with all_reduce
        if get_rank(group) != src:
            tensor.zero_()
        all_reduce(tensor, group)
    else:
        dist.broadcast(tensor, src=src, group=group)


def all_to_all(tensor, group):
    """Perform an all-to-all operation on a 1D Tensor."""
    assert tensor.dim() == 1
    split_count = get_world_size(group=group)
    assert tensor.numel() % split_count == 0
    if use_xla():
        assert isinstance(group, tuple) and group[0] == "tpu"
        return xm.all_to_all(
            tensor,
            split_dimension=0,
            concat_dimension=0,
            split_count=split_count,
            groups=group[1],
        )
    else:
        output = torch.zeros_like(tensor)
        dist.all_to_all_single(output, tensor, group=group)
        return output


def all_gather(tensor, group, return_tensor=False):
    """Perform an all-gather operation."""
    if use_xla():
        result = xm.all_gather(tensor, groups=group[1])
        world_size = get_world_size(group=group)
        result = result.view(world_size, *tensor.size())
        if return_tensor:
            return result
        else:
            return [result[i] for i in range(world_size)]
    else:
        world_size = get_world_size(group=group)
        rank = get_rank(group=group)
        tensor_list = [
            tensor if i == rank else torch.empty_like(tensor) for i in range(world_size)
        ]
        dist.all_gather(tensor_list, tensor, group=group)
        if return_tensor:
            return torch.stack(tensor_list, dim=0)
        else:
            return tensor_list


def all_gather_list(data, group=None, max_size=16384):
    """Gathers arbitrary data from all nodes into a list.

    Similar to :func:`~torch.distributed.all_gather` but for arbitrary Python
    data. Note that *data* must be picklable and any CUDA tensors will be moved
    to CPU and returned on CPU as well.

    Args:
        data (Any): data from the local worker to be gathered on other workers
        group: group of the collective
        max_size (int, optional): maximum size of the data to be gathered
            across workers
    """
    from fairseq import utils

    if group is None:
        group = get_global_group()
    rank = get_rank(group=group)
    world_size = get_world_size(group=group)

    buffer_size = max_size * world_size
    if (
        not hasattr(all_gather_list, "_buffer")
        or all_gather_list._buffer.numel() < buffer_size
    ):
        # all_gather_list._buffer = torch.cuda.ByteTensor(buffer_size)
        # all_gather_list._cpu_buffer = torch.ByteTensor(max_size).pin_memory()
        all_gather_list._buffer = torch.empty(buffer_size, dtype=torch.uint8, device='cuda')
        all_gather_list._cpu_buffer = torch.empty(max_size, dtype=torch.uint8, pin_memory=True)

    buffer = all_gather_list._buffer
    buffer.zero_()
    cpu_buffer = all_gather_list._cpu_buffer

    data = utils.move_to_cpu(data)
    enc = pickle.dumps(data)
    enc_size = len(enc)
    header_size = 4  # size of header that contains the length of the encoded data
    size = header_size + enc_size
    if size > max_size:
        raise ValueError(
            "encoded data size ({}) exceeds max_size ({})".format(size, max_size)
        )

    header = struct.pack(">I", enc_size)
    cpu_buffer[:size] = torch.ByteTensor(list(header + enc))
    start = rank * max_size
    buffer[start : start + size].copy_(cpu_buffer[:size])

    all_reduce(buffer, group=group)

    buffer = buffer.cpu()
    try:
        result = []
        for i in range(world_size):
            out_buffer = buffer[i * max_size : (i + 1) * max_size]
            (enc_size,) = struct.unpack(">I", bytes(out_buffer[:header_size].tolist()))
            if enc_size > 0:
                result.append(
                    pickle.loads(
                        bytes(out_buffer[header_size : header_size + enc_size].tolist())
                    )
                )
        return result
    except pickle.UnpicklingError:
        raise Exception(
            "Unable to unpickle data from other workers. all_gather_list requires all "
            "workers to enter the function together, so this error usually indicates "
            "that the workers have fallen out of sync somehow. Workers can fall out of "
            "sync if one of them runs out of memory, or if there are other conditions "
            "in your training script that can cause one worker to finish an epoch "
            "while other workers are still iterating over their portions of the data. "
            "Try rerunning with --ddp-backend=legacy_ddp and see if that helps."
        )


def all_reduce_dict(data: Mapping[str, Any], device, group) -> Dict[str, Any]:
    """
    AllReduce a dictionary of values across workers. We separately
    reduce items that are already on the device and items on CPU for
    better performance.

    Args:
        data (Mapping[str, Any]): dictionary of data to all-reduce, but
            cannot be a nested dictionary
        device (torch.device): device for the reduction
        group: group of the collective
    """
    data_keys = list(data.keys())

    # We want to separately reduce items that are already on the
    # device and items on CPU for performance reasons.
    cpu_data = OrderedDict()
    device_data = OrderedDict()
    for k in data_keys:
        t = data[k]
        if not torch.is_tensor(t):
            cpu_data[k] = torch.tensor(t, dtype=torch.double)
        elif t.device.type != device.type:
            cpu_data[k] = t.to(dtype=torch.double)
        else:
            device_data[k] = t.to(dtype=torch.double)

    def _all_reduce_dict(data: OrderedDict):
        if len(data) == 0:
            return data
        buf = torch.cat([t.view(-1) for t in data.values()]).to(device=device)
        all_reduce(buf, group=group)
        split_buf = torch.split(buf.clone(), [t.numel() for t in data.values()])
        reduced_data = [t.view_as(orig) for t, orig in zip(split_buf, data.values())]
        return OrderedDict(zip(data.keys(), reduced_data))

    cpu_data = _all_reduce_dict(cpu_data)
    device_data = _all_reduce_dict(device_data)

    def get_from_stack(key):
        if key in cpu_data:
            return cpu_data[key]
        elif key in device_data:
            return device_data[key]
        raise KeyError

    return OrderedDict([(key, get_from_stack(key)) for key in data_keys])


def broadcast_tensors(
    tensors: Optional[List[torch.Tensor]],
    src_rank: int,
    group: object,
    dist_device: Optional[torch.device] = None,
) -> List[torch.Tensor]:
    """
    Broadcasts a list of tensors without other (non-src) ranks needing to know
    the dtypes/shapes of the tensors.
    """
    if dist_device is None:
        if torch.distributed.get_backend(group) == "nccl":
            dist_device = torch.device("cuda")
        else:
            dist_device = torch.device("cpu")

    # share metadata first to simplify transfer
    is_src_rank = get_rank(group) == src_rank
    if is_src_rank:
        metadata = [
            {"size": t.size(), "dtype": t.dtype, "device": t.device} for t in tensors
        ]
        metadata = _broadcast_object_slow(metadata, src_rank, group, dist_device)
    else:
        metadata = _broadcast_object_slow(None, src_rank, group, dist_device)

    out_tensors = []
    for i, meta in enumerate(metadata):
        if is_src_rank:
            tensor = tensors[i]
            broadcast(tensors[i].to(dist_device), src=src_rank, group=group)
        else:
            tensor = torch.zeros(
                [meta["size"].numel()], dtype=meta["dtype"], device=dist_device
            )
            broadcast(tensor, src=src_rank, group=group)
        tensor = tensor.view(meta["size"]).to(meta["device"])
        out_tensors.append(tensor)
    return out_tensors


def broadcast_object(
    obj: Any,
    src_rank: int,
    group: object,
    dist_device: Optional[torch.device] = None,
) -> Any:
    """Broadcast an arbitrary Python object to other workers."""
    if dist_device is None:
        if torch.distributed.get_backend(group) == "nccl":
            dist_device = torch.device("cuda")
        else:
            dist_device = torch.device("cpu")

    if get_rank(group) == src_rank:
        # split the tensors from the non-tensors so we can broadcast them
        # directly, avoiding unnecessary serialization/deserialization
        tensors = []
        obj = _split_tensors_from_obj(obj, tensors)
        obj = _broadcast_object_slow(obj, src_rank, group, dist_device)
        tensors = broadcast_tensors(tensors, src_rank, group, dist_device)
    else:
        obj = _broadcast_object_slow(None, src_rank, group, dist_device)
        tensors = broadcast_tensors(None, src_rank, group, dist_device)
    return _put_tensors_in_obj(obj, tensors)


def _broadcast_object_slow(
    obj: Any,
    src_rank: int,
    group: object,
    dist_device: torch.device,
) -> Any:
    if get_rank(group) == src_rank:
        # Emit data
        buffer = io.BytesIO()
        torch.save(obj, buffer)
        buffer = torch.ByteTensor(buffer.getbuffer()).to(dist_device)
        length = torch.LongTensor([len(buffer)]).to(dist_device)
        broadcast(length, src=src_rank, group=group)
        broadcast(buffer, src=src_rank, group=group)
    else:
        # Fetch from the source
        length = torch.LongTensor([0]).to(dist_device)
        broadcast(length, src=src_rank, group=group)
        buffer = torch.ByteTensor(int(length.item())).to(dist_device)
        broadcast(buffer, src=src_rank, group=group)
        buffer = io.BytesIO(buffer.cpu().numpy())
        obj = torch.load(buffer, map_location="cpu", weights_only=False) #previously no weight's_only=False
    return obj


@dataclass(frozen=True)
class _TensorPlaceholder:
    index: int


def _split_tensors_from_obj(obj: Any, tensors: List[torch.Tensor]) -> Any:
    if torch.is_tensor(obj):
        placeholder = _TensorPlaceholder(index=len(tensors))
        tensors.append(obj)
        return placeholder
    elif isinstance(obj, dict):
        return {k: _split_tensors_from_obj(v, tensors) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [_split_tensors_from_obj(v, tensors) for v in obj]
    elif isinstance(obj, tuple):
        return tuple(_split_tensors_from_obj(v, tensors) for v in obj)
    elif isinstance(obj, set):
        return {_split_tensors_from_obj(v, tensors) for v in obj}
    else:
        return obj


def _put_tensors_in_obj(obj: Any, tensors: List[torch.Tensor]) -> Any:
    if isinstance(obj, _TensorPlaceholder):
        return tensors[obj.index]
    elif isinstance(obj, dict):
        return {k: _put_tensors_in_obj(v, tensors) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [_put_tensors_in_obj(v, tensors) for v in obj]
    elif isinstance(obj, tuple):
        return tuple(_put_tensors_in_obj(v, tensors) for v in obj)
    elif isinstance(obj, set):
        return {_put_tensors_in_obj(v, tensors) for v in obj}
    else:
        return obj
# Out:
# Overwriting /kaggle/working/kNN-TL/kNN-TL/fairseq/distributed/utils.py

# %%
# !bash /kaggle/working/kNN-TL/train-scripts/tmtl_child2.sh

# %% [markdown]
# TM-TL is shown to be better than kNN-TL for our case, for both datasets (MADAR, PADIC). Even tho the performance is real low (BLEU score peaked at 11.53), the parent representation alignment showed to be no good no beneficial for the child training.
